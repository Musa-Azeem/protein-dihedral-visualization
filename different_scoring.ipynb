# %%
# %load_ext autoreload
# %autoreload 2

# %%
from lib import DihedralAdherence
from lib import PDBMineQuery
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from pathlib import Path
PDBMINE_URL = os.getenv("PDBMINE_URL")
PROJECT_DIR = 'casp_da'

# %% [markdown]
# # Score by "in" cluster
#
# - Measure sillhouette score of predicted phi-psi using clusters. Use this as score

# %%
proteins = [
  'T1024', 'T1030', 'T1030-D2', 'T1024-D1', 'T1032-D1', 'T1053-D1', 'T1027-D1', 'T1029-D1',
  'T1025-D1', 'T1028-D1', 'T1030-D1', 'T1053-D2', 'T1057-D1','T1058-D1', 'T1058-D2'
]
da = DihedralAdherence(proteins[0], [4,5,6,7], PDBMINE_URL, PROJECT_DIR, kdews=[1,1,1,1], 
                      mode='ml', weights_file='ml_runs/best_model-kde_16-32_383.pt', device='cpu')
da.load_results_da()
# Out:
# Initializing T1024 ...
# Results already exist
# Casp ID: T1024 	PDB: 6t1z
# Structure exists: 'pdb/pdb6t1z.ent'
# UniProt ID: Q48658

# %%
(~ins.phi_psi_predictions.sil_score.isna()).sum()
# Out:
# 0

# %%
from lib.utils import get_phi_psi_dist, calc_da
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.cluster import KMeans

max_clusters = 7
ins = da
ins.xray_phi_psi['sil_score'] = np.nan
ins.phi_psi_predictions['sil_score'] = np.nan
ins.phi_psi_predictions['cluster'] = np.nan

for i,seq in enumerate(ins.xray_phi_psi.seq_ctxt.unique()):
    print(f'{i}/{len(ins.xray_phi_psi.seq_ctxt.unique())-1}: {seq}')
    if 'X' in seq:
        print(f'\tSkipping {seq} - X in sequence')
        continue
    phi_psi_dist, info = get_phi_psi_dist(ins.queries, seq)
    for i in info:
        print(f'\tWin {i[0]}: {i[1]} - {i[2]} samples')
    
    if phi_psi_dist.shape[0] < 2:
        print(f'\tSkipping {seq} - not enough samples')
        continue # leave as nan

    xray = ins.xray_phi_psi.loc[ins.xray_phi_psi.seq_ctxt == seq][['phi','psi']]
    if xray.shape[0] == 0:
        print(f'No xray seq {seq}')
        continue
    xray = xray.iloc[0].values

    preds = ins.phi_psi_predictions.loc[ins.phi_psi_predictions.seq_ctxt == seq]
    if preds.shape[0] == 0:
        print(f'No preds seq {seq}')
        continue

    max_sil_avg = -1
    one_cluster_wss = -1
    chosen_centroids = None
    for k in range(1, min(phi_psi_dist.shape[0], max_clusters)):
        kmeans = KMeans(n_clusters=k, n_init=10)
        labels = kmeans.fit_predict(phi_psi_dist[['phi', 'psi']])
        wss = kmeans.inertia_
        if k == 1:
            one_cluster_wss = wss
            phi_psi_dist['cluster'] = labels
            continue

        elif k == 2:
            if wss >= one_cluster_wss:
                break

        sil_avg = silhouette_score(phi_psi_dist[['phi', 'psi']], labels)
        if sil_avg > max_sil_avg:
            max_sil_avg = sil_avg
            phi_psi_dist['cluster'] = labels
            chosen_centroids = kmeans.cluster_centers_
    
    if chosen_centroids.shape[0] == 1:
        print(f'\tSkipping {seq} - only one cluster')
        continue

    dists = calc_da(xray, chosen_centroids)
    min_dist = np.min(dists)
    chosen_cluster_label = np.argmin(dists)

    sils = silhouette_samples(np.vstack([phi_psi_dist[['phi', 'psi']].values, xray]), np.append(phi_psi_dist.cluster.values, chosen_cluster_label))
    xray_sil = sils[-1]
    sils = sils[:-1]
    cluster_sils = {}
    for cluster_label in phi_psi_dist.cluster.unique():
        cluster_sils[cluster_label] = sils[phi_psi_dist.cluster.values == cluster_label].mean()

    xray_sil = (xray_sil + 1) / (cluster_sils[chosen_cluster_label] + 1)
    ins.xray_phi_psi.loc[ins.xray_phi_psi.seq_ctxt == seq, 'sil_score'] = xray_sil

    def diff(x1, x2):
        d = np.abs(x1 - x2)
        return np.minimum(d, 360-d)

    cluster_labels = np.argmin(np.linalg.norm(diff(preds[['phi', 'psi']].values[:,np.newaxis], chosen_centroids), axis=2), axis=1)
    preds.loc[:,'cluster'] = cluster_labels
    # calc silhouette score
    for cluster_label in preds.cluster.unique():
        these_preds = preds[preds.cluster == cluster_label]
        distance_to_points = np.linalg.norm(diff(these_preds[['phi', 'psi']].values[:,np.newaxis], phi_psi_dist[['phi', 'psi']].values), axis=2)
        a = distance_to_points[:, phi_psi_dist.cluster == cluster_label].mean(axis=1)
        b = distance_to_points[:, phi_psi_dist.cluster != cluster_label].mean(axis=1)
        sil = (b - a) / np.maximum(a, b)
        sil = (sil + 1) / (cluster_sils[cluster_label] + 1)
        # preds.loc[preds.cluster == cluster_label, 'sil_score'] = sil
        ins.phi_psi_predictions.loc[(ins.phi_psi_predictions.seq_ctxt == seq) & (preds.cluster == cluster_label), 'sil_score'] = sil
    
    # ins.phi_psi_predictions.loc[ins.phi_psi_predictions.seq_ctxt == seq, 'sil_score'] = preds.sil_score
    # print(f'Xray: {xray_sil:.2f}, Preds: {preds.sil_score.mean():.2f}')
    # fig, ax = plt.subplots(1, 1, figsize=(10, 10))
    # sns.scatterplot(phi_psi_dist, x='phi', y='psi', palette='Dark2', hue='cluster', ax=ax)
    # ax.scatter(xray[0], xray[1], marker='X', color='red', s=100, label='Xray')
    # sns.scatterplot(x=preds.phi, y=preds.psi, color='black', s=10, alpha=0.9, hue=preds.sil_score, ax=ax)
    # ax.set_xlim(-180, 180)
    # ax.set_ylim(-180, 180)
# Out:
# 0/372: KEFWNLD
# 	Win 4: FWNL - 388 samples
# 	Win 5: EFWNL - 25 samples
# 	Win 6: EFWNLD - 0 samples
# 	Win 7: KEFWNLD - 0 samples
# 1/372: EFWNLDK
# 	Win 4: WNLD - 291 samples
# 	Win 5: FWNLD - 8 samples
# 	Win 6: FWNLDK - 0 samples
# 	Win 7: EFWNLDK - 0 samples
# 2/372: FWNLDKN
# 	Win 4: NLDK - 2550 samples
# 	Win 5: WNLDK - 42 samples
# 	Win 6: WNLDKN - 0 samples
# 	Win 7: FWNLDKN - 0 samples
# 3/372: WNLDKNL
# 	Win 4: LDKN - 2427 samples
# 	Win 5: NLDKN - 95 samples
# 	Win 6: NLDKNL - 8 samples
# 	Win 7: WNLDKNL - 0 samples
# 4/372: NLDKNLQ
# 	Win 4: DKNL - 3165 samples
# 	Win 5: LDKNL - 132 samples
# 	Win 6: LDKNLQ - 6 samples
# 	Win 7: NLDKNLQ - 0 samples
# 5/372: LDKNLQL
# 	Win 4: KNLQ - 2662 samples
# 	Win 5: DKNLQ - 31 samples
# 	Win 6: DKNLQL - 0 samples
# 	Win 7: LDKNLQL - 0 samples
# 6/372: DKNLQLR
# 	Win 4: NLQL - 1602 samples
# 	Win 5: KNLQL - 152 samples
# 	Win 6: KNLQLR - 24 samples
# 	Win 7: DKNLQLR - 0 samples
# 7/372: KNLQLRL
# 	Win 4: LQLR - 2892 samples
# 	Win 5: NLQLR - 138 samples
# 	Win 6: NLQLRL - 0 samples
# 	Win 7: KNLQLRL - 0 samples
# 8/372: NLQLRLG
# 	Win 4: QLRL - 2633 samples
# 	Win 5: LQLRL - 175 samples
# 	Win 6: LQLRLG - 3 samples
# 	Win 7: NLQLRLG - 0 samples
# 9/372: LQLRLGI
# 	Win 4: LRLG - 4454 samples
# 	Win 5: QLRLG - 52 samples
# 	Win 6: QLRLGI - 2 samples
# 	Win 7: LQLRLGI - 0 samples
# 10/372: QLRLGIV
# 	Win 4: RLGI - 4135 samples
# 	Win 5: LRLGI - 111 samples
# 	Win 6: LRLGIV - 10 samples
# 	Win 7: QLRLGIV - 0 samples
# 11/372: LRLGIVF
# 	Win 4: LGIV - 3126 samples
# 	Win 5: RLGIV - 154 samples
# 	Win 6: RLGIVF - 2 samples
# 	Win 7: LRLGIVF - 0 samples
# 12/372: RLGIVFL
# 	Win 4: GIVF - 1756 samples
# 	Win 5: LGIVF - 75 samples
# 	Win 6: LGIVFL - 0 samples
# 	Win 7: RLGIVFL - 0 samples
# 13/372: LGIVFLG
# 	Win 4: IVFL - 2195 samples
# 	Win 5: GIVFL - 103 samples
# 	Win 6: GIVFLG - 17 samples
# 	Win 7: LGIVFLG - 0 samples
# 14/372: GIVFLGA
# 	Win 4: VFLG - 4127 samples
# 	Win 5: IVFLG - 172 samples
# 	Win 6: IVFLGA - 52 samples
# 	Win 7: GIVFLGA - 0 samples
# 15/372: IVFLGAF
# 	Win 4: FLGA - 3914 samples
# 	Win 5: VFLGA - 153 samples
# 	Win 6: VFLGAF - 6 samples
# 	Win 7: IVFLGAF - 0 samples
# 16/372: VFLGAFS
# 	Win 4: LGAF - 3888 samples
# 	Win 5: FLGAF - 72 samples
# 	Win 6: FLGAFS - 0 samples
# 	Win 7: VFLGAFS - 0 samples
# 17/372: FLGAFSY
# 	Win 4: GAFS - 3149 samples
# 	Win 5: LGAFS - 1176 samples
# 	Win 6: LGAFSY - 3 samples
# 	Win 7: FLGAFSY - 0 samples
# 18/372: LGAFSYG
# 	Win 4: AFSY - 1390 samples
# 	Win 5: GAFSY - 95 samples
# 	Win 6: GAFSYG - 6 samples
# 	Win 7: LGAFSYG - 0 samples
# 19/372: GAFSYGT
# 	Win 4: FSYG - 1625 samples
# 	Win 5: AFSYG - 273 samples
# 	Win 6: AFSYGT - 0 samples
# 	Win 7: GAFSYGT - 0 samples
# 20/372: AFSYGTV
# 	Win 4: SYGT - 1329 samples
# 	Win 5: FSYGT - 27 samples
# 	Win 6: FSYGTV - 0 samples
# 	Win 7: AFSYGTV - 0 samples
# 21/372: FSYGTVF
# 	Win 4: YGTV - 926 samples
# 	Win 5: SYGTV - 38 samples
# 	Win 6: SYGTVF - 0 samples
# 	Win 7: FSYGTVF - 0 samples
# 22/372: SYGTVFS
# 	Win 4: GTVF - 1901 samples
# 	Win 5: YGTVF - 16 samples
# 	Win 6: YGTVFS - 2 samples
# 	Win 7: SYGTVFS - 0 samples
# 23/372: YGTVFSS
# 	Win 4: TVFS - 2915 samples
# 	Win 5: GTVFS - 34 samples
# 	Win 6: GTVFSS - 0 samples
# 	Win 7: YGTVFSS - 0 samples
# 24/372: GTVFSSM
# 	Win 4: VFSS - 2491 samples
# 	Win 5: TVFSS - 185 samples
# 	Win 6: TVFSSM - 0 samples
# 	Win 7: GTVFSSM - 0 samples
# 25/372: TVFSSMT
# 	Win 4: FSSM - 543 samples
# 	Win 5: VFSSM - 40 samples
# 	Win 6: VFSSMT - 0 samples
# 	Win 7: TVFSSMT - 0 samples
# 26/372: VFSSMTI
# 	Win 4: SSMT - 2214 samples
# 	Win 5: FSSMT - 63 samples
# 	Win 6: FSSMTI - 0 samples
# 	Win 7: VFSSMTI - 0 samples
# 27/372: FSSMTIY
# 	Win 4: SMTI - 795 samples
# 	Win 5: SSMTI - 151 samples
# 	Win 6: SSMTIY - 0 samples
# 	Win 7: FSSMTIY - 0 samples
# 28/372: SSMTIYY
# 	Win 4: MTIY - 335 samples
# 	Win 5: SMTIY - 27 samples
# 	Win 6: SMTIYY - 0 samples
# 	Win 7: SSMTIYY - 0 samples
# 29/372: SMTIYYN
# 	Win 4: TIYY - 1943 samples
# 	Win 5: MTIYY - 25 samples
# 	Win 6: MTIYYN - 0 samples
# 	Win 7: SMTIYYN - 0 samples
# 30/372: MTIYYNQ
# 	Win 4: IYYN - 574 samples
# 	Win 5: TIYYN - 31 samples
# 	Win 6: TIYYNQ - 0 samples
# 	Win 7: MTIYYNQ - 0 samples
# 31/372: TIYYNQY
# 	Win 4: YYNQ - 2317 samples
# 	Win 5: IYYNQ - 0 samples
# 	Win 6: IYYNQY - 0 samples
# 	Win 7: TIYYNQY - 0 samples
# 32/372: IYYNQYL
# 	Win 4: YNQY - 367 samples
# 	Win 5: YYNQY - 50 samples
# 	Win 6: YYNQYL - 2 samples
# 	Win 7: IYYNQYL - 0 samples
# 33/372: YYNQYLG
# 	Win 4: NQYL - 1001 samples
# 	Win 5: YNQYL - 15 samples
# 	Win 6: YNQYLG - 2 samples
# 	Win 7: YYNQYLG - 2 samples
# 34/372: YNQYLGS
# 	Win 4: QYLG - 1423 samples
# 	Win 5: NQYLG - 26 samples
# 	Win 6: NQYLGS - 0 samples
# 	Win 7: YNQYLGS - 0 samples
# 35/372: NQYLGSA
# 	Win 4: YLGS - 2335 samples
# 	Win 5: QYLGS - 102 samples
# 	Win 6: QYLGSA - 0 samples
# 	Win 7: NQYLGSA - 0 samples
# 36/372: QYLGSAI
# 	Win 4: LGSA - 7591 samples
# 	Win 5: YLGSA - 127 samples
# 	Win 6: YLGSAI - 0 samples
# 	Win 7: QYLGSAI - 0 samples
# 37/372: YLGSAIT
# 	Win 4: GSAI - 3088 samples
# 	Win 5: LGSAI - 354 samples
# 	Win 6: LGSAIT - 12 samples
# 	Win 7: YLGSAIT - 0 samples
# 38/372: LGSAITG
# 	Win 4: SAIT - 4386 samples
# 	Win 5: GSAIT - 187 samples
# 	Win 6: GSAITG - 13 samples
# 	Win 7: LGSAITG - 0 samples
# 39/372: GSAITGI
# 	Win 4: AITG - 3297 samples
# 	Win 5: SAITG - 240 samples
# 	Win 6: SAITGI - 14 samples
# 	Win 7: GSAITGI - 0 samples
# 40/372: SAITGIL
# 	Win 4: ITGI - 2518 samples
# 	Win 5: AITGI - 216 samples
# 	Win 6: AITGIL - 0 samples
# 	Win 7: SAITGIL - 0 samples
# 41/372: AITGILL
# 	Win 4: TGIL - 2500 samples
# 	Win 5: ITGIL - 256 samples
# 	Win 6: ITGILL - 182 samples
# 	Win 7: AITGILL - 0 samples
# 42/372: ITGILLA
# 	Win 4: GILL - 5638 samples
# 	Win 5: TGILL - 401 samples
# 	Win 6: TGILLA - 26 samples
# 	Win 7: ITGILLA - 0 samples
# 43/372: TGILLAL
# 	Win 4: ILLA - 6771 samples
# 	Win 5: GILLA - 596 samples
# 	Win 6: GILLAL - 4 samples
# 	Win 7: TGILLAL - 0 samples
# 44/372: GILLALS
# 	Win 4: LLAL - 12759 samples
# 	Win 5: ILLAL - 650 samples
# 	Win 6: ILLALS - 10 samples
# 	Win 7: GILLALS - 0 samples
# 45/372: ILLALSA
# 	Win 4: LALS - 5137 samples
# 	Win 5: LLALS - 412 samples
# 	Win 6: LLALSA - 35 samples
# 	Win 7: ILLALSA - 0 samples
# 46/372: LLALSAV
# 	Win 4: ALSA - 7328 samples
# 	Win 5: LALSA - 301 samples
# 	Win 6: LALSAV - 7 samples
# 	Win 7: LLALSAV - 0 samples
# 47/372: LALSAVA
# 	Win 4: LSAV - 5648 samples
# 	Win 5: ALSAV - 391 samples
# 	Win 6: ALSAVA - 55 samples
# 	Win 7: LALSAVA - 0 samples
# 48/372: ALSAVAT
# 	Win 4: SAVA - 5132 samples
# 	Win 5: LSAVA - 298 samples
# 	Win 6: LSAVAT - 72 samples
# 	Win 7: ALSAVAT - 0 samples
# 49/372: LSAVATF
# 	Win 4: AVAT - 5226 samples
# 	Win 5: SAVAT - 265 samples
# 	Win 6: SAVATF - 7 samples
# 	Win 7: LSAVATF - 0 samples
# 50/372: SAVATFV
# 	Win 4: VATF - 2427 samples
# 	Win 5: AVATF - 109 samples
# 	Win 6: AVATFV - 0 samples
# 	Win 7: SAVATFV - 0 samples
# 51/372: AVATFVA
# 	Win 4: ATFV - 1685 samples
# 	Win 5: VATFV - 317 samples
# 	Win 6: VATFVA - 0 samples
# 	Win 7: AVATFVA - 0 samples
# 52/372: VATFVAG
# 	Win 4: TFVA - 2148 samples
# 	Win 5: ATFVA - 48 samples
# 	Win 6: ATFVAG - 6 samples
# 	Win 7: VATFVAG - 0 samples
# 53/372: ATFVAGI
# 	Win 4: FVAG - 2532 samples
# 	Win 5: TFVAG - 107 samples
# 	Win 6: TFVAGI - 0 samples
# 	Win 7: ATFVAGI - 0 samples
# 54/372: TFVAGIL
# 	Win 4: VAGI - 4502 samples
# 	Win 5: FVAGI - 121 samples
# 	Win 6: FVAGIL - 2 samples
# 	Win 7: TFVAGIL - 0 samples
# 55/372: FVAGILA
# 	Win 4: AGIL - 5016 samples
# 	Win 5: VAGIL - 502 samples
# 	Win 6: VAGILA - 41 samples
# 	Win 7: FVAGILA - 0 samples
# 56/372: VAGILAG
# 	Win 4: GILA - 5708 samples
# 	Win 5: AGILA - 579 samples
# 	Win 6: AGILAG - 44 samples
# 	Win 7: VAGILAG - 0 samples
# 57/372: AGILAGF
# 	Win 4: ILAG - 5027 samples
# 	Win 5: GILAG - 559 samples
# 	Win 6: GILAGF - 0 samples
# 	Win 7: AGILAGF - 0 samples
# 58/372: GILAGFF
# 	Win 4: LAGF - 2981 samples
# 	Win 5: ILAGF - 146 samples
# 	Win 6: ILAGFF - 0 samples
# 	Win 7: GILAGFF - 0 samples
# 59/372: ILAGFFA
# 	Win 4: AGFF - 1071 samples
# 	Win 5: LAGFF - 120 samples
# 	Win 6: LAGFFA - 4 samples
# 	Win 7: ILAGFFA - 0 samples
# 60/372: LAGFFAD
# 	Win 4: GFFA - 1432 samples
# 	Win 5: AGFFA - 139 samples
# 	Win 6: AGFFAD - 0 samples
# 	Win 7: LAGFFAD - 0 samples
# 61/372: AGFFADR
# 	Win 4: FFAD - 1583 samples
# 	Win 5: GFFAD - 78 samples
# 	Win 6: GFFADR - 21 samples
# 	Win 7: AGFFADR - 0 samples
# 62/372: GFFADRN
# 	Win 4: FADR - 2287 samples
# 	Win 5: FFADR - 162 samples
# 	Win 6: FFADRN - 24 samples
# 	Win 7: GFFADRN - 0 samples
# 63/372: FFADRNG
# 	Win 4: ADRN - 1114 samples
# 	Win 5: FADRN - 40 samples
# 	Win 6: FADRNG - 0 samples
# 	Win 7: FFADRNG - 0 samples
# 64/372: FADRNGR
# 	Win 4: DRNG - 1758 samples
# 	Win 5: ADRNG - 46 samples
# 	Win 6: ADRNGR - 0 samples
# 	Win 7: FADRNGR - 0 samples
# 65/372: ADRNGRK
# 	Win 4: RNGR - 1086 samples
# 	Win 5: DRNGR - 182 samples
# 	Win 6: DRNGRK - 28 samples
# 	Win 7: ADRNGRK - 0 samples
# 66/372: DRNGRKP
# 	Win 4: NGRK - 1809 samples
# 	Win 5: RNGRK - 128 samples
# 	Win 6: RNGRKP - 0 samples
# 	Win 7: DRNGRKP - 0 samples
# 67/372: RNGRKPV
# 	Win 4: GRKP - 1534 samples
# 	Win 5: NGRKP - 20 samples
# 	Win 6: NGRKPV - 1 samples
# 	Win 7: RNGRKPV - 0 samples
# 68/372: NGRKPVM
# 	Win 4: RKPV - 1487 samples
# 	Win 5: GRKPV - 50 samples
# 	Win 6: GRKPVM - 3 samples
# 	Win 7: NGRKPVM - 0 samples
# 69/372: GRKPVMV
# 	Win 4: KPVM - 1023 samples
# 	Win 5: RKPVM - 6 samples
# 	Win 6: RKPVMV - 0 samples
# 	Win 7: GRKPVMV - 0 samples
# 70/372: RKPVMVF
# 	Win 4: PVMV - 983 samples
# 	Win 5: KPVMV - 108 samples
# 	Win 6: KPVMVF - 2 samples
# 	Win 7: RKPVMVF - 0 samples
# 71/372: KPVMVFG
# 	Win 4: VMVF - 396 samples
# 	Win 5: PVMVF - 23 samples
# 	Win 6: PVMVFG - 0 samples
# 	Win 7: KPVMVFG - 0 samples
# 72/372: PVMVFGT
# 	Win 4: MVFG - 823 samples
# 	Win 5: VMVFG - 37 samples
# 	Win 6: VMVFGT - 7 samples
# 	Win 7: PVMVFGT - 0 samples
# 73/372: VMVFGTI
# 	Win 4: VFGT - 2189 samples
# 	Win 5: MVFGT - 22 samples
# 	Win 6: MVFGTI - 0 samples
# 	Win 7: VMVFGTI - 0 samples
# 74/372: MVFGTII
# 	Win 4: FGTI - 1468 samples
# 	Win 5: VFGTI - 148 samples
# 	Win 6: VFGTII - 0 samples
# 	Win 7: MVFGTII - 0 samples
# 75/372: VFGTIIQ
# 	Win 4: GTII - 2050 samples
# 	Win 5: FGTII - 71 samples
# 	Win 6: FGTIIQ - 0 samples
# 	Win 7: VFGTIIQ - 0 samples
# 76/372: FGTIIQL
# 	Win 4: TIIQ - 583 samples
# 	Win 5: GTIIQ - 8 samples
# 	Win 6: GTIIQL - 7 samples
# 	Win 7: FGTIIQL - 0 samples
# 77/372: GTIIQLL
# 	Win 4: IIQL - 1527 samples
# 	Win 5: TIIQL - 60 samples
# 	Win 6: TIIQLL - 8 samples
# 	Win 7: GTIIQLL - 0 samples
# 78/372: TIIQLLG
# 	Win 4: IQLL - 3467 samples
# 	Win 5: IIQLL - 100 samples
# 	Win 6: IIQLLG - 2 samples
# 	Win 7: TIIQLLG - 0 samples
# 79/372: IIQLLGA
# 	Win 4: QLLG - 4914 samples
# 	Win 5: IQLLG - 189 samples
# 	Win 6: IQLLGA - 30 samples
# 	Win 7: IIQLLGA - 0 samples
# 80/372: IQLLGAA
# 	Win 4: LLGA - 10582 samples
# 	Win 5: QLLGA - 317 samples
# 	Win 6: QLLGAA - 28 samples
# 	Win 7: IQLLGAA - 0 samples
# 81/372: QLLGAAL
# 	Win 4: LGAA - 7680 samples
# 	Win 5: LLGAA - 970 samples
# 	Win 6: LLGAAL - 92 samples
# 	Win 7: QLLGAAL - 0 samples
# 82/372: LLGAALA
# 	Win 4: GAAL - 8938 samples
# 	Win 5: LGAAL - 600 samples
# 	Win 6: LGAALA - 55 samples
# 	Win 7: LLGAALA - 0 samples
# 83/372: LGAALAI
# 	Win 4: AALA - 16761 samples
# 	Win 5: GAALA - 1046 samples
# 	Win 6: GAALAI - 70 samples
# 	Win 7: LGAALAI - 13 samples
# 84/372: GAALAIA
# 	Win 4: ALAI - 5830 samples
# 	Win 5: AALAI - 604 samples
# 	Win 6: AALAIA - 72 samples
# 	Win 7: GAALAIA - 0 samples
# 85/372: AALAIAS
# 	Win 4: LAIA - 6148 samples
# 	Win 5: ALAIA - 783 samples
# 	Win 6: ALAIAS - 23 samples
# 	Win 7: AALAIAS - 3 samples
# 86/372: ALAIASN
# 	Win 4: AIAS - 5432 samples
# 	Win 5: LAIAS - 253 samples
# 	Win 6: LAIASN - 0 samples
# 	Win 7: ALAIASN - 0 samples
# 87/372: LAIASNL
# 	Win 4: IASN - 3346 samples
# 	Win 5: AIASN - 826 samples
# 	Win 6: AIASNL - 4 samples
# 	Win 7: LAIASNL - 0 samples
# 88/372: AIASNLP
# 	Win 4: ASNL - 3529 samples
# 	Win 5: IASNL - 117 samples
# 	Win 6: IASNLP - 9 samples
# 	Win 7: AIASNLP - 0 samples
# 89/372: IASNLPG
# 	Win 4: SNLP - 2100 samples
# 	Win 5: ASNLP - 141 samples
# 	Win 6: ASNLPG - 0 samples
# 	Win 7: IASNLPG - 0 samples
# 90/372: ASNLPGH
# 	Win 4: NLPG - 3095 samples
# 	Win 5: SNLPG - 76 samples
# 	Win 6: SNLPGH - 0 samples
# 	Win 7: ASNLPGH - 0 samples
# 91/372: SNLPGHV
# 	Win 4: LPGH - 1145 samples
# 	Win 5: NLPGH - 28 samples
# 	Win 6: NLPGHV - 0 samples
# 	Win 7: SNLPGHV - 0 samples
# 92/372: NLPGHVN
# 	Win 4: PGHV - 925 samples
# 	Win 5: LPGHV - 107 samples
# 	Win 6: LPGHVN - 0 samples
# 	Win 7: NLPGHVN - 0 samples
# 93/372: LPGHVNP
# 	Win 4: GHVN - 720 samples
# 	Win 5: PGHVN - 50 samples
# 	Win 6: PGHVNP - 0 samples
# 	Win 7: LPGHVNP - 0 samples
# 94/372: PGHVNPW
# 	Win 4: HVNP - 586 samples
# 	Win 5: GHVNP - 28 samples
# 	Win 6: GHVNPW - 0 samples
# 	Win 7: PGHVNPW - 0 samples
# 95/372: GHVNPWS
# 	Win 4: VNPW - 153 samples
# 	Win 5: HVNPW - 0 samples
# 	Win 6: HVNPWS - 0 samples
# 	Win 7: GHVNPWS - 0 samples
# 96/372: HVNPWST
# 	Win 4: NPWS - 650 samples
# 	Win 5: VNPWS - 22 samples
# 	Win 6: VNPWST - 0 samples
# 	Win 7: HVNPWST - 0 samples
# 97/372: VNPWSTF
# 	Win 4: PWST - 199 samples
# 	Win 5: NPWST - 1 samples
# 	Win 6: NPWSTF - 0 samples
# 	Win 7: VNPWSTF - 0 samples
# 98/372: NPWSTFI
# 	Win 4: WSTF - 435 samples
# 	Win 5: PWSTF - 76 samples
# 	Win 6: PWSTFI - 0 samples
# 	Win 7: NPWSTFI - 0 samples
# 99/372: PWSTFIA
# 	Win 4: STFI - 2424 samples
# 	Win 5: WSTFI - 5 samples
# 	Win 6: WSTFIA - 0 samples
# 	Win 7: PWSTFIA - 0 samples
# 100/372: WSTFIAF
# 	Win 4: TFIA - 1504 samples
# 	Win 5: STFIA - 42 samples
# 	Win 6: STFIAF - 4 samples
# 	Win 7: WSTFIAF - 0 samples
# 101/372: STFIAFL
# 	Win 4: FIAF - 772 samples
# 	Win 5: TFIAF - 51 samples
# 	Win 6: TFIAFL - 0 samples
# 	Win 7: STFIAFL - 0 samples
# 102/372: TFIAFLL
# 	Win 4: IAFL - 2317 samples
# 	Win 5: FIAFL - 187 samples
# 	Win 6: FIAFLL - 0 samples
# 	Win 7: TFIAFLL - 0 samples
# 103/372: FIAFLLI
# 	Win 4: AFLL - 4444 samples
# 	Win 5: IAFLL - 268 samples
# 	Win 6: IAFLLI - 4 samples
# 	Win 7: FIAFLLI - 0 samples
# 104/372: IAFLLIS
# 	Win 4: FLLI - 2343 samples
# 	Win 5: AFLLI - 292 samples
# 	Win 6: AFLLIS - 12 samples
# 	Win 7: IAFLLIS - 0 samples
# 105/372: AFLLISF
# 	Win 4: LLIS - 7345 samples
# 	Win 5: FLLIS - 223 samples
# 	Win 6: FLLISF - 0 samples
# 	Win 7: AFLLISF - 0 samples
# 106/372: FLLISFG
# 	Win 4: LISF - 1769 samples
# 	Win 5: LLISF - 81 samples
# 	Win 6: LLISFG - 6 samples
# 	Win 7: FLLISFG - 0 samples
# 107/372: LLISFGY
# 	Win 4: ISFG - 1771 samples
# 	Win 5: LISFG - 454 samples
# 	Win 6: LISFGY - 0 samples
# 	Win 7: LLISFGY - 0 samples
# 108/372: LISFGYN
# 	Win 4: SFGY - 1495 samples
# 	Win 5: ISFGY - 60 samples
# 	Win 6: ISFGYN - 0 samples
# 	Win 7: LISFGYN - 0 samples
# 109/372: ISFGYNF
# 	Win 4: FGYN - 1055 samples
# 	Win 5: SFGYN - 70 samples
# 	Win 6: SFGYNF - 0 samples
# 	Win 7: ISFGYNF - 0 samples
# 110/372: SFGYNFV
# 	Win 4: GYNF - 1472 samples
# 	Win 5: FGYNF - 69 samples
# 	Win 6: FGYNFV - 0 samples
# 	Win 7: SFGYNFV - 0 samples
# 111/372: FGYNFVI
# 	Win 4: YNFV - 540 samples
# 	Win 5: GYNFV - 24 samples
# 	Win 6: GYNFVI - 0 samples
# 	Win 7: FGYNFVI - 0 samples
# 112/372: GYNFVIT
# 	Win 4: NFVI - 854 samples
# 	Win 5: YNFVI - 33 samples
# 	Win 6: YNFVIT - 0 samples
# 	Win 7: GYNFVIT - 0 samples
# 113/372: YNFVITA
# 	Win 4: FVIT - 1364 samples
# 	Win 5: NFVIT - 87 samples
# 	Win 6: NFVITA - 2 samples
# 	Win 7: YNFVITA - 0 samples
# 114/372: NFVITAG
# 	Win 4: VITA - 3346 samples
# 	Win 5: FVITA - 76 samples
# 	Win 6: FVITAG - 8 samples
# 	Win 7: NFVITAG - 0 samples
# 115/372: FVITAGN
# 	Win 4: ITAG - 4530 samples
# 	Win 5: VITAG - 666 samples
# 	Win 6: VITAGN - 0 samples
# 	Win 7: FVITAGN - 0 samples
# 116/372: VITAGNA
# 	Win 4: TAGN - 3209 samples
# 	Win 5: ITAGN - 183 samples
# 	Win 6: ITAGNA - 30 samples
# 	Win 7: VITAGNA - 0 samples
# 117/372: ITAGNAM
# 	Win 4: AGNA - 5122 samples
# 	Win 5: TAGNA - 468 samples
# 	Win 6: TAGNAM - 14 samples
# 	Win 7: ITAGNAM - 0 samples
# 118/372: TAGNAMI
# 	Win 4: GNAM - 921 samples
# 	Win 5: AGNAM - 188 samples
# 	Win 6: AGNAMI - 97 samples
# 	Win 7: TAGNAMI - 0 samples
# 119/372: AGNAMII
# 	Win 4: NAMI - 706 samples
# 	Win 5: GNAMI - 109 samples
# 	Win 6: GNAMII - 0 samples
# 	Win 7: AGNAMII - 0 samples
# 120/372: GNAMIID
# 	Win 4: AMII - 842 samples
# 	Win 5: NAMII - 57 samples
# 	Win 6: NAMIID - 0 samples
# 	Win 7: GNAMIID - 0 samples
# 121/372: NAMIIDA
# 	Win 4: MIID - 796 samples
# 	Win 5: AMIID - 75 samples
# 	Win 6: AMIIDA - 12 samples
# 	Win 7: NAMIIDA - 0 samples
# 122/372: AMIIDAS
# 	Win 4: IIDA - 2691 samples
# 	Win 5: MIIDA - 125 samples
# 	Win 6: MIIDAS - 40 samples
# 	Win 7: AMIIDAS - 0 samples
# 123/372: MIIDASN
# 	Win 4: IDAS - 2556 samples
# 	Win 5: IIDAS - 111 samples
# 	Win 6: IIDASN - 2 samples
# 	Win 7: MIIDASN - 0 samples
# 124/372: IIDASNA
# 	Win 4: DASN - 1610 samples
# 	Win 5: IDASN - 172 samples
# 	Win 6: IDASNA - 0 samples
# 	Win 7: IIDASNA - 0 samples
# 125/372: IDASNAE
# 	Win 4: ASNA - 1689 samples
# 	Win 5: DASNA - 62 samples
# 	Win 6: DASNAE - 2 samples
# 	Win 7: IDASNAE - 0 samples
# 126/372: DASNAEN
# 	Win 4: SNAE - 1424 samples
# 	Win 5: ASNAE - 207 samples
# 	Win 6: ASNAEN - 8 samples
# 	Win 7: DASNAEN - 0 samples
# 127/372: ASNAENR
# 	Win 4: NAEN - 1226 samples
# 	Win 5: SNAEN - 33 samples
# 	Win 6: SNAENR - 0 samples
# 	Win 7: ASNAENR - 0 samples
# 128/372: SNAENRK
# 	Win 4: AENR - 2467 samples
# 	Win 5: NAENR - 13 samples
# 	Win 6: NAENRK - 0 samples
# 	Win 7: SNAENRK - 0 samples
# 129/372: NAENRKV
# 	Win 4: ENRK - 1059 samples
# 	Win 5: AENRK - 164 samples
# 	Win 6: AENRKV - 0 samples
# 	Win 7: NAENRKV - 0 samples
# 130/372: AENRKVV
# 	Win 4: NRKV - 1386 samples
# 	Win 5: ENRKV - 89 samples
# 	Win 6: ENRKVV - 2 samples
# 	Win 7: AENRKVV - 0 samples
# 131/372: ENRKVVF
# 	Win 4: RKVV - 3568 samples
# 	Win 5: NRKVV - 50 samples
# 	Win 6: NRKVVF - 0 samples
# 	Win 7: ENRKVVF - 0 samples
# 132/372: NRKVVFM
# 	Win 4: KVVF - 1988 samples
# 	Win 5: RKVVF - 79 samples
# 	Win 6: RKVVFM - 0 samples
# 	Win 7: NRKVVFM - 0 samples
# 133/372: RKVVFML
# 	Win 4: VVFM - 346 samples
# 	Win 5: KVVFM - 47 samples
# 	Win 6: KVVFML - 0 samples
# 	Win 7: RKVVFML - 0 samples
# 134/372: KVVFMLD
# 	Win 4: VFML - 893 samples
# 	Win 5: VVFML - 28 samples
# 	Win 6: VVFMLD - 0 samples
# 	Win 7: KVVFMLD - 0 samples
# 135/372: VVFMLDY
# 	Win 4: FMLD - 877 samples
# 	Win 5: VFMLD - 0 samples
# 	Win 6: VFMLDY - 0 samples
# 	Win 7: VVFMLDY - 0 samples
# 136/372: VFMLDYW
# 	Win 4: MLDY - 695 samples
# 	Win 5: FMLDY - 32 samples
# 	Win 6: FMLDYW - 0 samples
# 	Win 7: VFMLDYW - 0 samples
# 137/372: FMLDYWA
# 	Win 4: LDYW - 2254 samples
# 	Win 5: MLDYW - 10 samples
# 	Win 6: MLDYWA - 9 samples
# 	Win 7: FMLDYWA - 0 samples
# 138/372: MLDYWAQ
# 	Win 4: DYWA - 194 samples
# 	Win 5: LDYWA - 36 samples
# 	Win 6: LDYWAQ - 1 samples
# 	Win 7: MLDYWAQ - 0 samples
# 139/372: LDYWAQN
# 	Win 4: YWAQ - 1072 samples
# 	Win 5: DYWAQ - 7 samples
# 	Win 6: DYWAQN - 0 samples
# 	Win 7: LDYWAQN - 0 samples
# 140/372: DYWAQNL
# 	Win 4: WAQN - 235 samples
# 	Win 5: YWAQN - 0 samples
# 	Win 6: YWAQNL - 0 samples
# 	Win 7: DYWAQNL - 0 samples
# 141/372: YWAQNLS
# 	Win 4: AQNL - 2210 samples
# 	Win 5: WAQNL - 0 samples
# 	Win 6: WAQNLS - 0 samples
# 	Win 7: YWAQNLS - 0 samples
# 142/372: WAQNLSV
# 	Win 4: QNLS - 2468 samples
# 	Win 5: AQNLS - 124 samples
# 	Win 6: AQNLSV - 0 samples
# 	Win 7: WAQNLSV - 0 samples
# 143/372: AQNLSVI
# 	Win 4: NLSV - 3270 samples
# 	Win 5: QNLSV - 153 samples
# 	Win 6: QNLSVI - 9 samples
# 	Win 7: AQNLSVI - 0 samples
# 144/372: QNLSVIL
# 	Win 4: LSVI - 3891 samples
# 	Win 5: NLSVI - 335 samples
# 	Win 6: NLSVIL - 4 samples
# 	Win 7: QNLSVIL - 0 samples
# 145/372: NLSVILG
# 	Win 4: SVIL - 3899 samples
# 	Win 5: LSVIL - 315 samples
# 	Win 6: LSVILG - 0 samples
# 	Win 7: NLSVILG - 0 samples
# 146/372: LSVILGA
# 	Win 4: VILG - 5816 samples
# 	Win 5: SVILG - 109 samples
# 	Win 6: SVILGA - 9 samples
# 	Win 7: LSVILGA - 0 samples
# 147/372: SVILGAA
# 	Win 4: ILGA - 4860 samples
# 	Win 5: VILGA - 963 samples
# 	Win 6: VILGAA - 19 samples
# 	Win 7: SVILGAA - 0 samples
# 148/372: VILGAAL
# 	Win 4: LGAA - 7680 samples
# 	Win 5: ILGAA - 209 samples
# 	Win 6: ILGAAL - 34 samples
# 	Win 7: VILGAAL - 0 samples
# 149/372: ILGAALG
# 	Win 4: GAAL - 8938 samples
# 	Win 5: LGAAL - 600 samples
# 	Win 6: LGAALG - 33 samples
# 	Win 7: ILGAALG - 11 samples
# 150/372: LGAALGA
# 	Win 4: AALG - 15505 samples
# 	Win 5: GAALG - 494 samples
# 	Win 6: GAALGA - 24 samples
# 	Win 7: LGAALGA - 11 samples
# 151/372: GAALGAW
# 	Win 4: ALGA - 8804 samples
# 	Win 5: AALGA - 775 samples
# 	Win 6: AALGAW - 4 samples
# 	Win 7: GAALGAW - 0 samples
# 152/372: AALGAWL
# 	Win 4: LGAW - 647 samples
# 	Win 5: ALGAW - 69 samples
# 	Win 6: ALGAWL - 20 samples
# 	Win 7: AALGAWL - 0 samples
# 153/372: ALGAWLF
# 	Win 4: GAWL - 897 samples
# 	Win 5: LGAWL - 57 samples
# 	Win 6: LGAWLF - 0 samples
# 	Win 7: ALGAWLF - 0 samples
# 154/372: LGAWLFR
# 	Win 4: AWLF - 481 samples
# 	Win 5: GAWLF - 42 samples
# 	Win 6: GAWLFR - 0 samples
# 	Win 7: LGAWLFR - 0 samples
# 155/372: GAWLFRP
# 	Win 4: WLFR - 531 samples
# 	Win 5: AWLFR - 3 samples
# 	Win 6: AWLFRP - 0 samples
# 	Win 7: GAWLFRP - 0 samples
# 156/372: AWLFRPA
# 	Win 4: LFRP - 1720 samples
# 	Win 5: WLFRP - 2 samples
# 	Win 6: WLFRPA - 0 samples
# 	Win 7: AWLFRPA - 0 samples
# 157/372: WLFRPAF
# 	Win 4: FRPA - 924 samples
# 	Win 5: LFRPA - 38 samples
# 	Win 6: LFRPAF - 0 samples
# 	Win 7: WLFRPAF - 0 samples
# 158/372: LFRPAFE
# 	Win 4: RPAF - 1143 samples
# 	Win 5: FRPAF - 25 samples
# 	Win 6: FRPAFE - 0 samples
# 	Win 7: LFRPAFE - 0 samples
# 159/372: FRPAFEA
# 	Win 4: PAFE - 1480 samples
# 	Win 5: RPAFE - 84 samples
# 	Win 6: RPAFEA - 6 samples
# 	Win 7: FRPAFEA - 0 samples
# 160/372: RPAFEAL
# 	Win 4: AFEA - 2924 samples
# 	Win 5: PAFEA - 79 samples
# 	Win 6: PAFEAL - 7 samples
# 	Win 7: RPAFEAL - 0 samples
# 161/372: PAFEALL
# 	Win 4: FEAL - 3437 samples
# 	Win 5: AFEAL - 252 samples
# 	Win 6: AFEALL - 35 samples
# 	Win 7: PAFEALL - 0 samples
# 162/372: AFEALLV
# 	Win 4: EALL - 10518 samples
# 	Win 5: FEALL - 376 samples
# 	Win 6: FEALLV - 89 samples
# 	Win 7: AFEALLV - 0 samples
# 163/372: FEALLVI
# 	Win 4: ALLV - 6431 samples
# 	Win 5: EALLV - 376 samples
# 	Win 6: EALLVI - 24 samples
# 	Win 7: FEALLVI - 0 samples
# 164/372: EALLVIL
# 	Win 4: LLVI - 3440 samples
# 	Win 5: ALLVI - 258 samples
# 	Win 6: ALLVIL - 37 samples
# 	Win 7: EALLVIL - 0 samples
# 165/372: ALLVILL
# 	Win 4: LVIL - 3377 samples
# 	Win 5: LLVIL - 423 samples
# 	Win 6: LLVILL - 28 samples
# 	Win 7: ALLVILL - 0 samples
# 166/372: LLVILLL
# 	Win 4: VILL - 4018 samples
# 	Win 5: LVILL - 218 samples
# 	Win 6: LVILLL - 49 samples
# 	Win 7: LLVILLL - 20 samples
# 167/372: LVILLLT
# 	Win 4: ILLL - 6216 samples
# 	Win 5: VILLL - 261 samples
# 	Win 6: VILLLT - 82 samples
# 	Win 7: LVILLLT - 0 samples
# 168/372: VILLLTV
# 	Win 4: LLLT - 6294 samples
# 	Win 5: ILLLT - 381 samples
# 	Win 6: ILLLTV - 50 samples
# 	Win 7: VILLLTV - 49 samples
# 169/372: ILLLTVL
# 	Win 4: LLTV - 4181 samples
# 	Win 5: LLLTV - 448 samples
# 	Win 6: LLLTVL - 65 samples
# 	Win 7: ILLLTVL - 1 samples
# 170/372: LLLTVLV
# 	Win 4: LTVL - 10194 samples
# 	Win 5: LLTVL - 622 samples
# 	Win 6: LLTVLV - 58 samples
# 	Win 7: LLLTVLV - 0 samples
# 171/372: LLTVLVS
# 	Win 4: TVLV - 5978 samples
# 	Win 5: LTVLV - 478 samples
# 	Win 6: LTVLVS - 29 samples
# 	Win 7: LLTVLVS - 24 samples
# 172/372: LTVLVSF
# 	Win 4: VLVS - 5219 samples
# 	Win 5: TVLVS - 340 samples
# 	Win 6: TVLVSF - 30 samples
# 	Win 7: LTVLVSF - 24 samples
# 173/372: TVLVSFF
# 	Win 4: LVSF - 2598 samples
# 	Win 5: VLVSF - 146 samples
# 	Win 6: VLVSFF - 0 samples
# 	Win 7: TVLVSFF - 0 samples
# 174/372: VLVSFFL
# 	Win 4: VSFF - 1513 samples
# 	Win 5: LVSFF - 40 samples
# 	Win 6: LVSFFL - 0 samples
# 	Win 7: VLVSFFL - 0 samples
# 175/372: LVSFFLT
# 	Win 4: SFFL - 1766 samples
# 	Win 5: VSFFL - 123 samples
# 	Win 6: VSFFLT - 6 samples
# 	Win 7: LVSFFLT - 0 samples
# 176/372: VSFFLTT
# 	Win 4: FFLT - 1224 samples
# 	Win 5: SFFLT - 74 samples
# 	Win 6: SFFLTT - 0 samples
# 	Win 7: VSFFLTT - 0 samples
# 177/372: SFFLTTF
# 	Win 4: FLTT - 1769 samples
# 	Win 5: FFLTT - 111 samples
# 	Win 6: FFLTTF - 0 samples
# 	Win 7: SFFLTTF - 0 samples
# 178/372: FFLTTFV
# 	Win 4: LTTF - 2318 samples
# 	Win 5: FLTTF - 134 samples
# 	Win 6: FLTTFV - 0 samples
# 	Win 7: FFLTTFV - 0 samples
# 179/372: FLTTFVM
# 	Win 4: TTFV - 1579 samples
# 	Win 5: LTTFV - 134 samples
# 	Win 6: LTTFVM - 2 samples
# 	Win 7: FLTTFVM - 0 samples
# 180/372: LTTFVMT
# 	Win 4: TFVM - 422 samples
# 	Win 5: TTFVM - 2 samples
# 	Win 6: TTFVMT - 0 samples
# 	Win 7: LTTFVMT - 0 samples
# 181/372: TTFVMTE
# 	Win 4: FVMT - 297 samples
# 	Win 5: TFVMT - 0 samples
# 	Win 6: TFVMTE - 0 samples
# 	Win 7: TTFVMTE - 0 samples
# 182/372: TFVMTET
# 	Win 4: VMTE - 661 samples
# 	Win 5: FVMTE - 11 samples
# 	Win 6: FVMTET - 0 samples
# 	Win 7: TFVMTET - 0 samples
# 183/372: FVMTETF
# 	Win 4: MTET - 1588 samples
# 	Win 5: VMTET - 1 samples
# 	Win 6: VMTETF - 0 samples
# 	Win 7: FVMTETF - 0 samples
# 184/372: VMTETFK
# 	Win 4: TETF - 1926 samples
# 	Win 5: MTETF - 31 samples
# 	Win 6: MTETFK - 2 samples
# 	Win 7: VMTETFK - 0 samples
# 185/372: MTETFKP
# 	Win 4: ETFK - 1976 samples
# 	Win 5: TETFK - 20 samples
# 	Win 6: TETFKP - 0 samples
# 	Win 7: MTETFKP - 0 samples
# 186/372: TETFKPT
# 	Win 4: TFKP - 1100 samples
# 	Win 5: ETFKP - 22 samples
# 	Win 6: ETFKPT - 0 samples
# 	Win 7: TETFKPT - 0 samples
# 187/372: NIFQAYK
# 	Win 4: FQAY - 430 samples
# 	Win 5: IFQAY - 7 samples
# 	Win 6: IFQAYK - 0 samples
# 	Win 7: NIFQAYK - 0 samples
# 188/372: IFQAYKT
# 	Win 4: QAYK - 1019 samples
# 	Win 5: FQAYK - 18 samples
# 	Win 6: FQAYKT - 0 samples
# 	Win 7: IFQAYKT - 0 samples
# 189/372: FQAYKTV
# 	Win 4: AYKT - 1561 samples
# 	Win 5: QAYKT - 51 samples
# 	Win 6: QAYKTV - 0 samples
# 	Win 7: FQAYKTV - 0 samples
# 190/372: QAYKTVL
# 	Win 4: YKTV - 800 samples
# 	Win 5: AYKTV - 74 samples
# 	Win 6: AYKTVL - 17 samples
# 	Win 7: QAYKTVL - 0 samples
# 191/372: AYKTVLQ
# 	Win 4: KTVL - 4197 samples
# 	Win 5: YKTVL - 52 samples
# 	Win 6: YKTVLQ - 0 samples
# 	Win 7: AYKTVLQ - 0 samples
# 192/372: YKTVLQD
# 	Win 4: TVLQ - 2269 samples
# 	Win 5: KTVLQ - 262 samples
# 	Win 6: KTVLQD - 2 samples
# 	Win 7: YKTVLQD - 0 samples
# 193/372: KTVLQDK
# 	Win 4: VLQD - 2796 samples
# 	Win 5: TVLQD - 91 samples
# 	Win 6: TVLQDK - 0 samples
# 	Win 7: KTVLQDK - 0 samples
# 194/372: TVLQDKT
# 	Win 4: LQDK - 3090 samples
# 	Win 5: VLQDK - 218 samples
# 	Win 6: VLQDKT - 0 samples
# 	Win 7: TVLQDKT - 0 samples
# 195/372: VLQDKTY
# 	Win 4: QDKT - 1119 samples
# 	Win 5: LQDKT - 194 samples
# 	Win 6: LQDKTY - 0 samples
# 	Win 7: VLQDKTY - 0 samples
# 196/372: LQDKTYM
# 	Win 4: DKTY - 1162 samples
# 	Win 5: QDKTY - 61 samples
# 	Win 6: QDKTYM - 0 samples
# 	Win 7: LQDKTYM - 0 samples
# 197/372: QDKTYMI
# 	Win 4: KTYM - 324 samples
# 	Win 5: DKTYM - 21 samples
# 	Win 6: DKTYMI - 0 samples
# 	Win 7: QDKTYMI - 0 samples
# 198/372: DKTYMIF
# 	Win 4: TYMI - 299 samples
# 	Win 5: KTYMI - 37 samples
# 	Win 6: KTYMIF - 35 samples
# 	Win 7: DKTYMIF - 0 samples
# 199/372: KTYMIFM
# 	Win 4: YMIF - 207 samples
# 	Win 5: TYMIF - 35 samples
# 	Win 6: TYMIFM - 0 samples
# 	Win 7: KTYMIFM - 0 samples
# 200/372: TYMIFMG
# 	Win 4: MIFM - 79 samples
# 	Win 5: YMIFM - 0 samples
# 	Win 6: YMIFMG - 0 samples
# 	Win 7: TYMIFMG - 0 samples
# 201/372: YMIFMGA
# 	Win 4: IFMG - 442 samples
# 	Win 5: MIFMG - 11 samples
# 	Win 6: MIFMGA - 0 samples
# 	Win 7: YMIFMGA - 0 samples
# 202/372: MIFMGAN
# 	Win 4: FMGA - 727 samples
# 	Win 5: IFMGA - 30 samples
# 	Win 6: IFMGAN - 3 samples
# 	Win 7: MIFMGAN - 0 samples
# 203/372: IFMGANI
# 	Win 4: MGAN - 1063 samples
# 	Win 5: FMGAN - 3 samples
# 	Win 6: FMGANI - 0 samples
# 	Win 7: IFMGANI - 0 samples
# 204/372: FMGANIA
# 	Win 4: GANI - 2426 samples
# 	Win 5: MGANI - 95 samples
# 	Win 6: MGANIA - 57 samples
# 	Win 7: FMGANIA - 0 samples
# 205/372: MGANIAT
# 	Win 4: ANIA - 3003 samples
# 	Win 5: GANIA - 273 samples
# 	Win 6: GANIAT - 42 samples
# 	Win 7: MGANIAT - 36 samples
# 206/372: GANIATT
# 	Win 4: NIAT - 1921 samples
# 	Win 5: ANIAT - 153 samples
# 	Win 6: ANIATT - 2 samples
# 	Win 7: GANIATT - 0 samples
# 207/372: ANIATTF
# 	Win 4: IATT - 1644 samples
# 	Win 5: NIATT - 48 samples
# 	Win 6: NIATTF - 8 samples
# 	Win 7: ANIATTF - 0 samples
# 208/372: NIATTFI
# 	Win 4: ATTF - 2503 samples
# 	Win 5: IATTF - 51 samples
# 	Win 6: IATTFI - 2 samples
# 	Win 7: NIATTFI - 0 samples
# 209/372: IATTFII
# 	Win 4: TTFI - 696 samples
# 	Win 5: ATTFI - 31 samples
# 	Win 6: ATTFII - 0 samples
# 	Win 7: IATTFII - 0 samples
# 210/372: ATTFIIM
# 	Win 4: TFII - 1101 samples
# 	Win 5: TTFII - 36 samples
# 	Win 6: TTFIIM - 0 samples
# 	Win 7: ATTFIIM - 0 samples
# 211/372: TTFIIMQ
# 	Win 4: FIIM - 265 samples
# 	Win 5: TFIIM - 1 samples
# 	Win 6: TFIIMQ - 0 samples
# 	Win 7: TTFIIMQ - 0 samples
# 212/372: TFIIMQF
# 	Win 4: IIMQ - 167 samples
# 	Win 5: FIIMQ - 0 samples
# 	Win 6: FIIMQF - 0 samples
# 	Win 7: TFIIMQF - 0 samples
# 213/372: FIIMQFD
# 	Win 4: IMQF - 271 samples
# 	Win 5: IIMQF - 2 samples
# 	Win 6: IIMQFD - 0 samples
# 	Win 7: FIIMQFD - 0 samples
# 214/372: IIMQFDN
# 	Win 4: MQFD - 1261 samples
# 	Win 5: IMQFD - 0 samples
# 	Win 6: IMQFDN - 0 samples
# 	Win 7: IIMQFDN - 0 samples
# 215/372: IMQFDNF
# 	Win 4: QFDN - 436 samples
# 	Win 5: MQFDN - 5 samples
# 	Win 6: MQFDNF - 0 samples
# 	Win 7: IMQFDNF - 0 samples
# 216/372: MQFDNFL
# 	Win 4: FDNF - 754 samples
# 	Win 5: QFDNF - 20 samples
# 	Win 6: QFDNFL - 0 samples
# 	Win 7: MQFDNFL - 0 samples
# 217/372: QFDNFLP
# 	Win 4: DNFL - 2110 samples
# 	Win 5: FDNFL - 76 samples
# 	Win 6: FDNFLP - 13 samples
# 	Win 7: QFDNFLP - 0 samples
# 218/372: FDNFLPV
# 	Win 4: NFLP - 756 samples
# 	Win 5: DNFLP - 16 samples
# 	Win 6: DNFLPV - 0 samples
# 	Win 7: FDNFLPV - 0 samples
# 219/372: DNFLPVH
# 	Win 4: FLPV - 1715 samples
# 	Win 5: NFLPV - 82 samples
# 	Win 6: NFLPVH - 0 samples
# 	Win 7: DNFLPVH - 0 samples
# 220/372: NFLPVHL
# 	Win 4: LPVH - 1469 samples
# 	Win 5: FLPVH - 31 samples
# 	Win 6: FLPVHL - 0 samples
# 	Win 7: NFLPVHL - 0 samples
# 221/372: FLPVHLS
# 	Win 4: PVHL - 1794 samples
# 	Win 5: LPVHL - 311 samples
# 	Win 6: LPVHLS - 7 samples
# 	Win 7: FLPVHLS - 0 samples
# 222/372: LPVHLSN
# 	Win 4: VHLS - 1808 samples
# 	Win 5: PVHLS - 202 samples
# 	Win 6: PVHLSN - 0 samples
# 	Win 7: LPVHLSN - 0 samples
# 223/372: PVHLSNS
# 	Win 4: HLSN - 1384 samples
# 	Win 5: VHLSN - 265 samples
# 	Win 6: VHLSNS - 0 samples
# 	Win 7: PVHLSNS - 0 samples
# 224/372: VHLSNSF
# 	Win 4: LSNS - 3064 samples
# 	Win 5: HLSNS - 13 samples
# 	Win 6: HLSNSF - 0 samples
# 	Win 7: VHLSNSF - 0 samples
# 225/372: HLSNSFK
# 	Win 4: SNSF - 1063 samples
# 	Win 5: LSNSF - 249 samples
# 	Win 6: LSNSFK - 0 samples
# 	Win 7: HLSNSFK - 0 samples
# 226/372: LSNSFKT
# 	Win 4: NSFK - 900 samples
# 	Win 5: SNSFK - 39 samples
# 	Win 6: SNSFKT - 0 samples
# 	Win 7: LSNSFKT - 0 samples
# 227/372: SNSFKTI
# 	Win 4: SFKT - 1249 samples
# 	Win 5: NSFKT - 117 samples
# 	Win 6: NSFKTI - 5 samples
# 	Win 7: SNSFKTI - 0 samples
# 228/372: NSFKTIT
# 	Win 4: FKTI - 1403 samples
# 	Win 5: SFKTI - 30 samples
# 	Win 6: SFKTIT - 4 samples
# 	Win 7: NSFKTIT - 0 samples
# 229/372: YGQRMLT
# 	Win 4: QRML - 1247 samples
# 	Win 5: GQRML - 40 samples
# 	Win 6: GQRMLT - 0 samples
# 	Win 7: YGQRMLT - 0 samples
# 230/372: GQRMLTI
# 	Win 4: RMLT - 622 samples
# 	Win 5: QRMLT - 27 samples
# 	Win 6: QRMLTI - 0 samples
# 	Win 7: GQRMLTI - 0 samples
# 231/372: QRMLTIY
# 	Win 4: MLTI - 795 samples
# 	Win 5: RMLTI - 16 samples
# 	Win 6: RMLTIY - 0 samples
# 	Win 7: QRMLTIY - 0 samples
# 232/372: RMLTIYL
# 	Win 4: LTIY - 1076 samples
# 	Win 5: MLTIY - 27 samples
# 	Win 6: MLTIYL - 0 samples
# 	Win 7: RMLTIYL - 0 samples
# 233/372: MLTIYLI
# 	Win 4: TIYL - 1496 samples
# 	Win 5: LTIYL - 65 samples
# 	Win 6: LTIYLI - 0 samples
# 	Win 7: MLTIYLI - 0 samples
# 234/372: LTIYLIL
# 	Win 4: IYLI - 2193 samples
# 	Win 5: TIYLI - 77 samples
# 	Win 6: TIYLIL - 0 samples
# 	Win 7: LTIYLIL - 0 samples
# 235/372: TIYLILA
# 	Win 4: YLIL - 1863 samples
# 	Win 5: IYLIL - 54 samples
# 	Win 6: IYLILA - 0 samples
# 	Win 7: TIYLILA - 0 samples
# 236/372: IYLILAC
# 	Win 4: LILA - 4683 samples
# 	Win 5: YLILA - 127 samples
# 	Win 6: YLILAC - 0 samples
# 	Win 7: IYLILAC - 0 samples
# 237/372: YLILACV
# 	Win 4: ILAC - 608 samples
# 	Win 5: LILAC - 116 samples
# 	Win 6: LILACV - 0 samples
# 	Win 7: YLILACV - 0 samples
# 238/372: LILACVL
# 	Win 4: LACV - 882 samples
# 	Win 5: ILACV - 8 samples
# 	Win 6: ILACVL - 0 samples
# 	Win 7: LILACVL - 0 samples
# 239/372: ILACVLV
# 	Win 4: ACVL - 796 samples
# 	Win 5: LACVL - 40 samples
# 	Win 6: LACVLV - 2 samples
# 	Win 7: ILACVLV - 0 samples
# 240/372: LACVLVV
# 	Win 4: CVLV - 1443 samples
# 	Win 5: ACVLV - 105 samples
# 	Win 6: ACVLVV - 1 samples
# 	Win 7: LACVLVV - 0 samples
# 241/372: ACVLVVL
# 	Win 4: VLVV - 6862 samples
# 	Win 5: CVLVV - 33 samples
# 	Win 6: CVLVVL - 6 samples
# 	Win 7: ACVLVVL - 0 samples
# 242/372: CVLVVLL
# 	Win 4: LVVL - 5507 samples
# 	Win 5: VLVVL - 405 samples
# 	Win 6: VLVVLL - 95 samples
# 	Win 7: CVLVVLL - 0 samples
# 243/372: VLVVLLM
# 	Win 4: VVLL - 6386 samples
# 	Win 5: LVVLL - 755 samples
# 	Win 6: LVVLLM - 0 samples
# 	Win 7: VLVVLLM - 0 samples
# 244/372: LVVLLMT
# 	Win 4: VLLM - 1602 samples
# 	Win 5: VVLLM - 16 samples
# 	Win 6: VVLLMT - 0 samples
# 	Win 7: LVVLLMT - 0 samples
# 245/372: VVLLMTT
# 	Win 4: LLMT - 1586 samples
# 	Win 5: VLLMT - 77 samples
# 	Win 6: VLLMTT - 27 samples
# 	Win 7: VVLLMTT - 0 samples
# 246/372: VLLMTTL
# 	Win 4: LMTT - 1295 samples
# 	Win 5: LLMTT - 30 samples
# 	Win 6: LLMTTL - 27 samples
# 	Win 7: VLLMTTL - 27 samples
# 247/372: LLMTTLN
# 	Win 4: MTTL - 1664 samples
# 	Win 5: LMTTL - 187 samples
# 	Win 6: LMTTLN - 0 samples
# 	Win 7: LLMTTLN - 0 samples
# 248/372: LMTTLNR
# 	Win 4: TTLN - 8011 samples
# 	Win 5: MTTLN - 171 samples
# 	Win 6: MTTLNR - 0 samples
# 	Win 7: LMTTLNR - 0 samples
# 249/372: MTTLNRL
# 	Win 4: TLNR - 1891 samples
# 	Win 5: TTLNR - 59 samples
# 	Win 6: TTLNRL - 18 samples
# 	Win 7: MTTLNRL - 0 samples
# 250/372: TTLNRLT
# 	Win 4: LNRL - 6861 samples
# 	Win 5: TLNRL - 365 samples
# 	Win 6: TLNRLT - 4 samples
# 	Win 7: TTLNRLT - 0 samples
# 251/372: TLNRLTK
# 	Win 4: NRLT - 2144 samples
# 	Win 5: LNRLT - 226 samples
# 	Win 6: LNRLTK - 23 samples
# 	Win 7: TLNRLTK - 0 samples
# 252/372: LNRLTKD
# 	Win 4: RLTK - 2716 samples
# 	Win 5: NRLTK - 75 samples
# 	Win 6: NRLTKD - 0 samples
# 	Win 7: LNRLTKD - 0 samples
# 253/372: NRLTKDW
# 	Win 4: LTKD - 5512 samples
# 	Win 5: RLTKD - 428 samples
# 	Win 6: RLTKDW - 0 samples
# 	Win 7: NRLTKDW - 0 samples
# 254/372: RLTKDWS
# 	Win 4: TKDW - 317 samples
# 	Win 5: LTKDW - 0 samples
# 	Win 6: LTKDWS - 0 samples
# 	Win 7: RLTKDWS - 0 samples
# 255/372: LTKDWSH
# 	Win 4: KDWS - 3093 samples
# 	Win 5: TKDWS - 2 samples
# 	Win 6: TKDWSH - 0 samples
# 	Win 7: LTKDWSH - 0 samples
# 256/372: TKDWSHQ
# 	Win 4: DWSH - 163 samples
# 	Win 5: KDWSH - 0 samples
# 	Win 6: KDWSHQ - 0 samples
# 	Win 7: TKDWSHQ - 0 samples
# 257/372: KDWSHQK
# 	Win 4: WSHQ - 110 samples
# 	Win 5: DWSHQ - 3 samples
# 	Win 6: DWSHQK - 0 samples
# 	Win 7: KDWSHQK - 0 samples
# 258/372: DWSHQKG
# 	Win 4: SHQK - 229 samples
# 	Win 5: WSHQK - 0 samples
# 	Win 6: WSHQKG - 0 samples
# 	Win 7: DWSHQKG - 0 samples
# 259/372: WSHQKGF
# 	Win 4: HQKG - 458 samples
# 	Win 5: SHQKG - 60 samples
# 	Win 6: SHQKGF - 0 samples
# 	Win 7: WSHQKGF - 0 samples
# 260/372: SHQKGFI
# 	Win 4: QKGF - 858 samples
# 	Win 5: HQKGF - 0 samples
# 	Win 6: HQKGFI - 0 samples
# 	Win 7: SHQKGFI - 0 samples
# 261/372: HQKGFIW
# 	Win 4: KGFI - 1254 samples
# 	Win 5: QKGFI - 78 samples
# 	Win 6: QKGFIW - 0 samples
# 	Win 7: HQKGFIW - 0 samples
# 262/372: QKGFIWG
# 	Win 4: GFIW - 549 samples
# 	Win 5: KGFIW - 15 samples
# 	Win 6: KGFIWG - 0 samples
# 	Win 7: QKGFIWG - 0 samples
# 263/372: KGFIWGS
# 	Win 4: FIWG - 274 samples
# 	Win 5: GFIWG - 106 samples
# 	Win 6: GFIWGS - 0 samples
# 	Win 7: KGFIWGS - 0 samples
# 264/372: GFIWGSL
# 	Win 4: IWGS - 284 samples
# 	Win 5: FIWGS - 30 samples
# 	Win 6: FIWGSL - 2 samples
# 	Win 7: GFIWGSL - 0 samples
# 265/372: FIWGSLF
# 	Win 4: WGSL - 1871 samples
# 	Win 5: IWGSL - 43 samples
# 	Win 6: IWGSLF - 0 samples
# 	Win 7: FIWGSLF - 0 samples
# 266/372: IWGSLFM
# 	Win 4: GSLF - 3591 samples
# 	Win 5: WGSLF - 0 samples
# 	Win 6: WGSLFM - 0 samples
# 	Win 7: IWGSLFM - 0 samples
# 267/372: WGSLFMA
# 	Win 4: SLFM - 551 samples
# 	Win 5: GSLFM - 62 samples
# 	Win 6: GSLFMA - 0 samples
# 	Win 7: WGSLFMA - 0 samples
# 268/372: GSLFMAI
# 	Win 4: LFMA - 768 samples
# 	Win 5: SLFMA - 31 samples
# 	Win 6: SLFMAI - 2 samples
# 	Win 7: GSLFMAI - 0 samples
# 269/372: SLFMAIG
# 	Win 4: FMAI - 478 samples
# 	Win 5: LFMAI - 13 samples
# 	Win 6: LFMAIG - 0 samples
# 	Win 7: SLFMAIG - 0 samples
# 270/372: LFMAIGM
# 	Win 4: MAIG - 1256 samples
# 	Win 5: FMAIG - 47 samples
# 	Win 6: FMAIGM - 26 samples
# 	Win 7: LFMAIGM - 0 samples
# 271/372: FMAIGMI
# 	Win 4: AIGM - 1505 samples
# 	Win 5: MAIGM - 106 samples
# 	Win 6: MAIGMI - 2 samples
# 	Win 7: FMAIGMI - 0 samples
# 272/372: MAIGMIF
# 	Win 4: IGMI - 812 samples
# 	Win 5: AIGMI - 23 samples
# 	Win 6: AIGMIF - 0 samples
# 	Win 7: MAIGMIF - 0 samples
# 273/372: AIGMIFS
# 	Win 4: GMIF - 722 samples
# 	Win 5: IGMIF - 50 samples
# 	Win 6: IGMIFS - 0 samples
# 	Win 7: AIGMIFS - 0 samples
# 274/372: IGMIFSF
# 	Win 4: MIFS - 389 samples
# 	Win 5: GMIFS - 29 samples
# 	Win 6: GMIFSF - 0 samples
# 	Win 7: IGMIFSF - 0 samples
# 275/372: GMIFSFL
# 	Win 4: IFSF - 1221 samples
# 	Win 5: MIFSF - 8 samples
# 	Win 6: MIFSFL - 5 samples
# 	Win 7: GMIFSFL - 0 samples
# 276/372: MIFSFLT
# 	Win 4: FSFL - 2090 samples
# 	Win 5: IFSFL - 126 samples
# 	Win 6: IFSFLT - 0 samples
# 	Win 7: MIFSFLT - 0 samples
# 277/372: IFSFLTT
# 	Win 4: SFLT - 1923 samples
# 	Win 5: FSFLT - 81 samples
# 	Win 6: FSFLTT - 5 samples
# 	Win 7: IFSFLTT - 0 samples
# 278/372: FSFLTTT
# 	Win 4: FLTT - 1769 samples
# 	Win 5: SFLTT - 176 samples
# 	Win 6: SFLTTT - 2 samples
# 	Win 7: FSFLTTT - 0 samples
# 279/372: SFLTTTF
# 	Win 4: LTTT - 2734 samples
# 	Win 5: FLTTT - 18 samples
# 	Win 6: FLTTTF - 0 samples
# 	Win 7: SFLTTTF - 0 samples
# 280/372: FLTTTFT
# 	Win 4: TTTF - 1939 samples
# 	Win 5: LTTTF - 171 samples
# 	Win 6: LTTTFT - 62 samples
# 	Win 7: FLTTTFT - 0 samples
# 281/372: LTTTFTP
# 	Win 4: TTFT - 2351 samples
# 	Win 5: TTTFT - 993 samples
# 	Win 6: TTTFTP - 16 samples
# 	Win 7: LTTTFTP - 16 samples
# 282/372: TTTFTPI
# 	Win 4: TFTP - 759 samples
# 	Win 5: TTFTP - 110 samples
# 	Win 6: TTFTPI - 0 samples
# 	Win 7: TTTFTPI - 0 samples
# 283/372: TTFTPIF
# 	Win 4: FTPI - 614 samples
# 	Win 5: TFTPI - 22 samples
# 	Win 6: TFTPIF - 0 samples
# 	Win 7: TTFTPIF - 0 samples
# 284/372: TFTPIFI
# 	Win 4: TPIF - 1415 samples
# 	Win 5: FTPIF - 58 samples
# 	Win 6: FTPIFI - 0 samples
# 	Win 7: TFTPIFI - 0 samples
# 285/372: FTPIFIA
# 	Win 4: PIFI - 1083 samples
# 	Win 5: TPIFI - 79 samples
# 	Win 6: TPIFIA - 0 samples
# 	Win 7: FTPIFIA - 0 samples
# 286/372: TPIFIAG
# 	Win 4: IFIA - 1454 samples
# 	Win 5: PIFIA - 105 samples
# 	Win 6: PIFIAG - 0 samples
# 	Win 7: TPIFIAG - 0 samples
# 287/372: PIFIAGI
# 	Win 4: FIAG - 2923 samples
# 	Win 5: IFIAG - 46 samples
# 	Win 6: IFIAGI - 0 samples
# 	Win 7: PIFIAGI - 0 samples
# 288/372: IFIAGIV
# 	Win 4: IAGI - 3701 samples
# 	Win 5: FIAGI - 356 samples
# 	Win 6: FIAGIV - 146 samples
# 	Win 7: IFIAGIV - 0 samples
# 289/372: FIAGIVY
# 	Win 4: AGIV - 4443 samples
# 	Win 5: IAGIV - 237 samples
# 	Win 6: IAGIVY - 0 samples
# 	Win 7: FIAGIVY - 0 samples
# 290/372: IAGIVYT
# 	Win 4: GIVY - 2413 samples
# 	Win 5: AGIVY - 29 samples
# 	Win 6: AGIVYT - 0 samples
# 	Win 7: IAGIVYT - 0 samples
# 291/372: AGIVYTL
# 	Win 4: IVYT - 904 samples
# 	Win 5: GIVYT - 46 samples
# 	Win 6: GIVYTL - 15 samples
# 	Win 7: AGIVYTL - 0 samples
# 292/372: GIVYTLG
# 	Win 4: VYTL - 2356 samples
# 	Win 5: IVYTL - 55 samples
# 	Win 6: IVYTLG - 1 samples
# 	Win 7: GIVYTLG - 0 samples
# 293/372: IVYTLGE
# 	Win 4: YTLG - 1523 samples
# 	Win 5: VYTLG - 39 samples
# 	Win 6: VYTLGE - 0 samples
# 	Win 7: IVYTLGE - 0 samples
# 294/372: VYTLGEI
# 	Win 4: TLGE - 4531 samples
# 	Win 5: YTLGE - 146 samples
# 	Win 6: YTLGEI - 0 samples
# 	Win 7: VYTLGEI - 0 samples
# 295/372: YTLGEIV
# 	Win 4: LGEI - 3664 samples
# 	Win 5: TLGEI - 223 samples
# 	Win 6: TLGEIV - 8 samples
# 	Win 7: YTLGEIV - 0 samples
# 296/372: TLGEIVY
# 	Win 4: GEIV - 3703 samples
# 	Win 5: LGEIV - 389 samples
# 	Win 6: LGEIVY - 4 samples
# 	Win 7: TLGEIVY - 0 samples
# 297/372: LGEIVYT
# 	Win 4: EIVY - 1003 samples
# 	Win 5: GEIVY - 104 samples
# 	Win 6: GEIVYT - 0 samples
# 	Win 7: LGEIVYT - 0 samples
# 298/372: GEIVYTP
# 	Win 4: IVYT - 904 samples
# 	Win 5: EIVYT - 29 samples
# 	Win 6: EIVYTP - 0 samples
# 	Win 7: GEIVYTP - 0 samples
# 299/372: EIVYTPS
# 	Win 4: VYTP - 1230 samples
# 	Win 5: IVYTP - 149 samples
# 	Win 6: IVYTPS - 0 samples
# 	Win 7: EIVYTPS - 0 samples
# 300/372: IVYTPSV
# 	Win 4: YTPS - 2028 samples
# 	Win 5: VYTPS - 14 samples
# 	Win 6: VYTPSV - 2 samples
# 	Win 7: IVYTPSV - 0 samples
# 301/372: VYTPSVQ
# 	Win 4: TPSV - 882 samples
# 	Win 5: YTPSV - 13 samples
# 	Win 6: YTPSVQ - 0 samples
# 	Win 7: VYTPSVQ - 0 samples
# 302/372: YTPSVQT
# 	Win 4: PSVQ - 793 samples
# 	Win 5: TPSVQ - 47 samples
# 	Win 6: TPSVQT - 0 samples
# 	Win 7: YTPSVQT - 0 samples
# 303/372: TPSVQTL
# 	Win 4: SVQT - 1211 samples
# 	Win 5: PSVQT - 35 samples
# 	Win 6: PSVQTL - 0 samples
# 	Win 7: TPSVQTL - 0 samples
# 304/372: PSVQTLG
# 	Win 4: VQTL - 2709 samples
# 	Win 5: SVQTL - 87 samples
# 	Win 6: SVQTLG - 0 samples
# 	Win 7: PSVQTLG - 0 samples
# 305/372: SVQTLGA
# 	Win 4: QTLG - 2544 samples
# 	Win 5: VQTLG - 301 samples
# 	Win 6: VQTLGA - 13 samples
# 	Win 7: SVQTLGA - 0 samples
# 306/372: VQTLGAD
# 	Win 4: TLGA - 3850 samples
# 	Win 5: QTLGA - 95 samples
# 	Win 6: QTLGAD - 24 samples
# 	Win 7: VQTLGAD - 0 samples
# 307/372: QTLGADL
# 	Win 4: LGAD - 6998 samples
# 	Win 5: TLGAD - 184 samples
# 	Win 6: TLGADL - 84 samples
# 	Win 7: QTLGADL - 24 samples
# 308/372: TLGADLM
# 	Win 4: GADL - 5885 samples
# 	Win 5: LGADL - 586 samples
# 	Win 6: LGADLM - 0 samples
# 	Win 7: TLGADLM - 0 samples
# 309/372: LGADLMN
# 	Win 4: ADLM - 2056 samples
# 	Win 5: GADLM - 63 samples
# 	Win 6: GADLMN - 0 samples
# 	Win 7: LGADLMN - 0 samples
# 310/372: GADLMNP
# 	Win 4: DLMN - 1561 samples
# 	Win 5: ADLMN - 79 samples
# 	Win 6: ADLMNP - 0 samples
# 	Win 7: GADLMNP - 0 samples
# 311/372: ADLMNPE
# 	Win 4: LMNP - 431 samples
# 	Win 5: DLMNP - 28 samples
# 	Win 6: DLMNPE - 0 samples
# 	Win 7: ADLMNPE - 0 samples
# 312/372: DLMNPEK
# 	Win 4: MNPE - 455 samples
# 	Win 5: LMNPE - 43 samples
# 	Win 6: LMNPEK - 0 samples
# 	Win 7: DLMNPEK - 0 samples
# 313/372: LMNPEKI
# 	Win 4: NPEK - 2203 samples
# 	Win 5: MNPEK - 31 samples
# 	Win 6: MNPEKI - 0 samples
# 	Win 7: LMNPEKI - 0 samples
# 314/372: MNPEKIG
# 	Win 4: PEKI - 1854 samples
# 	Win 5: NPEKI - 118 samples
# 	Win 6: NPEKIG - 0 samples
# 	Win 7: MNPEKIG - 0 samples
# 315/372: NPEKIGS
# 	Win 4: EKIG - 4074 samples
# 	Win 5: PEKIG - 80 samples
# 	Win 6: PEKIGS - 0 samples
# 	Win 7: NPEKIGS - 0 samples
# 316/372: PEKIGSY
# 	Win 4: KIGS - 3326 samples
# 	Win 5: EKIGS - 250 samples
# 	Win 6: EKIGSY - 1 samples
# 	Win 7: PEKIGSY - 0 samples
# 317/372: EKIGSYN
# 	Win 4: IGSY - 681 samples
# 	Win 5: KIGSY - 39 samples
# 	Win 6: KIGSYN - 3 samples
# 	Win 7: EKIGSYN - 0 samples
# 318/372: KIGSYNG
# 	Win 4: GSYN - 1258 samples
# 	Win 5: IGSYN - 22 samples
# 	Win 6: IGSYNG - 7 samples
# 	Win 7: KIGSYNG - 0 samples
# 319/372: IGSYNGV
# 	Win 4: SYNG - 1051 samples
# 	Win 5: GSYNG - 132 samples
# 	Win 6: GSYNGV - 2 samples
# 	Win 7: IGSYNGV - 0 samples
# 320/372: GSYNGVA
# 	Win 4: YNGV - 858 samples
# 	Win 5: SYNGV - 43 samples
# 	Win 6: SYNGVA - 0 samples
# 	Win 7: GSYNGVA - 0 samples
# 321/372: SYNGVAA
# 	Win 4: NGVA - 3933 samples
# 	Win 5: YNGVA - 18 samples
# 	Win 6: YNGVAA - 0 samples
# 	Win 7: SYNGVAA - 0 samples
# 322/372: YNGVAAI
# 	Win 4: GVAA - 6075 samples
# 	Win 5: NGVAA - 261 samples
# 	Win 6: NGVAAI - 14 samples
# 	Win 7: YNGVAAI - 0 samples
# 323/372: NGVAAIK
# 	Win 4: VAAI - 6155 samples
# 	Win 5: GVAAI - 649 samples
# 	Win 6: GVAAIK - 3 samples
# 	Win 7: NGVAAIK - 2 samples
# 324/372: GVAAIKM
# 	Win 4: AAIK - 4174 samples
# 	Win 5: VAAIK - 549 samples
# 	Win 6: VAAIKM - 0 samples
# 	Win 7: GVAAIKM - 0 samples
# 325/372: VAAIKMP
# 	Win 4: AIKM - 1204 samples
# 	Win 5: AAIKM - 219 samples
# 	Win 6: AAIKMP - 0 samples
# 	Win 7: VAAIKMP - 0 samples
# 326/372: AAIKMPI
# 	Win 4: IKMP - 189 samples
# 	Win 5: AIKMP - 33 samples
# 	Win 6: AIKMPI - 0 samples
# 	Win 7: AAIKMPI - 0 samples
# 327/372: AIKMPIA
# 	Win 4: KMPI - 423 samples
# 	Win 5: IKMPI - 23 samples
# 	Win 6: IKMPIA - 0 samples
# 	Win 7: AIKMPIA - 0 samples
# 328/372: IKMPIAS
# 	Win 4: MPIA - 862 samples
# 	Win 5: KMPIA - 9 samples
# 	Win 6: KMPIAS - 0 samples
# 	Win 7: IKMPIAS - 0 samples
# 329/372: KMPIASI
# 	Win 4: PIAS - 1370 samples
# 	Win 5: MPIAS - 59 samples
# 	Win 6: MPIASI - 0 samples
# 	Win 7: KMPIASI - 0 samples
# 330/372: MPIASIL
# 	Win 4: IASI - 3596 samples
# 	Win 5: PIASI - 234 samples
# 	Win 6: PIASIL - 13 samples
# 	Win 7: MPIASIL - 0 samples
# 331/372: PIASILA
# 	Win 4: ASIL - 3676 samples
# 	Win 5: IASIL - 196 samples
# 	Win 6: IASILA - 22 samples
# 	Win 7: PIASILA - 0 samples
# 332/372: IASILAG
# 	Win 4: SILA - 7077 samples
# 	Win 5: ASILA - 389 samples
# 	Win 6: ASILAG - 50 samples
# 	Win 7: IASILAG - 0 samples
# 333/372: ASILAGL
# 	Win 4: ILAG - 5027 samples
# 	Win 5: SILAG - 201 samples
# 	Win 6: SILAGL - 54 samples
# 	Win 7: ASILAGL - 50 samples
# 334/372: SILAGLL
# 	Win 4: LAGL - 9976 samples
# 	Win 5: ILAGL - 458 samples
# 	Win 6: ILAGLL - 18 samples
# 	Win 7: SILAGLL - 0 samples
# 335/372: ILAGLLV
# 	Win 4: AGLL - 8721 samples
# 	Win 5: LAGLL - 1220 samples
# 	Win 6: LAGLLV - 17 samples
# 	Win 7: ILAGLLV - 0 samples
# 336/372: LAGLLVS
# 	Win 4: GLLV - 6078 samples
# 	Win 5: AGLLV - 549 samples
# 	Win 6: AGLLVS - 58 samples
# 	Win 7: LAGLLVS - 1 samples
# 337/372: AGLLVSI
# 	Win 4: LLVS - 6688 samples
# 	Win 5: GLLVS - 382 samples
# 	Win 6: GLLVSI - 1 samples
# 	Win 7: AGLLVSI - 1 samples
# 338/372: GLLVSIS
# 	Win 4: LVSI - 3778 samples
# 	Win 5: LLVSI - 121 samples
# 	Win 6: LLVSIS - 2 samples
# 	Win 7: GLLVSIS - 0 samples
# 339/372: LLVSISP
# 	Win 4: VSIS - 2705 samples
# 	Win 5: LVSIS - 162 samples
# 	Win 6: LVSISP - 0 samples
# 	Win 7: LLVSISP - 0 samples
# 340/372: LVSISPM
# 	Win 4: SISP - 2488 samples
# 	Win 5: VSISP - 127 samples
# 	Win 6: VSISPM - 14 samples
# 	Win 7: LVSISPM - 0 samples
# 341/372: VSISPMI
# 	Win 4: ISPM - 763 samples
# 	Win 5: SISPM - 27 samples
# 	Win 6: SISPMI - 0 samples
# 	Win 7: VSISPMI - 0 samples
# 342/372: SISPMIK
# 	Win 4: SPMI - 236 samples
# 	Win 5: ISPMI - 6 samples
# 	Win 6: ISPMIK - 2 samples
# 	Win 7: SISPMIK - 0 samples
# 343/372: ISPMIKA
# 	Win 4: PMIK - 156 samples
# 	Win 5: SPMIK - 2 samples
# 	Win 6: SPMIKA - 0 samples
# 	Win 7: ISPMIKA - 0 samples
# 344/372: SPMIKAI
# 	Win 4: MIKA - 1043 samples
# 	Win 5: PMIKA - 26 samples
# 	Win 6: PMIKAI - 0 samples
# 	Win 7: SPMIKAI - 0 samples
# 345/372: PMIKAIG
# 	Win 4: IKAI - 4085 samples
# 	Win 5: MIKAI - 35 samples
# 	Win 6: MIKAIG - 0 samples
# 	Win 7: PMIKAIG - 0 samples
# 346/372: MIKAIGV
# 	Win 4: KAIG - 7483 samples
# 	Win 5: IKAIG - 282 samples
# 	Win 6: IKAIGV - 11 samples
# 	Win 7: MIKAIGV - 0 samples
# 347/372: IKAIGVS
# 	Win 4: AIGV - 4179 samples
# 	Win 5: KAIGV - 808 samples
# 	Win 6: KAIGVS - 21 samples
# 	Win 7: IKAIGVS - 7 samples
# 348/372: KAIGVSL
# 	Win 4: IGVS - 3406 samples
# 	Win 5: AIGVS - 273 samples
# 	Win 6: AIGVSL - 6 samples
# 	Win 7: KAIGVSL - 0 samples
# 349/372: AIGVSLV
# 	Win 4: GVSL - 7396 samples
# 	Win 5: IGVSL - 249 samples
# 	Win 6: IGVSLV - 0 samples
# 	Win 7: AIGVSLV - 0 samples
# 350/372: IGVSLVL
# 	Win 4: VSLV - 4601 samples
# 	Win 5: GVSLV - 303 samples
# 	Win 6: GVSLVL - 23 samples
# 	Win 7: IGVSLVL - 0 samples
# 351/372: GVSLVLA
# 	Win 4: SLVL - 6006 samples
# 	Win 5: VSLVL - 986 samples
# 	Win 6: VSLVLA - 29 samples
# 	Win 7: GVSLVLA - 0 samples
# 352/372: VSLVLAL
# 	Win 4: LVLA - 8000 samples
# 	Win 5: SLVLA - 538 samples
# 	Win 6: SLVLAL - 14 samples
# 	Win 7: VSLVLAL - 0 samples
# 353/372: SLVLALT
# 	Win 4: VLAL - 6625 samples
# 	Win 5: LVLAL - 868 samples
# 	Win 6: LVLALT - 18 samples
# 	Win 7: SLVLALT - 0 samples
# 354/372: LVLALTE
# 	Win 4: LALT - 4936 samples
# 	Win 5: VLALT - 337 samples
# 	Win 6: VLALTE - 27 samples
# 	Win 7: LVLALTE - 0 samples
# 355/372: VLALTEV
# 	Win 4: ALTE - 5798 samples
# 	Win 5: LALTE - 259 samples
# 	Win 6: LALTEV - 0 samples
# 	Win 7: VLALTEV - 0 samples
# 356/372: LALTEVL
# 	Win 4: LTEV - 3800 samples
# 	Win 5: ALTEV - 1182 samples
# 	Win 6: ALTEVL - 34 samples
# 	Win 7: LALTEVL - 0 samples
# 357/372: ALTEVLA
# 	Win 4: TEVL - 2766 samples
# 	Win 5: LTEVL - 292 samples
# 	Win 6: LTEVLA - 7 samples
# 	Win 7: ALTEVLA - 0 samples
# 358/372: LTEVLAI
# 	Win 4: EVLA - 7124 samples
# 	Win 5: TEVLA - 154 samples
# 	Win 6: TEVLAI - 0 samples
# 	Win 7: LTEVLAI - 0 samples
# 359/372: TEVLAII
# 	Win 4: VLAI - 4621 samples
# 	Win 5: EVLAI - 153 samples
# 	Win 6: EVLAII - 2 samples
# 	Win 7: TEVLAII - 0 samples
# 360/372: EVLAIIL
# 	Win 4: LAII - 4027 samples
# 	Win 5: VLAII - 91 samples
# 	Win 6: VLAIIL - 0 samples
# 	Win 7: EVLAIIL - 0 samples
# 361/372: VLAIILV
# 	Win 4: AIIL - 2624 samples
# 	Win 5: LAIIL - 251 samples
# 	Win 6: LAIILV - 7 samples
# 	Win 7: VLAIILV - 0 samples
# 362/372: LAIILVL
# 	Win 4: IILV - 2170 samples
# 	Win 5: AIILV - 298 samples
# 	Win 6: AIILVL - 13 samples
# 	Win 7: LAIILVL - 0 samples
# 363/372: AIILVLV
# 	Win 4: ILVL - 3389 samples
# 	Win 5: IILVL - 250 samples
# 	Win 6: IILVLV - 0 samples
# 	Win 7: AIILVLV - 0 samples
# 364/372: IILVLVA
# 	Win 4: LVLV - 5224 samples
# 	Win 5: ILVLV - 192 samples
# 	Win 6: ILVLVA - 6 samples
# 	Win 7: IILVLVA - 0 samples
# 365/372: ILVLVAV
# 	Win 4: VLVA - 7156 samples
# 	Win 5: LVLVA - 522 samples
# 	Win 6: LVLVAV - 1 samples
# 	Win 7: ILVLVAV - 0 samples
# 366/372: LVLVAVN
# 	Win 4: LVAV - 4867 samples
# 	Win 5: VLVAV - 295 samples
# 	Win 6: VLVAVN - 5 samples
# 	Win 7: LVLVAVN - 0 samples
# 367/372: VLVAVNR
# 	Win 4: VAVN - 2563 samples
# 	Win 5: LVAVN - 196 samples
# 	Win 6: LVAVNR - 1 samples
# 	Win 7: VLVAVNR - 1 samples
# 368/372: LVAVNRH
# 	Win 4: AVNR - 2343 samples
# 	Win 5: VAVNR - 67 samples
# 	Win 6: VAVNRH - 0 samples
# 	Win 7: LVAVNRH - 0 samples
# 369/372: VAVNRHQ
# 	Win 4: VNRH - 950 samples
# 	Win 5: AVNRH - 12 samples
# 	Win 6: AVNRHQ - 0 samples
# 	Win 7: VAVNRHQ - 0 samples
# 370/372: AVNRHQK
# 	Win 4: NRHQ - 134 samples
# 	Win 5: VNRHQ - 0 samples
# 	Win 6: VNRHQK - 0 samples
# 	Win 7: AVNRHQK - 0 samples
# 371/372: VNRHQKT
# 	Win 4: RHQK - 446 samples
# 	Win 5: NRHQK - 0 samples
# 	Win 6: NRHQKT - 0 samples
# 	Win 7: VNRHQKT - 0 samples
# 372/372: NRHQKTK
# 	Win 4: HQKT - 512 samples
# 	Win 5: RHQKT - 19 samples
# 	Win 6: RHQKTK - 0 samples
# 	Win 7: NRHQKTK - 0 samples

# %%
da.xray_phi_psi.sort_values('sil_score')
# Out:
#      pos seq_ctxt res         phi         psi protein_id          da  \
# 126  130  DASNAEN   N -111.834049  161.721426       6t1z    7.850945
# 35    39  NQYLGSA   L -118.253251 -178.325180       6t1z  165.678176
# 226  237  LSNSFKT   S -144.888539   52.246372       6t1z   54.070270
# 315  332  NPEKIGS   K -108.758528   34.339697       6t1z   14.708522
# 159  163  FRPAFEA   A -126.754472   67.684924       6t1z   23.015634
# ..   ...      ...  ..         ...         ...        ...         ...
# 36    40  QYLGSAI   G  -75.926941  173.971663       6t1z  160.136370
# 251  268  TLNRLTK   R  -55.715858  -44.667982       6t1z    9.460907
# 3      7  WNLDKNL   D  -66.325518  141.755098       6t1z    3.487576
# 231  248  QRMLTIY   L  -54.358420  -40.325213       6t1z    5.356483
# 68    72  NGRKPVM   K  -50.642510  -50.092374       6t1z   16.293463
#
#      n_samples      n_samples_list  da_no_scale  sil_score
# 126     1639.0   [1424, 207, 8, 0]     7.850945   0.096693
# 35      2437.0   [2335, 102, 0, 0]   165.678176   0.303990
# 226      939.0     [900, 39, 0, 0]    54.070270   0.636807
# 315     4154.0    [4074, 80, 0, 0]    14.708522   0.651797
# 159     1570.0    [1480, 84, 6, 0]    23.015634   0.712069
# ..         ...                 ...          ...        ...
# 36      7718.0   [7591, 127, 0, 0]   160.136370   1.068916
# 251     2393.0  [2144, 226, 23, 0]     9.460907   1.071628
# 3       2530.0    [2427, 95, 8, 0]     3.487576   1.071943
# 231      811.0     [795, 16, 0, 0]     5.356483   1.072148
# 68      1540.0    [1487, 50, 3, 0]    16.293463   1.104362
#
# [373 rows x 11 columns]

# %%
da.casp_protein_id
# Out:
# 'T1024'

# %%
da.results
# Out:
#             Model   GR#  GDT_TS   NP_P  RANK  Z-M1-GDT  Z-MA-GDT  GDT_HA  \
# 0    T1024TS427_3   427   79.22  100.0     1       NaN      2.09   60.67
# 1    T1024TS427_5   427   71.67  100.0     2       NaN      1.50   51.98
# 2    T1024TS226_5  226s   65.73  100.0     3       NaN      1.04   42.84
# 3    T1024TS427_4   427   65.22  100.0     4       NaN      1.00   48.78
# 4    T1024TS324_3  324s   65.15  100.0     5       NaN      1.00   42.52
# ..            ...   ...     ...    ...   ...       ...       ...     ...
# 507  T1024TS170_4  170s    9.46  100.0   508       NaN     -3.32    4.79
# 508  T1024TS063_5  063s    9.02  100.0   509       NaN     -3.35    5.88
# 509  T1024TS305_1  305s    8.76  100.0   510     -3.36     -3.37    4.60
# 510  T1024TS342_2   342    8.76  100.0   510       NaN     -3.37    6.33
# 511  T1024TS217_5   217    8.44  100.0   512       NaN     -3.40    4.67
#
#      GDC_SC  GDC_ALL  ...  CONTS  TMscore  Dali(raw)   FlexE    QSE  CAD_SS  \
# 0     46.80    53.52  ...  96.86     0.93     6369.1    0.35  90.02    0.69
# 1     38.22    44.45  ...  96.61     0.88     5966.0    0.35  83.46    0.68
# 2     26.75    36.95  ...  81.55     0.87     4599.4    3.40    NaN    0.39
# 3     28.83    31.09  ...  93.46     0.77     3500.6    1.44  68.42    0.65
# 4     25.94    36.11  ...  85.42     0.86     4728.6    2.61  87.83    0.41
# ..      ...      ...  ...    ...      ...        ...     ...    ...     ...
# 507    1.52     2.94  ...  41.23     0.23      440.5  201.20    NaN    0.07
# 508    0.72     2.65  ...  29.85     0.17        NaN  746.50  92.81    0.05
# 509    0.74     2.33  ...  48.22     0.22        NaN  151.85  18.11    0.07
# 510    2.64     4.53  ...  43.00     0.15      274.9  410.17    NaN    0.08
# 511    0.00     1.63  ...  48.36     0.20        NaN  167.41  17.24    0.00
#
#      MolPrb_clash  MolPrb_rotout  MolPrb_ramout  MolPrb_ramfv
# 0            2.62           0.59           0.00         98.03
# 1            3.08           0.29           0.00         98.28
# 2            3.85           2.35           2.22         91.87
# 3            1.69           0.59           0.00         98.28
# 4            1.85           2.64           0.74         96.55
# ..            ...            ...            ...           ...
# 507          0.00           0.59           0.74         92.36
# 508        374.98          23.46          22.73         60.10
# 509        721.62          10.56           5.91         85.22
# 510         48.43           2.64           3.20         91.63
# 511         26.35            NaN           3.94         89.90
#
# [512 rows x 44 columns]

# %%
da.grouped_preds = da.phi_psi_predictions.groupby('protein_id').sum(numeric_only=True).sil_score.to_frame()
da.grouped_preds = pd.merge(da.grouped_preds, da.results[['Model', 'GDT_TS']], left_on='protein_id', right_on='Model')
sns.regplot(data=da.grouped_preds, x='sil_score', y='GDT_TS')
# Out:
# <Axes: xlabel='sil_score', ylabel='GDT_TS'>

# %% [markdown]
# # Score by n-neighbors
