# %%
# %load_ext autoreload
# %autoreload 2

# %%
import Bio
from lib import DihedralAdherence
import os
from lib.constants import AMINO_ACID_CODES
from Bio import PDB
from Bio.PDB import Superimposer
from Bio.Align import PairwiseAligner
import numpy as np
import pandas as pd
import seaborn as sns

# %%
PDBMINE_URL = os.getenv("PDBMINE_URL")
PROJECT_DIR = 'casp_da'
proteins = [
  'T1024', 'T1030', 'T1030-D2', 'T1024-D1', 'T1032-D1', 'T1053-D1', 'T1027-D1', 'T1029-D1',
  'T1025-D1', 'T1028-D1', 'T1030-D1', 'T1053-D2', 'T1057-D1','T1058-D1', 'T1058-D2'
]
da = DihedralAdherence(proteins[0], [4,5,6,7], PDBMINE_URL, PROJECT_DIR, kdews=[1,32,64,128], 
                      mode='ml', weights_file='ml_runs/best_model-kde_16-32_383.pt', device='cpu')
# Out:
# Initializing T1024 ...
# Results already exist
# Casp ID: T1024 	PDB: 6t1z
# Structure exists: 'pdb/pdb6t1z.ent'
# UniProt ID: Q48658

# %%
def compute_lddt(xray_fn, pred_fn):
    INCLUSION_RADIUS = 15 # Angstroms
    THRESHOLDS = [0.5, 1, 2, 4] # Angstroms

    parser = PDB.PDBParser(QUIET=True)
    xray_structure = parser.get_structure('', xray_fn)
    pred_structure = parser.get_structure('', pred_fn)
    

    # A is reference
    chainA = next(iter((xray_structure[0].get_chains())))
    chainB = next(iter((pred_structure[0].get_chains())))

    # align
    residuesA = ''.join([AMINO_ACID_CODES.get(r.resname, 'X') for r in chainA.get_residues()])
    residuesB = ''.join([AMINO_ACID_CODES.get(r.resname, 'X') for r in chainB.get_residues()])

    aligner = PairwiseAligner()
    aligner.mode = 'global'
    alignments =  aligner.align(residuesA, residuesB)
    aligned = alignments[0].aligned

    atomsA = list(chainA.get_atoms())
    atomsB = list(chainB.get_atoms())

    atomsA = []
    atomsB = []
    residuesA = list(chainA.get_residues())
    residuesB = list(chainB.get_residues())
    for i,((t1,t2),(q1,q2)) in enumerate(zip(*aligned)):
        for j, (residueA, residueB) in enumerate(zip(residuesA[t1:t2], residuesB[q1:q2])):
            if residueA.resname != residueB.resname:
                print(f'{residueA.resname} != {residueB.resname}')
                continue
            try:
                atomsA.append(residueA['CA'].coord)
                atomsB.append(residueB['CA'].coord)
            except KeyError:
                print(f'No CA atom for {residueA.resname} or {residueB.resname}')
        
        if i < aligned.shape[1] - 1:
            if aligned[0,i][1] != aligned[0,i+1][0]:
                for k in range(aligned[0,i][1], aligned[0,i+1][0]+1):
                    try:
                        atomsA.append(residuesA[k]['CA'].coord)
                        atomsB.append(np.full(3, np.nan))
                    except KeyError:
                        continue
        elif aligned[0,i][1] != len(residuesA):
            for k in range(aligned[0,i][1], len(residuesA)):
                try:
                    atomsA.append(residuesA[k]['CA'].coord)
                    atomsB.append(np.full(3, np.nan))
                except KeyError:
                    continue

    atomsA = np.array(atomsA)
    atomsB = np.array(atomsB)

    # 273x1x3 - 273x3 = 273x273x3
    # norm(x) = sqrt(sum(x**2, axis=-1))
    pairwise_dists_A = np.linalg.norm(atomsA[:, None] - atomsA, axis=-1)
    pairwise_dists_B = np.linalg.norm(atomsB[:, None] - atomsB, axis=-1)

    # Compute lddt
    lddt = []
    local_atoms_mask = (pairwise_dists_A <= INCLUSION_RADIUS)
    n_local_atoms = local_atoms_mask.sum()
    dist_diff = np.abs(pairwise_dists_A - pairwise_dists_B)
    dist_diff[~local_atoms_mask] = np.inf   # Exclude atoms outside of the inclusion radius
    dist_diff[np.isnan(dist_diff)] = np.inf # Missing atoms are not preserved
    lddt = np.mean([(dist_diff < thresh).sum() / n_local_atoms for thresh in THRESHOLDS])
    
    return lddt

lddt = compute_lddt(da.xray_fn, da.predictions_dir / da.alphafold_id)

# %%
da.results[da.results.Model == protein_id]
# Out:
#             Model   GR#  GDT_TS   NP_P  RANK  Z-M1-GDT  Z-MA-GDT  GDT_HA  \
# 312  T1024TS337_5  337s   55.88  100.0   311       NaN      0.28   32.48
#
#      GDC_SC  GDC_ALL  ...  TMscore  Dali(raw)  FlexE    QSE  CAD_SS  \
# 312   15.84    28.03  ...     0.84     3879.9   4.28  35.88    0.28
#
#      MolPrb_clash  MolPrb_rotout  MolPrb_ramout  MolPrb_ramfv  lddt
# 312        146.53            4.4           1.97         94.58   NaN
#
# [1 rows x 45 columns]

# %%
for protein in proteins:
    da = DihedralAdherence(protein, [4,5,6,7], PDBMINE_URL, PROJECT_DIR, 
                           mode='ml', weights_file='ml_runs/best_model-kde_16-32_383.pt', device='cuda')
    da.load_results_da()
    da.results['lddt'] = np.nan
    for protein_id in da.protein_ids:
        lddt = compute_lddt(da.xray_fn, da.predictions_dir / protein_id)
        da.results.loc[da.results.Model == protein_id, 'lddt'] = lddt
        gdt = da.results.loc[da.results.Model == protein_id, 'GDT_TS'].values[0]
        print(f'{protein_id} lddt: {lddt:.02f}', f'gdt: {gdt}')
    da.results.to_csv(da.outdir / 'results-lddt.csv', index=False)
# Out:
# Initializing T1024 ...
# Results already exist
# Casp ID: T1024 	PDB: 6t1z
# Structure exists: 'pdb/pdb6t1z.ent'
# UniProt ID: Q48658
# T1024TS337_5 lddt: 0.65 gdt: 55.88
# T1024TS367_4 lddt: 0.75 gdt: 61.0
# T1024TS170_3 lddt: 0.25 gdt: 10.1
# T1024TS378_4 lddt: 0.59 gdt: 43.29
# T1024TS198_3 lddt: 0.65 gdt: 47.19
# T1024TS259_5 lddt: 0.61 gdt: 46.23
# T1024TS278_3 lddt: 0.72 gdt: 55.95
# T1024TS409_1 lddt: 0.78 gdt: 60.55
# T1024TS337_1 lddt: 0.68 gdt: 59.66
# T1024TS042_1 lddt: 0.76 gdt: 61.45
# T1024TS081_5 lddt: 0.59 gdt: 42.71
# T1024TS187_4 lddt: 0.75 gdt: 62.08
# T1024TS063_4 lddt: 0.45 gdt: 29.67
# T1024TS192_2 lddt: 0.68 gdt: 58.63
# T1024TS138_2 lddt: 0.72 gdt: 55.95
# T1024TS341_1 lddt: 0.67 gdt: 48.27
# T1024TS428_3 lddt: 0.71 gdt: 55.88
# T1024TS075_5 lddt: 0.65 gdt: 48.21
# T1024TS334_3 lddt: 0.77 gdt: 61.7
# T1024TS005_1 lddt: 0.79 gdt: 60.61
# T1024TS071_3 lddt: 0.74 gdt: 60.61
# T1024TS138_1 lddt: 0.72 gdt: 56.71
# T1024TS226_4 lddt: 0.75 gdt: 64.64
# T1024TS487_4 lddt: 0.76 gdt: 59.08
# T1024TS050_1 lddt: 0.66 gdt: 48.21
# T1024TS018_4 lddt: 0.77 gdt: 60.23
# T1024TS014_3 lddt: 0.63 gdt: 48.59
# T1024TS473_5 lddt: 0.79 gdt: 59.91
# T1024TS328_1 lddt: 0.74 gdt: 61.19
# T1024TS062_2 lddt: 0.78 gdt: 60.42
# T1024TS042_3 lddt: 0.72 gdt: 60.04
# T1024TS209_2 lddt: 0.80 gdt: 61.32
# T1024TS032_5 lddt: 0.80 gdt: 61.45
# T1024TS200_5 lddt: 0.74 gdt: 58.63
# T1024TS187_3 lddt: 0.65 gdt: 47.06
# T1024TS277_1 lddt: 0.44 gdt: 32.48
# T1024TS498_5 lddt: 0.80 gdt: 61.32
# T1024TS473_3 lddt: 0.81 gdt: 61.83
# T1024TS131_4 lddt: 0.33 gdt: 11.51
# T1024TS278_1 lddt: 0.75 gdt: 59.91
# T1024TS473_1 lddt: 0.81 gdt: 62.08
# T1024TS209_4 lddt: 0.80 gdt: 61.96
# T1024TS198_4 lddt: 0.65 gdt: 47.51
# T1024TS378_3 lddt: 0.59 gdt: 43.22
# T1024TS183_1 lddt: 0.73 gdt: 58.25
# T1024TS377_2 lddt: 0.78 gdt: 59.46
# T1024TS328_3 lddt: 0.75 gdt: 61.12
# T1024TS435_2 lddt: 0.75 gdt: 58.76
# T1024TS435_4 lddt: 0.74 gdt: 58.89
# T1024TS013_1 lddt: 0.74 gdt: 57.55
# T1024TS278_2 lddt: 0.71 gdt: 55.88
# T1024TS354_3 lddt: 0.77 gdt: 61.0
# T1024TS467_2 lddt: 0.43 gdt: 31.27
# T1024TS435_1 lddt: 0.75 gdt: 59.21
# T1024TS075_3 lddt: 0.67 gdt: 48.34
# T1024TS253_5 lddt: 0.65 gdt: 58.25
# T1024TS070_4 lddt: 0.63 gdt: 47.12
# T1024TS339_2 lddt: 0.75 gdt: 56.71
# T1024TS354_1 lddt: 0.77 gdt: 60.87
# T1024TS342_2 lddt: 0.26 gdt: 8.76
# T1024TS004_4 lddt: 0.49 gdt: 34.34
# T1024TS062_4 lddt: 0.78 gdt: 59.46
# T1024TS472_2 lddt: 0.80 gdt: 63.04
# T1024TS039_4 lddt: 0.77 gdt: 60.87
# T1024TS033_3 lddt: 0.60 gdt: 53.01
# T1024TS071_4 lddt: 0.74 gdt: 60.68
# T1024TS125_3 lddt: 0.73 gdt: 57.29
# T1024TS039_3 lddt: 0.75 gdt: 59.21
# T1024TS326_4 lddt: 0.77 gdt: 61.06
# T1024TS304_1 lddt: 0.78 gdt: 62.34
# T1024TS220_5 lddt: 0.77 gdt: 60.68
# T1024TS032_4 lddt: 0.80 gdt: 61.57
# T1024TS151_2 lddt: 0.57 gdt: 41.37
# T1024TS328_2 lddt: 0.75 gdt: 61.32
# T1024TS026_5 lddt: 0.75 gdt: 61.0
# T1024TS288_1 lddt: 0.77 gdt: 59.59
# T1024TS200_4 lddt: 0.63 gdt: 46.8
# T1024TS018_3 lddt: 0.77 gdt: 59.85
# T1024TS031_3 lddt: 0.77 gdt: 61.0
# T1024TS473_2 lddt: 0.80 gdt: 60.87
# T1024TS498_2 lddt: 0.81 gdt: 62.08
# T1024TS323_5 lddt: 0.68 gdt: 55.05
# T1024TS301_3 lddt: 0.62 gdt: 56.14
# T1024TS259_4 lddt: 0.62 gdt: 47.57
# T1024TS403_5 lddt: 0.79 gdt: 59.91
# T1024TS367_1 lddt: 0.74 gdt: 61.19
# T1024TS226_5 lddt: 0.73 gdt: 65.73
# T1024TS301_4 lddt: 0.62 gdt: 53.33
# T1024TS129_1 lddt: 0.77 gdt: 58.25
# T1024TS472_5 lddt: 0.78 gdt: 59.27
# T1024TS061_5 lddt: 0.75 gdt: 58.25
# T1024TS193_1 lddt: 0.78 gdt: 57.16
# T1024TS140_3 lddt: 0.78 gdt: 60.42
# T1024TS339_4 lddt: 0.78 gdt: 55.56
# T1024TS096_3 lddt: 0.65 gdt: 47.38
# T1024TS420_5 lddt: 0.79 gdt: 60.61
# T1024TS427_1 lddt: 0.84 gdt: 60.29
# T1024TS314_3 lddt: 0.71 gdt: 59.72
# T1024TS138_3 lddt: 0.72 gdt: 56.2
# T1024TS259_2 lddt: 0.60 gdt: 44.69
# T1024TS403_1 lddt: 0.81 gdt: 62.08
# T1024TS170_1 lddt: 0.40 gdt: 23.59
# T1024TS375_4 lddt: 0.80 gdt: 61.96
# T1024TS125_1 lddt: 0.74 gdt: 57.55
# T1024TS343_4 lddt: 0.81 gdt: 62.21
# T1024TS488_1 lddt: 0.79 gdt: 60.87
# T1024TS335_5 lddt: 0.71 gdt: 59.78
# T1024TS242_3 lddt: 0.36 gdt: 15.03
# T1024TS013_2 lddt: 0.71 gdt: 56.78
# T1024TS063_2 lddt: 0.38 gdt: 28.0
# T1024TS238_2 lddt: 0.78 gdt: 60.42
# T1024TS063_1 lddt: 0.38 gdt: 23.91
# T1024TS326_2 lddt: 0.77 gdt: 60.68
# T1024TS183_5 lddt: 0.73 gdt: 58.31
# T1024TS050_2 lddt: 0.67 gdt: 50.19
# T1024TS293_5 lddt: 0.80 gdt: 61.45
# T1024TS067_2 lddt: 0.78 gdt: 57.16
# T1024TS217_2 lddt: 0.74 gdt: 56.59
# T1024TS009_5 lddt: 0.79 gdt: 60.55
# T1024TS334_4 lddt: 0.72 gdt: 57.42
# T1024TS472_4 lddt: 0.79 gdt: 62.21
# T1024TS018_1 lddt: 0.78 gdt: 59.91
# T1024TS341_3 lddt: 0.66 gdt: 50.45
# T1024TS472_1 lddt: 0.80 gdt: 63.3
# T1024TS081_1 lddt: 0.59 gdt: 43.29
# T1024TS101_4 lddt: 0.69 gdt: 49.55
# T1024TS031_5 lddt: 0.72 gdt: 53.33
# T1024TS392_5 lddt: 0.75 gdt: 56.65
# T1024TS376_4 lddt: 0.76 gdt: 58.18
# T1024TS343_5 lddt: 0.80 gdt: 61.32
# T1024TS488_2 lddt: 0.81 gdt: 62.08
# T1024TS009_2 lddt: 0.77 gdt: 60.87
# T1024TS319_2 lddt: 0.74 gdt: 60.81
# T1024TS368_5 lddt: 0.81 gdt: 62.08
# T1024TS018_5 lddt: 0.77 gdt: 59.91
# T1024TS014_4 lddt: 0.65 gdt: 45.27
# T1024TS277_3 lddt: 0.42 gdt: 29.54
# T1024TS427_5 lddt: 0.93 gdt: 71.67
# T1024TS061_2 lddt: 0.75 gdt: 58.5
# T1024TS192_5 lddt: 0.69 gdt: 56.91
# T1024TS252_3 lddt: 0.75 gdt: 60.93
# T1024TS226_3 lddt: 0.74 gdt: 58.63
# T1024TS242_5 lddt: 0.37 gdt: 14.96
# T1024TS067_1 lddt: 0.80 gdt: 61.96
# T1024TS354_4 lddt: 0.77 gdt: 61.06
# T1024TS480_4 lddt: 0.70 gdt: 56.14
# T1024TS324_2 lddt: 0.69 gdt: 54.86
# T1024TS305_1 lddt: 0.30 gdt: 8.76
# T1024TS031_1 lddt: 0.77 gdt: 61.83
# T1024TS070_1 lddt: 0.78 gdt: 57.16
# T1024TS198_2 lddt: 0.66 gdt: 47.76
# T1024TS488_5 lddt: 0.79 gdt: 60.36
# T1024TS335_4 lddt: 0.77 gdt: 61.45
# T1024TS288_3 lddt: 0.70 gdt: 57.67
# T1024TS339_3 lddt: 0.77 gdt: 55.44
# T1024TS319_3 lddt: 0.75 gdt: 61.12
# T1024TS200_1 lddt: 0.77 gdt: 61.0
# T1024TS427_3 lddt: 0.94 gdt: 79.22
# T1024TS101_1 lddt: 0.79 gdt: 60.87
# T1024TS375_5 lddt: 0.81 gdt: 62.21
# T1024TS420_1 lddt: 0.79 gdt: 61.12
# T1024TS009_1 lddt: 0.77 gdt: 58.12
# T1024TS288_4 lddt: 0.80 gdt: 61.96
# T1024TS125_4 lddt: 0.74 gdt: 57.8
# T1024TS480_1 lddt: 0.74 gdt: 58.7
# T1024TS317_5 lddt: 0.72 gdt: 57.55
# T1024TS369_3 lddt: 0.40 gdt: 32.03
# T1024TS081_2 lddt: 0.60 gdt: 40.79
# T1024TS476_1 lddt: 0.73 gdt: 56.71
# T1024TS360_3 lddt: 0.49 gdt: 26.15
# T1024TS437_3 lddt: 0.61 gdt: 45.08
# T1024TS192_4 lddt: 0.67 gdt: 56.97
# T1024TS305_3 lddt: 0.33 gdt: 11.89
# T1024TS067_4 lddt: 0.77 gdt: 57.61
# T1024TS062_5 lddt: 0.78 gdt: 59.59
# T1024TS427_2 lddt: 0.85 gdt: 59.85
# T1024TS129_5 lddt: 0.73 gdt: 57.35
# T1024TS354_2 lddt: 0.77 gdt: 60.68
# T1024TS026_4 lddt: 0.75 gdt: 57.23
# T1024TS288_2 lddt: 0.77 gdt: 59.59
# T1024TS005_2 lddt: 0.78 gdt: 60.42
# T1024TS033_2 lddt: 0.57 gdt: 47.63
# T1024TS328_5 lddt: 0.75 gdt: 60.93
# T1024TS252_5 lddt: 0.69 gdt: 57.74
# T1024TS198_1 lddt: 0.66 gdt: 48.02
# T1024TS014_1 lddt: 0.63 gdt: 47.38
# T1024TS362_4 lddt: 0.33 gdt: 10.68
# T1024TS460_3 lddt: 0.56 gdt: 43.09
# T1024TS097_2 lddt: 0.70 gdt: 55.24
# T1024TS187_1 lddt: 0.66 gdt: 46.8
# T1024TS183_3 lddt: 0.73 gdt: 58.5
# T1024TS252_2 lddt: 0.65 gdt: 47.25
# T1024TS379_1 lddt: 0.80 gdt: 61.96
# T1024TS125_2 lddt: 0.74 gdt: 58.5
# T1024TS081_4 lddt: 0.58 gdt: 42.65
# T1024TS467_3 lddt: 0.46 gdt: 33.89
# T1024TS488_3 lddt: 0.79 gdt: 59.53
# T1024TS031_4 lddt: 0.77 gdt: 61.0
# T1024TS200_3 lddt: 0.63 gdt: 46.8
# T1024TS343_3 lddt: 0.81 gdt: 62.08
# T1024TS305_5 lddt: 0.33 gdt: 15.6
# T1024TS170_2 lddt: 0.40 gdt: 23.79
# T1024TS362_2 lddt: 0.76 gdt: 59.46
# T1024TS403_2 lddt: 0.80 gdt: 60.87
# T1024TS033_1 lddt: 0.53 gdt: 37.66
# T1024TS242_1 lddt: 0.37 gdt: 15.03
# T1024TS362_1 lddt: 0.76 gdt: 60.49
# T1024TS293_1 lddt: 0.79 gdt: 61.57
# T1024TS301_5 lddt: 0.61 gdt: 52.17
# T1024TS319_5 lddt: 0.74 gdt: 61.19
# T1024TS498_4 lddt: 0.80 gdt: 61.64
# T1024TS024_2 lddt: 0.75 gdt: 59.97
# T1024TS257_4 lddt: 0.77 gdt: 60.68
# T1024TS427_4 lddt: 0.88 gdt: 65.22
# T1024TS487_2 lddt: 0.75 gdt: 56.46
# T1024TS131_3 lddt: 0.39 gdt: 21.36
# T1024TS437_4 lddt: 0.61 gdt: 45.27
# T1024TS216_1 lddt: 0.81 gdt: 62.21
# T1024TS170_4 lddt: 0.25 gdt: 9.46
# T1024TS183_4 lddt: 0.73 gdt: 57.74
# T1024TS151_1 lddt: 0.51 gdt: 42.01
# T1024TS420_4 lddt: 0.79 gdt: 61.0
# T1024TS062_1 lddt: 0.79 gdt: 60.61
# T1024TS252_1 lddt: 0.66 gdt: 47.25
# T1024TS340_1 lddt: 0.60 gdt: 43.41
# T1024TS253_2 lddt: 0.76 gdt: 60.81
# T1024TS015_1 lddt: 0.80 gdt: 61.96
# T1024TS061_3 lddt: 0.75 gdt: 58.31
# T1024TS460_2 lddt: 0.60 gdt: 47.19
# T1024TS226_2 lddt: 0.75 gdt: 60.1
# T1024TS340_2 lddt: 0.60 gdt: 43.41
# T1024TS183_2 lddt: 0.73 gdt: 58.44
# T1024TS467_1 lddt: 0.42 gdt: 30.5
# T1024TS209_5 lddt: 0.81 gdt: 62.21
# T1024TS013_4 lddt: 0.71 gdt: 56.14
# T1024TS039_1 lddt: 0.75 gdt: 57.23
# T1024TS323_4 lddt: 0.66 gdt: 52.49
# T1024TS138_5 lddt: 0.71 gdt: 54.67
# T1024TS081_3 lddt: 0.60 gdt: 44.18
# T1024TS334_1 lddt: 0.77 gdt: 61.45
# T1024TS075_4 lddt: 0.65 gdt: 46.23
# T1024TS324_1 lddt: 0.75 gdt: 61.45
# T1024TS004_3 lddt: 0.48 gdt: 34.08
# T1024TS217_5 lddt: 0.29 gdt: 8.44
# T1024TS334_5 lddt: 0.74 gdt: 58.12
# T1024TS277_2 lddt: 0.42 gdt: 29.54
# T1024TS319_1 lddt: 0.75 gdt: 60.61
# T1024TS437_5 lddt: 0.60 gdt: 44.05
# T1024TS362_3 lddt: 0.76 gdt: 58.63
# T1024TS129_2 lddt: 0.76 gdt: 61.45
# T1024TS376_5 lddt: 0.71 gdt: 55.75
# T1024TS063_3 lddt: 0.45 gdt: 30.11
# T1024TS317_1 lddt: 0.71 gdt: 54.86
# T1024TS257_1 lddt: 0.80 gdt: 61.96
# T1024TS075_1 lddt: 0.67 gdt: 47.06
# T1024TS254_4 lddt: 0.68 gdt: 61.57
# T1024TS360_4 lddt: 0.49 gdt: 33.76
# T1024TS428_1 lddt: 0.70 gdt: 40.47
# T1024TS319_4 lddt: 0.75 gdt: 61.7
# T1024TS193_3 lddt: 0.63 gdt: 46.8
# T1024TS004_5 lddt: 0.49 gdt: 34.34
# T1024TS351_3 lddt: 0.75 gdt: 56.71
# T1024TS360_2 lddt: 0.54 gdt: 37.79
# T1024TS238_4 lddt: 0.76 gdt: 57.74
# T1024TS437_1 lddt: 0.61 gdt: 45.01
# T1024TS032_1 lddt: 0.77 gdt: 57.74
# T1024TS378_5 lddt: 0.59 gdt: 43.03
# T1024TS042_4 lddt: 0.58 gdt: 17.45
# T1024TS412_1 lddt: 0.52 gdt: 40.47
# T1024TS217_4 lddt: 0.64 gdt: 44.88
# T1024TS259_3 lddt: 0.61 gdt: 45.2
# T1024TS301_2 lddt: 0.61 gdt: 54.67
# T1024TS324_4 lddt: 0.73 gdt: 64.9
# T1024TS460_4 lddt: 0.66 gdt: 54.35
# T1024TS379_3 lddt: 0.77 gdt: 61.0
# T1024TS476_2 lddt: 0.72 gdt: 55.95
# T1024TS337_4 lddt: 0.64 gdt: 45.33
# T1024TS096_1 lddt: 0.66 gdt: 48.91
# T1024TS368_1 lddt: 0.77 gdt: 58.12
# T1024TS377_5 lddt: 0.78 gdt: 59.27
# T1024TS335_3 lddt: 0.73 gdt: 58.12
# T1024TS351_4 lddt: 0.77 gdt: 55.44
# T1024TS005_3 lddt: 0.78 gdt: 60.55
# T1024TS254_3 lddt: 0.67 gdt: 60.04
# T1024TS435_5 lddt: 0.75 gdt: 58.57
# T1024TS096_5 lddt: 0.65 gdt: 47.38
# T1024TS392_4 lddt: 0.76 gdt: 58.95
# T1024TS131_2 lddt: 0.32 gdt: 11.45
# T1024TS075_2 lddt: 0.66 gdt: 47.19
# T1024TS009_4 lddt: 0.79 gdt: 60.61
# T1024TS024_1 lddt: 0.75 gdt: 60.04
# T1024TS014_2 lddt: 0.63 gdt: 47.89
# T1024TS032_3 lddt: 0.80 gdt: 61.77
# T1024TS131_1 lddt: 0.34 gdt: 11.38
# T1024TS026_3 lddt: 0.78 gdt: 59.21
# T1024TS360_5 lddt: 0.51 gdt: 36.51
# T1024TS460_1 lddt: 0.65 gdt: 53.84
# T1024TS071_1 lddt: 0.73 gdt: 60.29
# T1024TS336_1 lddt: 0.50 gdt: 43.22
# T1024TS369_5 lddt: 0.40 gdt: 32.1
# T1024TS317_2 lddt: 0.72 gdt: 55.18
# T1024TS377_1 lddt: 0.78 gdt: 59.34
# T1024TS392_2 lddt: 0.76 gdt: 58.63
# T1024TS288_5 lddt: 0.72 gdt: 56.91
# T1024TS015_5 lddt: 0.72 gdt: 53.33
# T1024TS317_4 lddt: 0.72 gdt: 57.23
# T1024TS339_5 lddt: 0.77 gdt: 57.61
# T1024TS209_1 lddt: 0.81 gdt: 62.08
# T1024TS193_2 lddt: 0.71 gdt: 37.02
# T1024TS140_1 lddt: 0.79 gdt: 60.61
# T1024TS217_1 lddt: 0.79 gdt: 60.81
# T1024TS050_4 lddt: 0.65 gdt: 50.26
# T1024TS220_1 lddt: 0.77 gdt: 60.93
# T1024TS314_1 lddt: 0.74 gdt: 58.31
# T1024TS368_2 lddt: 0.79 gdt: 60.61
# T1024TS376_2 lddt: 0.67 gdt: 58.38
# T1024TS050_3 lddt: 0.66 gdt: 47.76
# T1024TS131_5 lddt: 0.36 gdt: 14.51
# T1024TS062_3 lddt: 0.78 gdt: 60.55
# T1024TS018_2 lddt: 0.77 gdt: 60.04
# T1024TS222_2 lddt: 0.74 gdt: 59.46
# T1024TS097_1 lddt: 0.70 gdt: 55.56
# T1024TS379_2 lddt: 0.78 gdt: 60.42
# T1024TS460_5 lddt: 0.64 gdt: 52.56
# T1024TS129_4 lddt: 0.75 gdt: 60.74
# T1024TS097_4 lddt: 0.70 gdt: 55.56
# T1024TS323_3 lddt: 0.67 gdt: 52.62
# T1024TS367_5 lddt: 0.75 gdt: 60.93
# T1024TS326_5 lddt: 0.77 gdt: 61.0
# T1024TS125_5 lddt: 0.73 gdt: 56.97
# T1024TS096_2 lddt: 0.67 gdt: 49.04
# T1024TS420_3 lddt: 0.79 gdt: 60.61
# T1024TS209_3 lddt: 0.80 gdt: 61.64
# T1024TS192_3 lddt: 0.59 gdt: 52.3
# T1024TS375_2 lddt: 0.80 gdt: 61.32
# T1024TS254_1 lddt: 0.68 gdt: 61.51
# T1024TS015_4 lddt: 0.80 gdt: 61.64
# T1024TS377_3 lddt: 0.78 gdt: 59.59
# T1024TS220_3 lddt: 0.77 gdt: 60.93
# T1024TS435_3 lddt: 0.75 gdt: 58.76
# T1024TS067_5 lddt: 0.75 gdt: 56.71
# T1024TS257_2 lddt: 0.75 gdt: 56.71
# T1024TS472_3 lddt: 0.79 gdt: 62.28
# T1024TS253_3 lddt: 0.75 gdt: 61.32
# T1024TS379_5 lddt: 0.75 gdt: 56.46
# T1024TS252_4 lddt: 0.65 gdt: 47.19
# T1024TS140_5 lddt: 0.63 gdt: 51.15
# T1024TS368_3 lddt: 0.77 gdt: 60.68
# T1024TS375_3 lddt: 0.80 gdt: 61.64
# T1024TS314_2 lddt: 0.69 gdt: 54.16
# T1024TS487_1 lddt: 0.75 gdt: 57.23
# T1024TS293_3 lddt: 0.79 gdt: 61.32
# T1024TS198_5 lddt: 0.73 gdt: 56.27
# T1024TS004_1 lddt: 0.48 gdt: 34.14
# T1024TS403_3 lddt: 0.81 gdt: 61.83
# T1024TS238_5 lddt: 0.77 gdt: 58.12
# T1024TS005_4 lddt: 0.78 gdt: 59.46
# T1024TS192_1 lddt: 0.72 gdt: 59.78
# T1024TS067_3 lddt: 0.77 gdt: 55.44
# T1024TS323_2 lddt: 0.66 gdt: 52.62
# T1024TS254_2 lddt: 0.68 gdt: 62.47
# T1024TS428_5 lddt: 0.81 gdt: 62.08
# T1024TS187_5 lddt: 0.69 gdt: 58.7
# T1024TS096_4 lddt: 0.65 gdt: 46.1
# T1024TS278_4 lddt: 0.73 gdt: 59.02
# T1024TS326_1 lddt: 0.77 gdt: 60.87
# T1024TS480_5 lddt: 0.70 gdt: 56.52
# T1024TS339_1 lddt: 0.80 gdt: 61.96
# T1024TS004_2 lddt: 0.48 gdt: 34.14
# T1024TS324_5 lddt: 0.59 gdt: 17.84
# T1024TS343_2 lddt: 0.80 gdt: 61.64
# T1024TS323_1 lddt: 0.66 gdt: 52.75
# T1024TS305_2 lddt: 0.31 gdt: 9.53
# T1024TS220_2 lddt: 0.77 gdt: 60.81
# T1024TS480_3 lddt: 0.70 gdt: 56.71
# T1024TS378_2 lddt: 0.59 gdt: 43.93
# T1024TS013_3 lddt: 0.70 gdt: 56.65
# T1024TS377_4 lddt: 0.77 gdt: 59.14
# T1024TS392_1 lddt: 0.75 gdt: 57.67
# T1024TS369_4 lddt: 0.40 gdt: 31.84
# T1024TS015_2 lddt: 0.81 gdt: 62.08
# T1024TS293_2 lddt: 0.79 gdt: 61.57
# T1024TS317_3 lddt: 0.72 gdt: 56.14
# T1024TS487_3 lddt: 0.76 gdt: 60.29
# T1024TS403_4 lddt: 0.78 gdt: 59.46
# T1024TS033_5 lddt: 0.51 gdt: 33.31
# T1024TS014_5 lddt: 0.63 gdt: 46.35
# T1024TS437_2 lddt: 0.61 gdt: 44.44
# T1024TS488_4 lddt: 0.80 gdt: 61.96
# T1024TS063_5 lddt: 0.20 gdt: 9.02
# T1024TS392_3 lddt: 0.75 gdt: 61.0
# T1024TS196_1 lddt: 0.35 gdt: 11.12
# T1024TS050_5 lddt: 0.65 gdt: 48.21
# T1024TS473_4 lddt: 0.78 gdt: 59.46
# T1024TS042_5 lddt: 0.70 gdt: 40.47
# T1024TS305_4 lddt: 0.36 gdt: 12.6
# T1024TS013_5 lddt: 0.75 gdt: 60.55
# T1024TS420_2 lddt: 0.79 gdt: 60.81
# T1024TS314_4 lddt: 0.70 gdt: 55.37
# T1024TS337_3 lddt: 0.64 gdt: 47.38
# T1024TS222_4 lddt: 0.74 gdt: 58.82
# T1024TS242_4 lddt: 0.37 gdt: 14.96
# T1024TS369_2 lddt: 0.40 gdt: 32.03
# T1024TS293_4 lddt: 0.79 gdt: 61.0
# T1024TS032_2 lddt: 0.80 gdt: 61.89
# T1024TS026_2 lddt: 0.79 gdt: 60.61
# T1024TS253_4 lddt: 0.63 gdt: 49.3
# T1024TS335_2 lddt: 0.69 gdt: 54.16
# T1024TS314_5 lddt: 0.71 gdt: 55.44
# T1024TS376_3 lddt: 0.72 gdt: 53.58
# T1024TS254_5 lddt: 0.67 gdt: 61.96
# T1024TS220_4 lddt: 0.77 gdt: 60.81
# T1024TS200_2 lddt: 0.77 gdt: 61.0
# T1024TS097_5 lddt: 0.70 gdt: 55.95
# T1024TS140_2 lddt: 0.78 gdt: 61.12
# T1024TS257_5 lddt: 0.78 gdt: 55.56
# T1024TS376_1 lddt: 0.71 gdt: 53.13
# T1024TS070_2 lddt: 0.71 gdt: 37.02
# T1024TS015_3 lddt: 0.75 gdt: 56.71
# T1024TS335_1 lddt: 0.77 gdt: 61.19
# T1024TS498_1 lddt: 0.78 gdt: 55.56
# T1024TS487_5 lddt: 0.75 gdt: 59.46
# T1024TS031_2 lddt: 0.76 gdt: 62.47
# T1024TS324_3 lddt: 0.75 gdt: 65.15
# T1024TS101_5 lddt: 0.78 gdt: 60.74
# T1024TS140_4 lddt: 0.78 gdt: 60.55
# T1024TS026_1 lddt: 0.81 gdt: 62.15
# T1024TS428_2 lddt: 0.77 gdt: 57.61
# T1024TS378_1 lddt: 0.59 gdt: 42.65
# T1024TS042_2 lddt: 0.69 gdt: 50.64
# T1024TS193_4 lddt: 0.63 gdt: 47.12
# T1024TS129_3 lddt: 0.76 gdt: 61.25
# T1024TS369_1 lddt: 0.40 gdt: 30.63
# T1024TS257_3 lddt: 0.77 gdt: 57.61
# T1024TS448_1 lddt: 0.69 gdt: 56.84
# T1024TS005_5 lddt: 0.78 gdt: 59.34
# T1024TS253_1 lddt: 0.79 gdt: 61.51
# T1024TS334_2 lddt: 0.74 gdt: 58.18
# T1024TS138_4 lddt: 0.71 gdt: 54.67
# T1024TS070_5 lddt: 0.71 gdt: 37.85
# T1024TS061_4 lddt: 0.75 gdt: 57.99
# T1024TS362_5 lddt: 0.35 gdt: 13.11
# T1024TS351_5 lddt: 0.78 gdt: 55.56
# T1024TS151_3 lddt: 0.48 gdt: 36.89
# T1024TS337_2 lddt: 0.64 gdt: 45.59
# T1024TS071_5 lddt: 0.73 gdt: 60.55
# T1024TS498_3 lddt: 0.80 gdt: 61.96
# T1024TS222_1 lddt: 0.75 gdt: 61.0
# T1024TS480_2 lddt: 0.71 gdt: 56.46
# T1024TS242_2 lddt: 0.37 gdt: 14.96
# T1024TS351_2 lddt: 0.77 gdt: 57.61
# T1024TS328_4 lddt: 0.75 gdt: 61.0
# T1024TS367_2 lddt: 0.75 gdt: 61.32
# T1024TS360_1 lddt: 0.53 gdt: 35.36
# T1024TS226_1 lddt: 0.75 gdt: 61.38
# T1024TS379_4 lddt: 0.76 gdt: 59.08
# T1024TS187_2 lddt: 0.65 gdt: 46.8
# T1024TS278_5 lddt: 0.73 gdt: 56.71
# T1024TS343_1 lddt: 0.80 gdt: 61.96
# T1024TS428_4 lddt: 0.80 gdt: 61.64
# T1024TS367_3 lddt: 0.75 gdt: 61.12
# T1024TS101_2 lddt: 0.66 gdt: 46.87
# T1024TS301_1 lddt: 0.56 gdt: 45.4
# T1024TS217_3 lddt: 0.77 gdt: 59.08
# T1024TS326_3 lddt: 0.77 gdt: 61.0
# T1024TS033_4 lddt: 0.46 gdt: 34.46
# T1024TS259_1 lddt: 0.62 gdt: 47.25
# T1024TS193_5 lddt: 0.71 gdt: 37.85
# T1024TS101_3 lddt: 0.69 gdt: 48.91
# T1024TS354_5 lddt: 0.77 gdt: 61.0
# T1024TS070_3 lddt: 0.63 gdt: 46.8
# T1024TS222_5 lddt: 0.63 gdt: 45.33
# T1024TS222_3 lddt: 0.74 gdt: 61.19
# T1024TS169_1 lddt: 0.48 gdt: 27.68
# T1024TS097_3 lddt: 0.70 gdt: 55.69
# T1024TS009_3 lddt: 0.81 gdt: 62.08
# T1024TS375_1 lddt: 0.81 gdt: 62.08
# T1024TS341_2 lddt: 0.66 gdt: 49.04
# Initializing T1030 ...
# Results already exist
# Casp ID: T1030 	PDB: 6poo
# Structure exists: 'pdb/pdb6poo.ent'
# UniProt ID: Q8DWZ6
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS226_4 lddt: 0.57 gdt: 24.08
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS254_4 lddt: 0.70 gdt: 38.74
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS024_4 lddt: 0.65 gdt: 35.81
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS427_2 lddt: 0.93 gdt: 63.55
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS305_3 lddt: 0.37 gdt: 14.74
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS377_3 lddt: 0.72 gdt: 43.96
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS323_5 lddt: 0.66 gdt: 36.81
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS288_2 lddt: 0.54 gdt: 21.98
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS014_2 lddt: 0.40 gdt: 13.74
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS031_2 lddt: 0.64 gdt: 36.63
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS392_1 lddt: 0.65 gdt: 36.08
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS200_3 lddt: 0.48 gdt: 22.62
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS013_3 lddt: 0.66 gdt: 40.11
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS488_3 lddt: 0.74 gdt: 50.09
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS209_3 lddt: 0.64 gdt: 41.85
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS472_4 lddt: 0.70 gdt: 42.22
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS097_1 lddt: 0.57 gdt: 18.86
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS039_4 lddt: 0.71 gdt: 39.29
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS437_1 lddt: 0.40 gdt: 15.84
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS067_1 lddt: 0.67 gdt: 41.03
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS042_5 lddt: 0.41 gdt: 16.21
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS151_1 lddt: 0.43 gdt: 12.36
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS334_3 lddt: 0.63 gdt: 44.78
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS343_1 lddt: 0.50 gdt: 24.82
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS129_1 lddt: 0.65 gdt: 37.36
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS050_1 lddt: 0.40 gdt: 15.75
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS220_2 lddt: 0.71 gdt: 44.14
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS238_1 lddt: 0.75 gdt: 50.92
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS343_2 lddt: 0.55 gdt: 25.46
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS169_1 lddt: 0.50 gdt: 19.05
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS013_5 lddt: 0.66 gdt: 40.75
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS067_4 lddt: 0.71 gdt: 43.59
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS129_5 lddt: 0.68 gdt: 43.41
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS460_5 lddt: 0.41 gdt: 15.57
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS071_4 lddt: 0.69 gdt: 31.32
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS392_4 lddt: 0.65 gdt: 36.81
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS026_5 lddt: 0.66 gdt: 37.82
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS050_2 lddt: 0.48 gdt: 12.27
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS187_5 lddt: 0.61 gdt: 29.85
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS473_1 lddt: 0.60 gdt: 35.53
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS336_1 lddt: 0.40 gdt: 15.57
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS075_2 lddt: 0.69 gdt: 43.41
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS140_4 lddt: 0.69 gdt: 43.41
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS061_3 lddt: 0.68 gdt: 42.31
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS319_3 lddt: 0.70 gdt: 40.2
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS377_5 lddt: 0.70 gdt: 43.68
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS075_1 lddt: 0.69 gdt: 44.6
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS342_1 lddt: 0.49 gdt: 15.2
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS427_1 lddt: 0.93 gdt: 63.0
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS498_1 lddt: 0.74 gdt: 44.05
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS254_5 lddt: 0.70 gdt: 45.51
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS101_1 lddt: 0.72 gdt: 40.75
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS238_3 lddt: 0.75 gdt: 50.64
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS458_1 lddt: 0.35 gdt: 8.33
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS334_2 lddt: 0.65 gdt: 43.96
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS032_2 lddt: 0.70 gdt: 44.51
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS032_3 lddt: 0.69 gdt: 42.67
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS063_4 lddt: 0.32 gdt: 10.99
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS369_4 lddt: 0.43 gdt: 9.07
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS304_5 lddt: 0.57 gdt: 28.94
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS192_2 lddt: 0.58 gdt: 29.85
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS337_1 lddt: 0.67 gdt: 40.38
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS288_5 lddt: 0.55 gdt: 25.46
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS319_5 lddt: 0.70 gdt: 40.75
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS343_5 lddt: 0.74 gdt: 50.09
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS460_4 lddt: 0.48 gdt: 13.55
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS293_4 lddt: 0.73 gdt: 45.42
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS032_4 lddt: 0.71 gdt: 39.1
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS326_2 lddt: 0.67 gdt: 41.67
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS009_4 lddt: 0.72 gdt: 43.96
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS220_1 lddt: 0.71 gdt: 43.77
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS301_5 lddt: 0.39 gdt: 11.9
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS377_1 lddt: 0.69 gdt: 40.57
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS326_3 lddt: 0.67 gdt: 42.03
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS101_4 lddt: 0.73 gdt: 40.84
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS238_2 lddt: 0.75 gdt: 49.82
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS196_1 lddt: 0.39 gdt: 14.84
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS428_5 lddt: 0.68 gdt: 35.62
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS317_5 lddt: 0.45 gdt: 13.1
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS305_2 lddt: 0.34 gdt: 14.65
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS314_4 lddt: 0.74 gdt: 49.36
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS373_2 lddt: 0.37 gdt: 13.83
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS050_3 lddt: 0.48 gdt: 12.27
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS070_4 lddt: 0.52 gdt: 19.87
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS198_2 lddt: 0.70 gdt: 43.86
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS304_3 lddt: 0.60 gdt: 28.94
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS369_2 lddt: 0.37 gdt: 10.26
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS259_3 lddt: 0.56 gdt: 20.42
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS277_1 lddt: 0.65 gdt: 40.57
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS257_1 lddt: 0.67 gdt: 41.03
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS376_1 lddt: 0.36 gdt: 10.16
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS024_5 lddt: 0.65 gdt: 36.08
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS367_3 lddt: 0.70 gdt: 41.76
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS498_3 lddt: 0.74 gdt: 50.09
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS319_2 lddt: 0.70 gdt: 37.64
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS376_5 lddt: 0.34 gdt: 12.73
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS009_3 lddt: 0.73 gdt: 44.69
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS129_3 lddt: 0.71 gdt: 45.33
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS067_2 lddt: 0.74 gdt: 45.6
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS437_4 lddt: 0.44 gdt: 18.32
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS428_4 lddt: 0.69 gdt: 44.96
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS448_1 lddt: 0.50 gdt: 18.32
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS317_2 lddt: 0.45 gdt: 11.72
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS476_2 lddt: 0.33 gdt: 6.68
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS257_5 lddt: 0.75 gdt: 53.94
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS250_1 lddt: 0.58 gdt: 23.35
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS335_1 lddt: 0.75 gdt: 47.8
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS453_2 lddt: 0.47 gdt: 21.43
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS140_5 lddt: 0.69 gdt: 44.96
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS360_4 lddt: 0.42 gdt: 18.32
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS026_3 lddt: 0.68 gdt: 39.65
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS075_4 lddt: 0.49 gdt: 22.53
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS097_5 lddt: 0.58 gdt: 20.7
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS323_4 lddt: 0.67 gdt: 36.26
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS226_1 lddt: 0.61 gdt: 37.36
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS187_3 lddt: 0.70 gdt: 39.01
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS096_2 lddt: 0.61 gdt: 31.14
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS220_3 lddt: 0.71 gdt: 44.05
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS293_5 lddt: 0.72 gdt: 46.43
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS288_1 lddt: 0.71 gdt: 38.09
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS379_3 lddt: 0.69 gdt: 42.49
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS031_5 lddt: 0.63 gdt: 34.8
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS326_5 lddt: 0.67 gdt: 41.58
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS278_2 lddt: 0.53 gdt: 25.27
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS487_5 lddt: 0.71 gdt: 43.59
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS377_4 lddt: 0.67 gdt: 41.21
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS368_4 lddt: 0.70 gdt: 42.22
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS140_2 lddt: 0.69 gdt: 44.96
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS368_5 lddt: 0.67 gdt: 41.58
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS032_5 lddt: 0.70 gdt: 42.03
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS013_1 lddt: 0.66 gdt: 40.75
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS259_4 lddt: 0.56 gdt: 20.15
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS222_2 lddt: 0.70 gdt: 41.76
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS097_4 lddt: 0.55 gdt: 18.5
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS379_1 lddt: 0.71 gdt: 39.29
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS304_1 lddt: 0.71 gdt: 37.36
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS328_2 lddt: 0.70 gdt: 42.4
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS317_1 lddt: 0.47 gdt: 15.29
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS024_2 lddt: 0.65 gdt: 36.08
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS351_2 lddt: 0.75 gdt: 53.94
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS379_2 lddt: 0.65 gdt: 40.11
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS217_4 lddt: 0.72 gdt: 48.26
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS487_2 lddt: 0.66 gdt: 36.26
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS252_4 lddt: 0.64 gdt: 41.12
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS420_2 lddt: 0.72 gdt: 44.14
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS437_5 lddt: 0.41 gdt: 14.65
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS487_1 lddt: 0.71 gdt: 39.84
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS193_1 lddt: 0.52 gdt: 23.08
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS062_5 lddt: 0.67 gdt: 41.21
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS428_2 lddt: 0.71 gdt: 43.59
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS369_3 lddt: 0.44 gdt: 15.11
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS362_2 lddt: 0.73 gdt: 46.52
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS351_5 lddt: 0.74 gdt: 44.05
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS096_3 lddt: 0.60 gdt: 25.64
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS375_1 lddt: 0.74 gdt: 41.94
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS052_1 lddt: 0.41 gdt: 18.96
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS238_5 lddt: 0.74 gdt: 50.09
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS138_3 lddt: 0.50 gdt: 12.73
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS314_2 lddt: 0.75 gdt: 45.15
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS200_4 lddt: 0.69 gdt: 42.49
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS031_3 lddt: 0.60 gdt: 31.14
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS222_3 lddt: 0.68 gdt: 39.47
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS005_1 lddt: 0.72 gdt: 43.96
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS259_1 lddt: 0.54 gdt: 20.33
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS071_5 lddt: 0.66 gdt: 30.22
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS220_5 lddt: 0.71 gdt: 43.59
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS252_3 lddt: 0.71 gdt: 39.29
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS403_4 lddt: 0.60 gdt: 35.53
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS009_1 lddt: 0.73 gdt: 44.78
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS460_2 lddt: 0.61 gdt: 31.32
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS125_5 lddt: 0.67 gdt: 35.53
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS314_5 lddt: 0.73 gdt: 45.24
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS222_5 lddt: 0.54 gdt: 20.7
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS473_3 lddt: 0.60 gdt: 34.8
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS277_5 lddt: 0.39 gdt: 19.23
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS070_2 lddt: 0.57 gdt: 28.66
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS031_1 lddt: 0.63 gdt: 34.8
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS259_5 lddt: 0.55 gdt: 20.97
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS317_3 lddt: 0.46 gdt: 14.38
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS193_4 lddt: 0.52 gdt: 26.74
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS328_4 lddt: 0.70 gdt: 42.22
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS335_4 lddt: 0.63 gdt: 45.05
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS488_1 lddt: 0.75 gdt: 46.24
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS187_2 lddt: 0.70 gdt: 36.35
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS293_3 lddt: 0.72 gdt: 43.86
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS026_4 lddt: 0.68 gdt: 39.47
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS339_3 lddt: 0.68 gdt: 39.65
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS254_1 lddt: 0.76 gdt: 56.04
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS488_4 lddt: 0.70 gdt: 41.94
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS259_2 lddt: 0.53 gdt: 19.5
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS473_2 lddt: 0.60 gdt: 34.34
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS226_3 lddt: 0.67 gdt: 38.74
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS498_2 lddt: 0.55 gdt: 25.46
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS198_5 lddt: 0.47 gdt: 17.03
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS360_1 lddt: 0.41 gdt: 18.68
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS277_2 lddt: 0.65 gdt: 40.57
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS192_4 lddt: 0.56 gdt: 29.58
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS278_4 lddt: 0.56 gdt: 24.73
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS216_1 lddt: 0.70 gdt: 42.22
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS238_4 lddt: 0.74 gdt: 40.75
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS368_2 lddt: 0.73 gdt: 44.87
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS420_3 lddt: 0.68 gdt: 35.81
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS304_4 lddt: 0.53 gdt: 25.46
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS192_5 lddt: 0.65 gdt: 35.81
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS129_4 lddt: 0.65 gdt: 37.45
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS351_1 lddt: 0.74 gdt: 50.09
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS257_3 lddt: 0.72 gdt: 43.96
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS360_5 lddt: 0.46 gdt: 15.38
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS343_4 lddt: 0.74 gdt: 41.94
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS200_1 lddt: 0.74 gdt: 45.6
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS024_3 lddt: 0.65 gdt: 36.35
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS427_4 lddt: 0.77 gdt: 57.23
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS014_4 lddt: 0.41 gdt: 14.56
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS319_1 lddt: 0.71 gdt: 39.29
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS458_2 lddt: 0.35 gdt: 9.52
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS071_2 lddt: 0.63 gdt: 36.26
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS428_1 lddt: 0.69 gdt: 43.5
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS005_2 lddt: 0.69 gdt: 40.57
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS015_4 lddt: 0.53 gdt: 19.5
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS014_3 lddt: 0.41 gdt: 13.83
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS334_4 lddt: 0.64 gdt: 43.68
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS039_2 lddt: 0.74 gdt: 45.6
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS379_5 lddt: 0.70 gdt: 44.32
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS403_5 lddt: 0.60 gdt: 34.07
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS222_4 lddt: 0.68 gdt: 39.65
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS252_2 lddt: 0.69 gdt: 36.45
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS480_1 lddt: 0.42 gdt: 18.32
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS453_1 lddt: 0.60 gdt: 28.94
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS081_3 lddt: 0.38 gdt: 14.93
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS387_1 lddt: 0.73 gdt: 45.51
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS250_4 lddt: 0.55 gdt: 22.25
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS375_3 lddt: 0.74 gdt: 50.09
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS198_3 lddt: 0.70 gdt: 44.69
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS376_4 lddt: 0.45 gdt: 15.2
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS427_3 lddt: 0.76 gdt: 53.39
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS488_5 lddt: 0.74 gdt: 45.97
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS362_1 lddt: 0.73 gdt: 45.51
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS138_4 lddt: 0.50 gdt: 12.64
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS476_3 lddt: 0.55 gdt: 25.46
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS052_2 lddt: 0.41 gdt: 18.96
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS288_3 lddt: 0.71 gdt: 42.67
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS063_5 lddt: 0.28 gdt: 9.34
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS324_4 lddt: 0.43 gdt: 16.76
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS013_4 lddt: 0.66 gdt: 39.93
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS015_2 lddt: 0.75 gdt: 49.82
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS096_5 lddt: 0.61 gdt: 27.93
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS138_1 lddt: 0.50 gdt: 13.37
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS334_1 lddt: 0.66 gdt: 43.86
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS187_1 lddt: 0.70 gdt: 36.26
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS335_3 lddt: 0.65 gdt: 44.41
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS050_4 lddt: 0.40 gdt: 14.84
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS033_1 lddt: 0.28 gdt: 12.45
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS042_3 lddt: 0.43 gdt: 16.03
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS435_5 lddt: 0.65 gdt: 37.55
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS326_4 lddt: 0.67 gdt: 41.58
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS337_3 lddt: 0.51 gdt: 25.46
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS062_4 lddt: 0.69 gdt: 40.66
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS301_1 lddt: 0.47 gdt: 14.56
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS193_3 lddt: 0.58 gdt: 20.6
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS362_5 lddt: 0.57 gdt: 31.04
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS301_2 lddt: 0.49 gdt: 16.03
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS487_3 lddt: 0.70 gdt: 44.32
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS305_5 lddt: 0.36 gdt: 14.93
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS101_5 lddt: 0.72 gdt: 38.83
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS217_2 lddt: 0.44 gdt: 19.14
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS319_4 lddt: 0.71 gdt: 37.45
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS339_2 lddt: 0.67 gdt: 41.03
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS217_1 lddt: 0.46 gdt: 23.26
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS278_3 lddt: 0.55 gdt: 25.46
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS420_5 lddt: 0.71 gdt: 40.11
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS013_2 lddt: 0.65 gdt: 39.29
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS052_4 lddt: 0.41 gdt: 18.96
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS337_5 lddt: 0.50 gdt: 19.69
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS183_1 lddt: 0.74 gdt: 45.6
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS170_3 lddt: 0.39 gdt: 9.89
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS324_5 lddt: 0.43 gdt: 15.66
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS367_2 lddt: 0.70 gdt: 42.4
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS428_3 lddt: 0.69 gdt: 44.96
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS209_1 lddt: 0.64 gdt: 42.12
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS015_1 lddt: 0.74 gdt: 41.94
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS254_3 lddt: 0.73 gdt: 46.15
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS403_2 lddt: 0.64 gdt: 42.12
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS063_2 lddt: 0.25 gdt: 9.8
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS304_2 lddt: 0.55 gdt: 21.98
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS324_3 lddt: 0.45 gdt: 20.05
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS193_2 lddt: 0.58 gdt: 20.7
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS125_2 lddt: 0.67 gdt: 34.8
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS293_2 lddt: 0.74 gdt: 51.65
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS192_1 lddt: 0.64 gdt: 39.29
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS317_4 lddt: 0.47 gdt: 14.93
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS367_1 lddt: 0.70 gdt: 41.94
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS435_3 lddt: 0.65 gdt: 36.63
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS334_5 lddt: 0.64 gdt: 43.22
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS373_1 lddt: 0.36 gdt: 11.72
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS373_3 lddt: 0.38 gdt: 13.74
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS062_1 lddt: 0.72 gdt: 43.96
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS253_4 lddt: 0.54 gdt: 22.07
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS125_1 lddt: 0.68 gdt: 40.66
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS339_1 lddt: 0.75 gdt: 53.94
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS062_3 lddt: 0.69 gdt: 40.57
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS125_3 lddt: 0.68 gdt: 37.73
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS328_5 lddt: 0.70 gdt: 42.22
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS129_2 lddt: 0.68 gdt: 44.51
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS252_5 lddt: 0.53 gdt: 21.98
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS305_4 lddt: 0.36 gdt: 12.0
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS032_1 lddt: 0.72 gdt: 45.6
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS435_1 lddt: 0.65 gdt: 37.55
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS200_2 lddt: 0.41 gdt: 18.96
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS335_2 lddt: 0.65 gdt: 39.1
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS138_5 lddt: 0.49 gdt: 13.55
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS200_5 lddt: 0.45 gdt: 17.12
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS063_3 lddt: 0.32 gdt: 11.45
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS070_1 lddt: 0.57 gdt: 29.21
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS050_5 lddt: 0.40 gdt: 14.84
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS498_5 lddt: 0.74 gdt: 41.94
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS403_3 lddt: 0.64 gdt: 42.49
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS138_2 lddt: 0.49 gdt: 12.0
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS140_3 lddt: 0.70 gdt: 44.78
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS042_2 lddt: 0.44 gdt: 19.23
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS252_1 lddt: 0.70 gdt: 37.82
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS342_2 lddt: 0.49 gdt: 16.85
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS257_2 lddt: 0.71 gdt: 39.29
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS472_5 lddt: 0.69 gdt: 42.49
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS192_3 lddt: 0.66 gdt: 34.89
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS339_5 lddt: 0.71 gdt: 39.29
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS253_3 lddt: 0.66 gdt: 41.58
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS031_4 lddt: 0.55 gdt: 22.53
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS209_2 lddt: 0.64 gdt: 42.03
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS379_4 lddt: 0.70 gdt: 43.86
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS453_3 lddt: 0.45 gdt: 21.98
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS097_2 lddt: 0.59 gdt: 22.89
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS362_3 lddt: 0.73 gdt: 45.88
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS170_1 lddt: 0.39 gdt: 9.43
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS341_1 lddt: 0.55 gdt: 17.95
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS314_1 lddt: 0.78 gdt: 48.08
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS437_3 lddt: 0.44 gdt: 18.5
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS081_2 lddt: 0.39 gdt: 16.12
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS498_4 lddt: 0.75 gdt: 53.94
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS369_5 lddt: 0.44 gdt: 15.11
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS376_2 lddt: 0.39 gdt: 15.48
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS341_2 lddt: 0.39 gdt: 18.5
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS039_3 lddt: 0.70 gdt: 41.94
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS250_5 lddt: 0.52 gdt: 24.63
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS392_2 lddt: 0.66 gdt: 36.81
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS063_1 lddt: 0.33 gdt: 13.74
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS278_5 lddt: 0.50 gdt: 24.82
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS209_5 lddt: 0.64 gdt: 42.49
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS170_4 lddt: 0.40 gdt: 9.25
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS170_2 lddt: 0.40 gdt: 9.25
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS250_3 lddt: 0.59 gdt: 28.2
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS375_2 lddt: 0.74 gdt: 45.6
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS277_3 lddt: 0.65 gdt: 37.27
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS324_1 lddt: 0.44 gdt: 18.86
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS026_1 lddt: 0.69 gdt: 40.38
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS005_3 lddt: 0.70 gdt: 43.68
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS326_1 lddt: 0.67 gdt: 41.03
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS070_5 lddt: 0.57 gdt: 29.12
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS061_5 lddt: 0.67 gdt: 42.03
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS101_2 lddt: 0.60 gdt: 23.08
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS096_1 lddt: 0.61 gdt: 28.48
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS480_5 lddt: 0.43 gdt: 17.49
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS342_3 lddt: 0.52 gdt: 18.22
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS305_1 lddt: 0.35 gdt: 13.0
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS420_1 lddt: 0.74 gdt: 46.15
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS277_4 lddt: 0.64 gdt: 41.3
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS468_1 lddt: 0.65 gdt: 40.11
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS328_1 lddt: 0.70 gdt: 41.94
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS187_4 lddt: 0.54 gdt: 29.67
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS351_4 lddt: 0.74 gdt: 41.94
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS342_4 lddt: 0.51 gdt: 18.41
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS293_1 lddt: 0.74 gdt: 51.01
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS314_3 lddt: 0.77 gdt: 47.34
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS376_3 lddt: 0.38 gdt: 13.92
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS009_5 lddt: 0.74 gdt: 45.79
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS337_2 lddt: 0.52 gdt: 25.46
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS257_4 lddt: 0.68 gdt: 39.65
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS460_1 lddt: 0.69 gdt: 42.49
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS339_4 lddt: 0.70 gdt: 43.77
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS254_2 lddt: 0.74 gdt: 45.33
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS052_5 lddt: 0.41 gdt: 18.86
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS341_4 lddt: 0.47 gdt: 11.9
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS217_5 lddt: 0.51 gdt: 26.1
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS337_4 lddt: 0.53 gdt: 18.41
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS253_5 lddt: 0.56 gdt: 29.49
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS039_1 lddt: 0.75 gdt: 50.92
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS324_2 lddt: 0.46 gdt: 17.12
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS222_1 lddt: 0.70 gdt: 42.22
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS209_4 lddt: 0.64 gdt: 42.49
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS097_3 lddt: 0.58 gdt: 21.43
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS026_2 lddt: 0.75 gdt: 50.92
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS375_4 lddt: 0.74 gdt: 50.09
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS014_5 lddt: 0.37 gdt: 11.17
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# T1030TS473_4 lddt: 0.60 gdt: 34.07
# MSE != MET
# MSE != MET
# MSE != MET
# MSE != MET
# ...
# T1058TS042_4-D2 lddt: 0.24 gdt: 55.74
# T1058TS125_4-D2 lddt: 0.29 gdt: 68.63
# T1058TS187_1-D2 lddt: 0.24 gdt: 53.73
# T1058TS362_4-D2 lddt: 0.13 gdt: 18.48
# T1058TS427_5-D2 lddt: 0.36 gdt: 93.17
# T1058TS336_1-D2 lddt: 0.11 gdt: 15.06
# T1058TS198_5-D2 lddt: 0.23 gdt: 37.42
# T1058TS360_3-D2 lddt: 0.16 gdt: 35.56
# T1058TS018_4-D2 lddt: 0.27 gdt: 62.89
# T1058TS187_2-D2 lddt: 0.24 gdt: 55.44
# T1058TS050_5-D2 lddt: 0.19 gdt: 41.92
# T1058TS097_4-D2 lddt: 0.22 gdt: 50.31
# T1058TS301_1-D2 lddt: 0.21 gdt: 54.19
# T1058TS427_2-D2 lddt: 0.36 gdt: 93.48
# T1058TS217_5-D2 lddt: 0.31 gdt: 76.4
# T1058TS033_2-D2 lddt: 0.07 gdt: 10.25
# T1058TS288_5-D2 lddt: 0.32 gdt: 81.83
# T1058TS458_1-D2 lddt: 0.07 gdt: 10.25
# T1058TS170_2-D2 lddt: 0.10 gdt: 12.27
# T1058TS428_1-D2 lddt: 0.15 gdt: 22.98
# T1058TS368_2-D2 lddt: 0.30 gdt: 73.45
# T1058TS015_2-D2 lddt: 0.32 gdt: 75.93
# T1058TS437_5-D2 lddt: 0.08 gdt: 11.8
# T1058TS070_3-D2 lddt: 0.14 gdt: 28.88
# T1058TS052_4-D2 lddt: 0.12 gdt: 18.94
# T1058TS376_1-D2 lddt: 0.20 gdt: 37.42
# T1058TS403_4-D2 lddt: 0.31 gdt: 73.45
# T1058TS480_2-D2 lddt: 0.29 gdt: 72.05
# T1058TS476_1-D2 lddt: 0.22 gdt: 49.53
# T1058TS220_5-D2 lddt: 0.32 gdt: 76.86
# T1058TS460_5-D2 lddt: 0.15 gdt: 25.93
# T1058TS042_5-D2 lddt: 0.27 gdt: 44.1
# T1058TS062_1-D2 lddt: 0.22 gdt: 56.83
# T1058TS063_1-D2 lddt: 0.07 gdt: 10.09
# T1058TS293_4-D2 lddt: 0.31 gdt: 77.64
# T1058TS193_5-D2 lddt: 0.30 gdt: 73.76
# T1058TS042_2-D2 lddt: 0.27 gdt: 57.45
# T1058TS187_3-D2 lddt: 0.25 gdt: 54.81
# T1058TS220_3-D2 lddt: 0.27 gdt: 62.27
# T1058TS314_1-D2 lddt: 0.27 gdt: 63.66
# T1058TS096_4-D2 lddt: 0.12 gdt: 15.99
# T1058TS368_5-D2 lddt: 0.31 gdt: 72.67
# T1058TS222_1-D2 lddt: 0.28 gdt: 63.82
# T1058TS242_1-D2 lddt: 0.05 gdt: 6.83
# T1058TS472_3-D2 lddt: 0.22 gdt: 55.59
# T1058TS096_3-D2 lddt: 0.12 gdt: 21.27
# T1058TS138_2-D2 lddt: 0.20 gdt: 32.45
# T1058TS062_3-D2 lddt: 0.22 gdt: 56.06
# T1058TS472_1-D2 lddt: 0.32 gdt: 75.93
# T1058TS183_3-D2 lddt: 0.27 gdt: 65.84
# T1058TS217_1-D2 lddt: 0.28 gdt: 70.03
# T1058TS061_1-D2 lddt: 0.31 gdt: 74.07
# T1058TS031_3-D2 lddt: 0.27 gdt: 63.82
# T1058TS483_2-D2 lddt: 0.25 gdt: 56.37
# T1058TS427_4-D2 lddt: 0.36 gdt: 94.25
# T1058TS369_4-D2 lddt: 0.09 gdt: 10.87
# T1058TS328_5-D2 lddt: 0.28 gdt: 63.51
# T1058TS259_4-D2 lddt: 0.15 gdt: 22.98
# T1058TS376_5-D2 lddt: 0.22 gdt: 55.9
# T1058TS032_3-D2 lddt: 0.31 gdt: 72.83
# T1058TS192_5-D2 lddt: 0.20 gdt: 48.6
# T1058TS170_1-D2 lddt: 0.10 gdt: 12.89
# T1058TS200_1-D2 lddt: 0.29 gdt: 69.88
# T1058TS200_5-D2 lddt: 0.32 gdt: 80.12
# T1058TS253_4-D2 lddt: 0.18 gdt: 35.71
# T1058TS009_2-D2 lddt: 0.31 gdt: 75.47
# T1058TS428_4-D2 lddt: 0.25 gdt: 60.09
# T1058TS498_5-D2 lddt: 0.31 gdt: 72.67
# T1058TS453_2-D2 lddt: 0.22 gdt: 50.62
# T1058TS319_5-D2 lddt: 0.26 gdt: 59.78
# T1058TS140_2-D2 lddt: 0.22 gdt: 56.83
# T1058TS032_4-D2 lddt: 0.28 gdt: 62.73
# T1058TS026_1-D2 lddt: 0.28 gdt: 63.82
# T1058TS183_2-D2 lddt: 0.30 gdt: 72.05
# T1058TS369_2-D2 lddt: 0.08 gdt: 12.58
# T1058TS259_2-D2 lddt: 0.14 gdt: 19.88
# T1058TS024_5-D2 lddt: 0.30 gdt: 70.03
# T1058TS050_4-D2 lddt: 0.19 gdt: 42.24
# T1058TS075_1-D2 lddt: 0.28 gdt: 65.22
# T1058TS061_4-D2 lddt: 0.22 gdt: 58.23
# T1058TS193_2-D2 lddt: 0.30 gdt: 74.22
# T1058TS337_3-D2 lddt: 0.12 gdt: 17.86
# T1058TS033_1-D2 lddt: 0.07 gdt: 10.09
# T1058TS428_3-D2 lddt: 0.13 gdt: 18.01
# T1058TS170_4-D2 lddt: 0.10 gdt: 12.11
# T1058TS319_4-D2 lddt: 0.26 gdt: 61.49
# T1058TS498_3-D2 lddt: 0.26 gdt: 60.09
# T1058TS453_1-D2 lddt: 0.22 gdt: 52.64
# T1058TS305_3-D2 lddt: 0.08 gdt: 12.73
# T1058TS392_1-D2 lddt: 0.29 gdt: 71.43
# T1058TS364_4-D2 lddt: 0.24 gdt: 54.66
# T1058TS032_2-D2 lddt: 0.27 gdt: 43.32
# T1058TS368_1-D2 lddt: 0.31 gdt: 75.47
# T1058TS498_2-D2 lddt: 0.32 gdt: 76.71
# T1058TS005_5-D2 lddt: 0.22 gdt: 54.97
# T1058TS277_5-D2 lddt: 0.27 gdt: 62.89
# T1058TS349_3-D2 lddt: 0.11 gdt: 14.29
# T1058TS101_5-D2 lddt: 0.29 gdt: 65.53
# T1058TS005_3-D2 lddt: 0.14 gdt: 19.72
# T1058TS238_4-D2 lddt: 0.31 gdt: 73.29
# T1058TS039_2-D2 lddt: 0.30 gdt: 72.98
# T1058TS238_2-D2 lddt: 0.30 gdt: 71.74
# T1058TS437_3-D2 lddt: 0.08 gdt: 11.65
# T1058TS252_3-D2 lddt: 0.24 gdt: 55.9
# T1058TS024_1-D2 lddt: 0.30 gdt: 69.72
# T1058TS242_2-D2 lddt: 0.08 gdt: 9.16
# T1058TS487_2-D2 lddt: 0.26 gdt: 63.51
# T1058TS498_4-D2 lddt: 0.26 gdt: 63.2
# T1058TS009_3-D2 lddt: 0.30 gdt: 73.29
# T1058TS138_4-D2 lddt: 0.19 gdt: 31.68
# T1058TS326_1-D2 lddt: 0.27 gdt: 61.96
# T1058TS379_1-D2 lddt: 0.32 gdt: 76.86
# T1058TS277_4-D2 lddt: 0.27 gdt: 62.11
# T1058TS375_1-D2 lddt: 0.32 gdt: 76.71
# T1058TS334_5-D2 lddt: 0.31 gdt: 76.09
# T1058TS376_4-D2 lddt: 0.22 gdt: 54.81
# T1058TS341_2-D2 lddt: 0.16 gdt: 26.09
# T1058TS075_2-D2 lddt: 0.24 gdt: 52.33
# T1058TS472_2-D2 lddt: 0.26 gdt: 63.2
# T1058TS015_3-D2 lddt: 0.15 gdt: 22.98
# T1058TS437_2-D2 lddt: 0.08 gdt: 11.96
# T1058TS254_3-D2 lddt: 0.27 gdt: 63.2
# T1058TS335_3-D2 lddt: 0.33 gdt: 83.7
# T1058TS071_3-D2 lddt: 0.24 gdt: 53.26
# T1058TS323_5-D2 lddt: 0.22 gdt: 45.81
# T1058TS453_3-D2 lddt: 0.19 gdt: 21.58
# T1058TS323_2-D2 lddt: 0.22 gdt: 45.34
# T1058TS334_4-D2 lddt: 0.32 gdt: 83.39
# T1058TS360_5-D2 lddt: 0.19 gdt: 34.78
# T1058TS324_1-D2 lddt: 0.30 gdt: 72.05
# T1058TS323_3-D2 lddt: 0.22 gdt: 45.81
# T1058TS253_5-D2 lddt: 0.09 gdt: 14.13
# T1058TS032_5-D2 lddt: 0.29 gdt: 69.88
# T1058TS328_2-D2 lddt: 0.26 gdt: 61.34
# T1058TS257_5-D2 lddt: 0.30 gdt: 72.98
# T1058TS183_5-D2 lddt: 0.31 gdt: 73.29
# T1058TS375_2-D2 lddt: 0.32 gdt: 75.93
# T1058TS367_2-D2 lddt: 0.28 gdt: 63.51
# T1058TS033_5-D2 lddt: 0.07 gdt: 10.56
# T1058TS351_3-D2 lddt: 0.31 gdt: 73.29
# T1058TS031_1-D2 lddt: 0.30 gdt: 69.72
# T1058TS151_2-D2 lddt: 0.09 gdt: 14.91
# T1058TS031_2-D2 lddt: 0.29 gdt: 69.88
# T1058TS039_5-D2 lddt: 0.24 gdt: 53.73
# T1058TS377_3-D2 lddt: 0.22 gdt: 56.68
# T1058TS314_4-D2 lddt: 0.26 gdt: 60.56
# T1058TS238_1-D2 lddt: 0.31 gdt: 73.29
# T1058TS242_5-D2 lddt: 0.05 gdt: 6.99
# T1058TS460_2-D2 lddt: 0.17 gdt: 40.22
# T1058TS480_5-D2 lddt: 0.29 gdt: 72.52
# T1058TS198_3-D2 lddt: 0.24 gdt: 52.17
# T1058TS254_2-D2 lddt: 0.32 gdt: 76.55
# T1058TS222_5-D2 lddt: 0.08 gdt: 14.13
# T1058TS052_5-D2 lddt: 0.12 gdt: 18.94
# T1058TS368_4-D2 lddt: 0.32 gdt: 76.86
# T1058TS483_1-D2 lddt: 0.25 gdt: 58.54
# T1058TS472_4-D2 lddt: 0.22 gdt: 56.37
# T1058TS192_4-D2 lddt: 0.23 gdt: 43.48
# T1058TS096_1-D2 lddt: 0.14 gdt: 20.5
# T1058TS379_4-D2 lddt: 0.28 gdt: 63.82
# T1058TS473_4-D2 lddt: 0.31 gdt: 73.45
# T1058TS216_1-D2 lddt: 0.32 gdt: 76.71
# T1058TS468_1-D2 lddt: 0.27 gdt: 61.8
# T1058TS131_1-D2 lddt: 0.17 gdt: 30.28
# T1058TS362_3-D2 lddt: 0.30 gdt: 74.38
# T1058TS013_4-D2 lddt: 0.32 gdt: 81.83
# T1058TS222_2-D2 lddt: 0.28 gdt: 63.35
# T1058TS075_3-D2 lddt: 0.24 gdt: 52.48
# T1058TS042_1-D2 lddt: 0.30 gdt: 71.58
# T1058TS448_1-D2 lddt: 0.20 gdt: 36.02
# T1058TS226_3-D2 lddt: 0.25 gdt: 58.08
# T1058TS468_2-D2 lddt: 0.27 gdt: 61.8
# T1058TS257_1-D2 lddt: 0.32 gdt: 76.71
# T1058TS435_2-D2 lddt: 0.28 gdt: 65.68
# T1058TS335_4-D2 lddt: 0.31 gdt: 78.26
# T1058TS140_5-D2 lddt: 0.22 gdt: 55.12
# T1058TS403_2-D2 lddt: 0.32 gdt: 76.71
# T1058TS351_4-D2 lddt: 0.31 gdt: 73.29
# T1058TS209_1-D2 lddt: 0.32 gdt: 75.93
# T1058TS031_5-D2 lddt: 0.25 gdt: 59.47
# T1058TS026_3-D2 lddt: 0.27 gdt: 62.73
# T1058TS014_3-D2 lddt: 0.10 gdt: 16.3
# T1058TS488_2-D2 lddt: 0.31 gdt: 74.22
# T1058TS487_5-D2 lddt: 0.26 gdt: 60.09
# T1058TS062_5-D2 lddt: 0.22 gdt: 56.68
# T1058TS337_1-D2 lddt: 0.22 gdt: 54.97
# T1058TS305_1-D2 lddt: 0.11 gdt: 19.25
# T1058TS009_4-D2 lddt: 0.31 gdt: 75.93
# T1058TS349_4-D2 lddt: 0.11 gdt: 14.44
# T1058TS379_3-D2 lddt: 0.31 gdt: 73.45
# T1058TS129_4-D2 lddt: 0.29 gdt: 69.72
# T1058TS220_4-D2 lddt: 0.27 gdt: 62.11
# T1058TS324_5-D2 lddt: 0.27 gdt: 44.1
# T1058TS420_1-D2 lddt: 0.32 gdt: 75.62
# T1058TS226_1-D2 lddt: 0.30 gdt: 68.94
# T1058TS319_1-D2 lddt: 0.26 gdt: 60.09
# T1058TS217_3-D2 lddt: 0.31 gdt: 72.36
# T1058TS339_2-D2 lddt: 0.31 gdt: 73.45
# T1058TS242_4-D2 lddt: 0.05 gdt: 7.61
# T1058TS367_3-D2 lddt: 0.27 gdt: 62.58
# T1058TS042_3-D2 lddt: 0.29 gdt: 69.25
# T1058TS288_4-D2 lddt: 0.32 gdt: 76.71
# T1058TS253_1-D2 lddt: 0.31 gdt: 73.29
# T1058TS005_4-D2 lddt: 0.15 gdt: 22.98
# T1058TS014_2-D2 lddt: 0.09 gdt: 14.13
# T1058TS323_1-D2 lddt: 0.22 gdt: 45.34
# T1058TS473_5-D2 lddt: 0.32 gdt: 76.86
# T1058TS252_1-D2 lddt: 0.25 gdt: 60.09
# T1058TS301_2-D2 lddt: 0.18 gdt: 31.52
# T1058TS487_1-D2 lddt: 0.26 gdt: 63.2
# T1058TS334_3-D2 lddt: 0.33 gdt: 84.78
# T1058TS409_1-D2 lddt: 0.22 gdt: 56.83
# T1058TS018_1-D2 lddt: 0.29 gdt: 73.91
# T1058TS015_5-D2 lddt: 0.32 gdt: 76.71
# T1058TS335_1-D2 lddt: 0.33 gdt: 83.85
# T1058TS026_2-D2 lddt: 0.28 gdt: 63.35
# T1058TS343_3-D2 lddt: 0.31 gdt: 73.45
# T1058TS368_3-D2 lddt: 0.30 gdt: 73.29
# T1058TS460_3-D2 lddt: 0.19 gdt: 46.43
# T1058TS018_3-D2 lddt: 0.30 gdt: 74.69
# T1058TS367_1-D2 lddt: 0.27 gdt: 63.35
# T1058TS192_3-D2 lddt: 0.27 gdt: 64.44
# T1058TS301_3-D2 lddt: 0.20 gdt: 42.55
# T1058TS305_4-D2 lddt: 0.10 gdt: 12.42
# T1058TS373_1-D2 lddt: 0.09 gdt: 13.2
# T1058TS253_3-D2 lddt: 0.25 gdt: 56.06
# T1058TS304_1-D2 lddt: 0.24 gdt: 51.24
# T1058TS334_1-D2 lddt: 0.33 gdt: 87.11
# T1058TS222_4-D2 lddt: 0.27 gdt: 64.91
# T1058TS487_4-D2 lddt: 0.24 gdt: 57.92
# T1058TS039_3-D2 lddt: 0.31 gdt: 72.67
# T1058TS362_5-D2 lddt: 0.12 gdt: 13.35
# T1058TS301_5-D2 lddt: 0.18 gdt: 26.24
# T1058TS326_4-D2 lddt: 0.27 gdt: 61.65
# T1058TS052_3-D2 lddt: 0.12 gdt: 18.94
# T1058TS226_2-D2 lddt: 0.24 gdt: 54.5
# T1058TS015_1-D2 lddt: 0.32 gdt: 77.02
# T1058TS200_4-D2 lddt: 0.21 gdt: 42.55
# T1058TS067_5-D2 lddt: 0.14 gdt: 19.72
# T1058TS026_4-D2 lddt: 0.27 gdt: 64.91
# T1058TS024_4-D2 lddt: 0.30 gdt: 69.72
# T1058TS125_3-D2 lddt: 0.30 gdt: 70.65
# T1058TS061_5-D2 lddt: 0.30 gdt: 74.69
# T1058TS349_2-D2 lddt: 0.11 gdt: 14.29
# T1058TS257_3-D2 lddt: 0.22 gdt: 40.37
# T1058TS196_1-D2 lddt: 0.11 gdt: 13.82
# T1058TS435_5-D2 lddt: 0.29 gdt: 67.39
# T1058TS018_5-D2 lddt: 0.29 gdt: 72.67
# T1058TS317_1-D2 lddt: 0.18 gdt: 32.45
# T1058TS070_4-D2 lddt: 0.14 gdt: 28.88
# T1058TS458_4-D2 lddt: 0.08 gdt: 11.96
# T1058TS367_4-D2 lddt: 0.28 gdt: 63.04
# T1058TS226_5-D2 lddt: 0.29 gdt: 67.55
# T1058TS335_5-D2 lddt: 0.32 gdt: 81.21
# T1058TS198_1-D2 lddt: 0.28 gdt: 65.22
# T1058TS209_5-D2 lddt: 0.32 gdt: 76.86
# T1058TS293_3-D2 lddt: 0.31 gdt: 77.48
# T1058TS341_1-D2 lddt: 0.20 gdt: 48.76
# T1058TS343_1-D2 lddt: 0.32 gdt: 75.93
# T1058TS013_2-D2 lddt: 0.32 gdt: 80.12
# T1058TS200_3-D2 lddt: 0.20 gdt: 17.86
# T1058TS324_3-D2 lddt: 0.24 gdt: 56.21
# T1058TS340_1-D2 lddt: 0.10 gdt: 15.68
# T1058TS339_3-D2 lddt: 0.22 gdt: 40.37
# T1058TS488_1-D2 lddt: 0.32 gdt: 75.93
# T1058TS024_3-D2 lddt: 0.29 gdt: 70.03
# T1058TS067_1-D2 lddt: 0.32 gdt: 76.86
# T1058TS428_2-D2 lddt: 0.12 gdt: 18.17
# T1058TS187_4-D2 lddt: 0.25 gdt: 56.83
# T1058TS209_2-D2 lddt: 0.32 gdt: 76.71
# T1058TS071_5-D2 lddt: 0.24 gdt: 51.55
# T1058TS458_3-D2 lddt: 0.07 gdt: 10.87
# T1058TS341_3-D2 lddt: 0.16 gdt: 26.09
# T1058TS360_2-D2 lddt: 0.17 gdt: 33.7
# T1058TS138_5-D2 lddt: 0.19 gdt: 34.47
# T1058TS392_5-D2 lddt: 0.28 gdt: 64.91
# T1058TS335_2-D2 lddt: 0.31 gdt: 79.5
# T1058TS369_1-D2 lddt: 0.09 gdt: 12.42
# T1058TS364_1-D2 lddt: 0.23 gdt: 53.73
# T1058TS376_2-D2 lddt: 0.20 gdt: 55.44
# T1058TS328_4-D2 lddt: 0.27 gdt: 63.35
# T1058TS375_4-D2 lddt: 0.31 gdt: 73.45
# T1058TS067_3-D2 lddt: 0.29 gdt: 70.65
# T1058TS288_2-D2 lddt: 0.29 gdt: 67.7
# T1058TS453_4-D2 lddt: 0.19 gdt: 18.94
# T1058TS254_4-D2 lddt: 0.31 gdt: 76.4
# T1058TS364_2-D2 lddt: 0.24 gdt: 56.06
# T1058TS063_4-D2 lddt: 0.10 gdt: 13.04
# T1058TS151_5-D2 lddt: 0.21 gdt: 21.89
# T1058TS138_3-D2 lddt: 0.20 gdt: 34.78
# T1058TS342_2-D2 lddt: 0.22 gdt: 42.7
# T1058TS453_5-D2 lddt: 0.18 gdt: 18.32
# T1058TS293_2-D2 lddt: 0.31 gdt: 77.17
# T1058TS305_2-D2 lddt: 0.10 gdt: 17.08
# T1058TS252_4-D2 lddt: 0.24 gdt: 55.44
# T1058TS170_5-D2 lddt: 0.10 gdt: 12.89
# T1058TS131_4-D2 lddt: 0.17 gdt: 34.32
# T1058TS187_5-D2 lddt: 0.25 gdt: 54.97
# T1058TS052_1-D2 lddt: 0.12 gdt: 19.57
# T1058TS319_3-D2 lddt: 0.24 gdt: 56.83
# T1058TS259_5-D2 lddt: 0.14 gdt: 19.72
# T1058TS337_2-D2 lddt: 0.12 gdt: 17.86
# T1058TS498_1-D2 lddt: 0.32 gdt: 75.93
# T1058TS131_5-D2 lddt: 0.16 gdt: 32.45
# T1058TS097_2-D2 lddt: 0.21 gdt: 35.56
# T1058TS339_5-D2 lddt: 0.26 gdt: 60.09
# T1058TS314_5-D2 lddt: 0.27 gdt: 62.27
# T1058TS014_5-D2 lddt: 0.10 gdt: 15.22
# T1058TS377_2-D2 lddt: 0.22 gdt: 56.21
# T1058TS427_3-D2 lddt: 0.37 gdt: 94.1
# T1058TS379_2-D2 lddt: 0.32 gdt: 77.02
# T1058TS305_5-D2 lddt: 0.09 gdt: 13.35
# T1058TS101_3-D2 lddt: 0.29 gdt: 66.77
# T1058TS435_1-D2 lddt: 0.29 gdt: 69.41
# T1058TS278_5-D2 lddt: 0.20 gdt: 32.76
# T1058TS138_1-D2 lddt: 0.20 gdt: 35.56
# T1058TS061_3-D2 lddt: 0.22 gdt: 57.92
# T1058TS192_1-D2 lddt: 0.22 gdt: 53.88
# T1058TS005_1-D2 lddt: 0.13 gdt: 18.01
# T1058TS377_1-D2 lddt: 0.22 gdt: 56.37
# T1058TS337_5-D2 lddt: 0.12 gdt: 17.08
# T1058TS373_2-D2 lddt: 0.09 gdt: 11.8
# T1058TS101_2-D2 lddt: 0.29 gdt: 64.91
# T1058TS169_1-D2 lddt: 0.09 gdt: 15.22
# T1058TS257_2-D2 lddt: 0.31 gdt: 73.45
# T1058TS063_3-D2 lddt: 0.08 gdt: 12.73
# T1058TS377_4-D2 lddt: 0.22 gdt: 56.83
# T1058TS101_1-D2 lddt: 0.29 gdt: 65.37
# T1058TS067_2-D2 lddt: 0.32 gdt: 77.02
# T1058TS420_3-D2 lddt: 0.22 gdt: 55.74
# T1058TS217_2-D2 lddt: 0.30 gdt: 72.98
# T1058TS220_1-D2 lddt: 0.27 gdt: 62.27
# T1058TS125_2-D2 lddt: 0.30 gdt: 71.74
# T1058TS217_4-D2 lddt: 0.29 gdt: 69.88
# T1058TS342_4-D2 lddt: 0.08 gdt: 10.71
# T1058TS071_2-D2 lddt: 0.25 gdt: 56.21
# T1058TS096_2-D2 lddt: 0.14 gdt: 22.36
# T1058TS252_2-D2 lddt: 0.24 gdt: 54.19
# T1058TS193_1-D2 lddt: 0.30 gdt: 75.0
# T1058TS324_2-D2 lddt: 0.28 gdt: 51.86
# T1058TS435_3-D2 lddt: 0.29 gdt: 68.01
# T1058TS014_4-D2 lddt: 0.10 gdt: 15.99
# T1058TS151_1-D2 lddt: 0.10 gdt: 13.51
# T1058TS293_1-D2 lddt: 0.31 gdt: 76.86
# T1058TS005_2-D2 lddt: 0.12 gdt: 18.17
# T1058TS052_2-D2 lddt: 0.12 gdt: 18.79
# T1058TS096_5-D2 lddt: 0.13 gdt: 20.34
# T1058TS033_4-D2 lddt: 0.07 gdt: 9.78
# T1058TS013_5-D2 lddt: 0.32 gdt: 76.4
# T1058TS379_5-D2 lddt: 0.28 gdt: 65.22
# T1058TS070_1-D2 lddt: 0.27 gdt: 43.79
# T1058TS009_1-D2 lddt: 0.31 gdt: 73.29
# T1058TS428_5-D2 lddt: 0.14 gdt: 19.72
# T1058TS192_2-D2 lddt: 0.21 gdt: 48.76
# T1058TS360_4-D2 lddt: 0.14 gdt: 23.76
# T1058TS362_1-D2 lddt: 0.30 gdt: 74.53
# T1058TS278_3-D2 lddt: 0.21 gdt: 49.07
# T1058TS420_2-D2 lddt: 0.26 gdt: 63.04
# T1058TS304_4-D2 lddt: 0.19 gdt: 46.89
# T1058TS403_5-D2 lddt: 0.32 gdt: 76.86
# T1058TS063_2-D2 lddt: 0.06 gdt: 10.09
# T1058TS277_2-D2 lddt: 0.27 gdt: 62.58
# T1058TS013_3-D2 lddt: 0.32 gdt: 79.66
# T1058TS392_2-D2 lddt: 0.27 gdt: 67.08
# T1058TS293_5-D2 lddt: 0.32 gdt: 78.57
# T1058TS277_1-D2 lddt: 0.27 gdt: 62.11
# T1058TS480_4-D2 lddt: 0.30 gdt: 75.93
# T1058TS101_4-D2 lddt: 0.29 gdt: 66.61
# T1058TS259_1-D2 lddt: 0.12 gdt: 18.17
# T1058TS488_5-D2 lddt: 0.27 gdt: 43.32
# T1058TS183_1-D2 lddt: 0.30 gdt: 72.98
# T1058TS050_1-D2 lddt: 0.21 gdt: 42.55
# T1058TS360_1-D2 lddt: 0.17 gdt: 31.83
# T1058TS342_1-D2 lddt: 0.21 gdt: 40.53
# T1058TS062_4-D2 lddt: 0.22 gdt: 56.83
# T1058TS198_4-D2 lddt: 0.27 gdt: 65.37
# T1058TS473_3-D2 lddt: 0.32 gdt: 77.02
# T1058TS061_2-D2 lddt: 0.22 gdt: 57.3
# T1058TS301_4-D2 lddt: 0.18 gdt: 29.5
# T1058TS458_2-D2 lddt: 0.07 gdt: 9.94
# T1058TS026_5-D2 lddt: 0.27 gdt: 63.2
# T1058TS018_2-D2 lddt: 0.28 gdt: 66.3
# T1058TS369_3-D2 lddt: 0.08 gdt: 11.34
# T1058TS183_4-D2 lddt: 0.27 gdt: 64.75
# T1058TS343_2-D2 lddt: 0.32 gdt: 77.02
# T1058TS364_3-D2 lddt: 0.23 gdt: 55.44
# T1058TS472_5-D2 lddt: 0.22 gdt: 56.68
# T1058TS473_1-D2 lddt: 0.32 gdt: 75.93
# T1058TS362_2-D2 lddt: 0.30 gdt: 75.78
# T1058TS039_4-D2 lddt: 0.26 gdt: 63.2
# T1058TS222_3-D2 lddt: 0.27 gdt: 62.73
# T1058TS097_1-D2 lddt: 0.21 gdt: 34.16
# T1058TS403_1-D2 lddt: 0.32 gdt: 75.93
# T1058TS334_2-D2 lddt: 0.32 gdt: 83.08
# T1058TS317_2-D2 lddt: 0.18 gdt: 31.83
# T1058TS097_3-D2 lddt: 0.20 gdt: 28.42
# T1058TS420_4-D2 lddt: 0.28 gdt: 65.68
# T1058TS427_1-D2 lddt: 0.37 gdt: 93.48
# T1058TS328_1-D2 lddt: 0.27 gdt: 61.49
# T1058TS257_4-D2 lddt: 0.26 gdt: 63.51
# T1058TS342_3-D2 lddt: 0.16 gdt: 30.75
# T1058TS351_2-D2 lddt: 0.31 gdt: 72.67
# T1058TS403_3-D2 lddt: 0.32 gdt: 77.02
# T1058TS420_5-D2 lddt: 0.30 gdt: 70.19
# T1058TS125_1-D2 lddt: 0.29 gdt: 70.03
# T1058TS304_3-D2 lddt: 0.23 gdt: 49.84
# T1058TS304_5-D2 lddt: 0.32 gdt: 79.66
# T1058TS376_3-D2 lddt: 0.22 gdt: 54.19
# T1058TS339_1-D2 lddt: 0.32 gdt: 76.71
# T1058TS317_5-D2 lddt: 0.18 gdt: 32.14
# T1058TS343_5-D2 lddt: 0.32 gdt: 76.86
# T1058TS437_4-D2 lddt: 0.08 gdt: 11.8
# T1058TS140_4-D2 lddt: 0.22 gdt: 56.83
# T1058TS277_3-D2 lddt: 0.27 gdt: 61.96
# T1058TS050_3-D2 lddt: 0.11 gdt: 14.44
# T1058TS324_4-D2 lddt: 0.27 gdt: 64.13
# T1058TS071_4-D2 lddt: 0.24 gdt: 53.26
# T1058TS063_5-D2 lddt: 0.08 gdt: 11.18
# T1058TS435_4-D2 lddt: 0.29 gdt: 69.25
# T1058TS226_4-D2 lddt: 0.29 gdt: 70.65
# T1058TS288_1-D2 lddt: 0.29 gdt: 68.63
# T1058TS487_3-D2 lddt: 0.24 gdt: 58.08

# %%
da.grouped_preds.merge(da.results[['Model', 'lddt']], left_on='protein_id', right_on='Model', suffixes=('', '_r')).drop('Model_r', axis=1)
# Out:
#        protein_id         da     da_na         Model  GDT_TS    log_da target  \
# 0    T1024TS004_1  30.266066  0.072139  T1024TS004_1   34.14  1.480956  T1024
# 1    T1024TS004_2  30.189927  0.072139  T1024TS004_2   34.14  1.479862  T1024
# 2    T1024TS004_3  30.229983  0.072139  T1024TS004_3   34.08  1.480438  T1024
# 3    T1024TS004_4  30.654444  0.072139  T1024TS004_4   34.34  1.486493  T1024
# 4    T1024TS004_5  30.583299  0.072139  T1024TS004_5   34.34  1.485484  T1024
# ..            ...        ...       ...           ...     ...       ...    ...
# 473  T1024TS498_1  16.460785  0.072139  T1024TS498_1   55.56  1.216451  T1024
# 474  T1024TS498_2  13.037734  0.072139  T1024TS498_2   62.08  1.115202  T1024
# 475  T1024TS498_3  13.770827  0.072139  T1024TS498_3   61.96  1.138960  T1024
# 476  T1024TS498_4  14.460857  0.072139  T1024TS498_4   61.64  1.160194  T1024
# 477  T1024TS498_5  15.630697  0.072139  T1024TS498_5   61.32  1.193978  T1024
#
#          lddt
# 0    0.478541
# 1    0.478564
# 2    0.475111
# 3    0.486165
# 4    0.486142
# ..        ...
# 473  0.776140
# 474  0.808306
# 475  0.803207
# 476  0.800287
# 477  0.802257
#
# [478 rows x 8 columns]

# %%
from scipy.stats import pearsonr, linregress

# %%
proteins = [
  'T1024', 'T1030', 'T1030-D2', 'T1024-D1', 'T1032-D1', 'T1053-D1', 'T1027-D1', 'T1029-D1',
  'T1025-D1', 'T1028-D1', 'T1030-D1', 'T1053-D2', 'T1057-D1','T1058-D1', 'T1058-D2'
]
results = []
for protein in proteins:
    # protein = proteins[1]
    da = DihedralAdherence(protein, [4,5,6,7], PDBMINE_URL, PROJECT_DIR, 
                            mode='ml', weights_file='ml_runs/best_model-kde_16-32_383.pt', device='cuda')
    da.load_results_da()
    da.filter_nas(0.8)
    da.results = pd.read_csv(da.outdir / 'results-lddt.csv')
    da.grouped_preds = da.grouped_preds.merge(da.results[['Model', 'lddt']], left_on='protein_id', right_on='Model', suffixes=('', '_r')).drop('Model_r', axis=1)

    n_preds = da.grouped_preds_da.shape[0]
    regr = linregress(da.grouped_preds.log_da, da.grouped_preds.lddt)
    rsquared = regr.rvalue**2
    corr, pval = pearsonr(da.grouped_preds.log_da, da.grouped_preds.lddt)

    results.append((protein, rsquared, corr, n_preds))

results = pd.DataFrame(results, columns=['protein', 'rsquared', 'pearsonr', 'n_preds'])
results.loc[len(results)] = ['Mean', results.rsquared.mean(), results.pearsonr.mean(), results.n_preds.mean()]
results.to_markdown('thisresult.md',index=False)
# Out:
# Initializing T1024 ...
# Results already exist
# Casp ID: T1024 	PDB: 6t1z
# Structure exists: 'pdb/pdb6t1z.ent'
# UniProt ID: Q48658
# Initializing T1030 ...
# Results already exist
# Casp ID: T1030 	PDB: 6poo
# Structure exists: 'pdb/pdb6poo.ent'
# UniProt ID: Q8DWZ6
# Initializing T1030-D2 ...
# Results already exist
# Casp ID: T1030-D2 	PDB: 6poo
# Structure exists: 'pdb/pdb6poo.ent'
# UniProt ID: Q8DWZ6
# Initializing T1024-D1 ...
# Results already exist
# Casp ID: T1024-D1 	PDB: 6t1z
# Structure exists: 'pdb/pdb6t1z.ent'
# UniProt ID: Q48658
# Initializing T1032-D1 ...
# Results already exist
# Casp ID: T1032-D1 	PDB: 6n64
# Structure exists: 'pdb/pdb6n64.ent'
# UniProt ID: Q6P5D8
# Initializing T1053-D1 ...
# Results already exist
# Casp ID: T1053-D1 	PDB: 7m7a
# Structure exists: 'pdb/pdb7m7a.ent'
# UniProt ID: Q5ZRA8
# Initializing T1027-D1 ...
# Results already exist
# Casp ID: T1027-D1 	PDB: 7d2o
# Structure exists: 'pdb/pdb7d2o.ent'
# UniProt ID: Q9BLZ2
# Initializing T1029-D1 ...
# Results already exist
# Casp ID: T1029-D1 	PDB: 6uf2
# Structure exists: 'pdb/pdb6uf2.ent'
# UniProt ID: Q31PX7
# Initializing T1025-D1 ...
# Results already exist
# Casp ID: T1025-D1 	PDB: 6uv6
# Structure exists: 'pdb/pdb6uv6.ent'
# UniProt ID: Q0H2W9
# No CASP AlphaFold prediction
# Initializing T1028-D1 ...
# Results already exist
# Casp ID: T1028-D1 	PDB: 6vqp
# Structure exists: 'pdb/pdb6vqp.ent'
# UniProt ID: Q8KND1
# No CASP AlphaFold prediction
# Initializing T1030-D1 ...
# Results already exist
# Casp ID: T1030-D1 	PDB: 6poo
# Structure exists: 'pdb/pdb6poo.ent'
# UniProt ID: Q8DWZ6
# Initializing T1053-D2 ...
# Results already exist
# Casp ID: T1053-D2 	PDB: 7m7a
# Structure exists: 'pdb/pdb7m7a.ent'
# UniProt ID: Q5ZRA8
# Initializing T1057-D1 ...
# Results already exist
# Casp ID: T1057-D1 	PDB: 7m6b
# Structure exists: 'pdb/pdb7m6b.ent'
# UniProt ID: B9MNH4
# Initializing T1058-D1 ...
# Results already exist
# Casp ID: T1058-D1 	PDB: 7abw
# Structure exists: 'pdb/pdb7abw.ent'
# UniProt ID: Q9I117
# Initializing T1058-D2 ...
# Results already exist
# Casp ID: T1058-D2 	PDB: 7abw
# Structure exists: 'pdb/pdb7abw.ent'
# UniProt ID: Q9I117

# %%
PDBMINE_URL = os.getenv("GREEN_PDBMINE_URL")
PROJECT_DIR = 'casp_da'
proteins = [
  'T1024', 'T1030', 'T1030-D2', 'T1024-D1', 'T1032-D1', 'T1053-D1', 'T1027-D1', 'T1029-D1',
  'T1025-D1', 'T1028-D1', 'T1030-D1', 'T1053-D2', 'T1057-D1','T1058-D1', 'T1058-D2'
]
proteins = ['T1038', 'T1030-D2', 'T1024-D1', 'T1053-D1', 'T1057-D1', 'T1058-D1', 'T1058-D2'] # good (af >85 gdt)
proteins = ['T1030-D2', 'T1024-D1', 'T1053-D1', 'T1057-D1', 'T1058-D1', 'T1058-D2'] # good (af >85 gdt)
# proteins = ['T1024', 'T1091', 'T1030', 'T1032-D1', 'T1027-D1', 'T1030-D1', 'T1096', 'T1029-D1'] # bad (af <85 gdt)
# proteins = ['T1096', 'T1029-D1'] # bad (af < 50 gdt)
preds = []
for protein in proteins:
    da = DihedralAdherence(
        protein, [4,5,6,7], PDBMINE_URL, PROJECT_DIR, mode='ml', quantile=1,
        weights_file='ml_runs/best_model-kde_16-32_383.pt', device='cuda'
    )
    da.load_results_da()
    da.filter_nas(.8)
    da.results = pd.read_csv(da.outdir / 'results-lddt.csv')
    da.grouped_preds = da.grouped_preds.merge(da.results[['Model', 'lddt']], left_on='protein_id', right_on='Model', suffixes=('', '_r')).drop('Model_r', axis=1)
    preds.append(da.grouped_preds)

preds = pd.concat(preds)
# Out:
# Initializing T1030-D2 ...
# Results already exist
# Casp ID: T1030-D2 	PDB: 6poo
# Structure exists: 'pdb/pdb6poo.ent'
# UniProt ID: Q8DWZ6
# Initializing T1024-D1 ...
# Results already exist
# Casp ID: T1024-D1 	PDB: 6t1z
# Structure exists: 'pdb/pdb6t1z.ent'
# UniProt ID: Q48658
# Initializing T1053-D1 ...
# Results already exist
# Casp ID: T1053-D1 	PDB: 7m7a
# Structure exists: 'pdb/pdb7m7a.ent'
# UniProt ID: Q5ZRA8
# Initializing T1057-D1 ...
# Results already exist
# Casp ID: T1057-D1 	PDB: 7m6b
# Structure exists: 'pdb/pdb7m6b.ent'
# UniProt ID: B9MNH4
# Initializing T1058-D1 ...
# Results already exist
# Casp ID: T1058-D1 	PDB: 7abw
# Structure exists: 'pdb/pdb7abw.ent'
# UniProt ID: Q9I117
# Initializing T1058-D2 ...
# Results already exist
# Casp ID: T1058-D2 	PDB: 7abw
# Structure exists: 'pdb/pdb7abw.ent'
# UniProt ID: Q9I117

# %%
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")
sns.set_palette("pastel")
fig, ax = plt.subplots(figsize=(8, 6.5))
df = preds.dropna(subset=['da', 'lddt']).reset_index(drop=True)

df['da'] = np.log10(df['da'])
df = df[~df.Model.str.contains('427')]

regr = linregress(df.da, df.lddt)
corr = pearsonr(df['da'], df['lddt'])
print(regr.rvalue**2, corr)
print(f'Slope: {regr.slope}, Intercept: {regr.intercept}')
# sns.kdeplot(data=df, x='da', y='lddt', ax=ax, fill=True, bw_method=0.1)
sns.scatterplot(data=df, x='da', y='lddt', ax=ax, marker='o', s=25, edgecolor='b', legend=True, hue='target', palette='pastel')
# sns.regplot(data=df.reset_index(drop=True), x='da', y='lddt', ax=ax, scatter=False, color='red')
ax.plot(
    np.linspace(0.8, 2.3, 100), 
    regr.intercept + regr.slope * np.linspace(0.8, 2.3, 100), 
    color='red', lw=2, label='Best Fit'
)
ax.set_xlabel('Log10 Dihedral Adherence Score', fontsize=14, labelpad=15)
ax.set_ylabel('Prediction lDDT', fontsize=14, labelpad=15)
ax.set_title(r'lDDT vs Dihedral Adherence for Predictions', fontsize=16, pad=20)
ax.text(0.6, 0.95, r'$R^2$='+f'{regr.rvalue**2:.3f}', transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=dict(boxstyle='round,pad=0.5', edgecolor='black', facecolor='white'))
if regr.intercept > 0:
    s = f'y = {regr.slope:.1E}x + {regr.intercept:.1f}'
else:
    s = f'y = {regr.slope:.1E}x - {-regr.intercept:.1f}'
ax.text(.025,.05, s, transform=ax.transAxes, fontsize=12, color='red',
        bbox=dict(boxstyle='round,pad=0.4', edgecolor='red', facecolor='white'))
ax.set_xlim(.8, 2.3)
ax.set_ylim(0, 1)
plt.legend(fontsize=12, loc='upper right')
plt.tight_layout()
plt.show()
sns.reset_defaults()
# Out:
# 0.13004920987784213 PearsonRResult(statistic=-0.36062336291183644, pvalue=1.0459450102235545e-72)
# Slope: -0.31175218118407283, Intercept: 0.8331185986524425
