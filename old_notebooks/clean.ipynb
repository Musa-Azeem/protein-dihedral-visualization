# %%
# %load_ext autoreload
# %autoreload 2

# %%
from lib import DihedralAdherence
from lib import PDBMineQuery
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from pathlib import Path
PDBMINE_URL = os.getenv("PDBMINE_URL")
PROJECT_DIR = 'casp_da'

# %%
list(da.seqs).index('NLQLRLG')
list(da.seqs).index('EFWNLDK')
# Out:
# 1

# %%
PDBMINE_URL = os.getenv("GREEN_PDBMINE_URL")
PROJECT_DIR = 'casp_da'
proteins = [
    'T1024', 'T1096', 'T1091', 'T1030', 'T1038', 'T1030-D2', 'T1024-D1', 'T1032-D1', 'T1053-D1', 'T1027-D1', 'T1029-D1',
    'T1025-D1', 'T1028-D1', 'T1030-D1', 'T1053-D2', 'T1057-D1','T1058-D1', 'T1058-D2'
]
proteins = [
	'T1024', 'T1030', 'T1030-D2', 'T1024-D1', 'T1032-D1', 'T1053-D1', 'T1027-D1', 'T1029-D1',
	'T1025-D1', 'T1028-D1', 'T1030-D1', 'T1053-D2', 'T1057-D1','T1058-D1', 'T1058-D2'
]
# da = DihedralAdherence(proteins[0], [4,5,6,7], PDBMINE_URL, PROJECT_DIR, kdews=[1,32,64,128], 
proteins = [
  'T1024', 'T1030', 'T1030-D2', 'T1024-D1', 'T1032-D1', 'T1053-D1', 'T1027-D1', 'T1029-D1',
  'T1025-D1', 'T1028-D1', 'T1030-D1', 'T1053-D2', 'T1057-D1','T1058-D1', 'T1058-D2'
]
# da.load_results()
# da.compute_das()
# da.test_pdbmine_conn()
# da.query_pdbmine()
da.load_results_da()
da.filter_nas(quantile=0.8)
da.plot_one_dist_scatter(da.seqs[1])
da.plot_one_dist_3d(da.seqs[1])
# rsquared, pearsonr = da.test_correlation()
# da.filter_nas(quantile=0.7)
# results = pd.concat([q.results for q in da.queries])
# print(results.groupby('phi').size().sort_index(ascending=False).head())
# results.describe().loc[['min','max'], ['phi','psi']]
# print(da.xray_phi_psi.describe().loc[['min','max'], ['phi','psi']])
# da.phi_psi_predictions.describe().loc[['min','max'], ['phi','psi']]
# da.plot_da_for_seq()
# da.plot_dist_kde(percentile=0.50)
# both = da.plot_res_vs_da()
# da.plot_da_vs_gdt()
# da.plot_da_vs_gdt_simple()
# print(da.grouped_preds.da_na.describe())
# print(da.grouped_preds[da.grouped_preds.da_na > da.grouped_preds.da_na.quantile(0.9)].shape)
# da.plot_res_vs_da(da.protein_ids[0], highlight_res=((159,163),(187,191),(373,377)), legend_loc='upper left', text_loc='left')
# print((~np.isnan(da.grouped_preds_da.values)).sum(axis=1).mean())
# print((~np.isnan(da.grouped_preds_da.values)).sum(axis=1).std())
# da.plot_heatmap(fillna=False, fillna_row=False)
# print(da.grouped_preds[da.grouped_preds.protein_id==da.get_id('337_5')].RMS_CA)
# rmsds, n, rmsd_inner = da.split_and_compute_rmsd(pred_id=da.protein_ids[0], split=[(48,48),(49,49),(76, 76),(106,106),(107,107)])
# rmsds, n, rmsd_inner = da.split_and_compute_rmsd(pred_id=da.protein_ids[0], split=[(161,161), (189,189), (362,375)])
# Out:
# Initializing T1024 ...
# Results already exist
# Casp ID: T1024 	PDB: 6t1z
# Structure exists: 'pdb/pdb6t1z.ent'
# UniProt ID: Q48658
# Max: P(-82.729805, -20.557103)=0.000062

# %%
from lib.utils import get_phi_psi_dist
seq = da.seqs[3]
phi_psi_dist = get_phi_psi_dist(da.queries, seq)[0]
phi_psi_dist = phi_psi_dist.loc[~phi_psi_dist[['phi', 'psi']].isna().any(axis=1)]
xray = da.xray_phi_psi.loc[da.xray_phi_psi.seq_ctxt == seq, ['phi','psi']].values[0]

# %%
from matplotlib.ticker import FuncFormatter

x = phi_psi_dist[['phi','psi']].values.T
weights = phi_psi_dist['weight'].values
kde = gaussian_kde(x, weights=weights, bw_method=0.5)

x_grid, y_grid = np.meshgrid(np.linspace(-180, 180, 360), np.linspace(-180, 180, 360))
grid = np.vstack([x_grid.ravel(), y_grid.ravel()])
z = kde(grid).reshape(x_grid.shape)
zmax = z.max()
z = z / zmax
print(f'Max: P({grid[0,z.argmax()]:02f}, {grid[1,z.argmax()]:02f})={z.max():02f}')

cm = plt.get_cmap('turbo')
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(x_grid, y_grid, z, cmap=cm)
# ax.zaxis.set_major_formatter(FuncFormatter(lambda x,pos:f'{x * 10e3:.1f}'))
# ax.zaxis.set_major_formatter(FuncFormatter(lambda x,pos:f'{x * 1e3:.1f}'))

ax.set_title(f'PDBMine Distribution of Dihedral Angles\nfor Residue {seq[da.winsize_ctxt//2]} of Window {seq}', y=0.99, fontsize=12)
ax.set_xlabel('Phi', fontsize=10, labelpad=10)
ax.set_ylabel('Psi', fontsize=10, labelpad=10)
ax.set_zlabel(r'Likelihood (normalized by max)', fontsize=10, labelpad=10)
ax.xaxis.set_tick_params(labelsize=8)
ax.yaxis.set_tick_params(labelsize=8)
ax.zaxis.set_tick_params(labelsize=8)
ax.set_box_aspect(aspect=None, zoom=0.8)
# ax.dist = 5
plt.tight_layout()
plt.show()
# Out:
# Max: P(-76.713092, 120.835655)=1.000000

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
max_sil_avg = -1
for k in range(2, min(phi_psi_dist.shape[0], 7)):
    kmeans = KMeans(n_clusters=k, n_init=10) # TODO experiment with n_init
    labels = kmeans.fit_predict(phi_psi_dist[['phi', 'psi']])
    sil_avg = silhouette_score(phi_psi_dist[['phi', 'psi']], labels)
    if sil_avg > max_sil_avg:
        max_sil_avg = sil_avg
        phi_psi_dist['cluster'] = labels
sns.scatterplot(phi_psi_dist, x='phi', y='psi', hue='cluster', palette='Dark2')
for cluster in phi_psi_dist.cluster.unique():
    center = phi_psi_dist[phi_psi_dist.cluster==cluster][['phi', 'psi']].mean().values
    plt.scatter(center[0], center[1], color='black', marker='X', alpha=0.8)
    print(center)
plt.scatter(xray[0], xray[1], color='red', marker='^', alpha=0.8, label='X-ray')
print(xray)
# phi_psi_dist.plot(kind='scatter', x='phi', y='psi', c='cluster', cmap='viridis', s=10)
plt.title('Cluster with Kmeans to maximize silhouette score')
plt.xlim(-180, 180)
plt.ylim(-180, 180)
plt.legend()
plt.show()
# Out:
# [-81.18190255 -18.64037123]
# [-92.07641886 124.54636291]
# [ -96.1371517  -170.41981424]
# [75.45212766 40.70106383]
# [-66.32551808 141.75509818]

# %%
from scipy.stats import gaussian_kde

phi_psi_dist['likelihood'] = kde(phi_psi_dist[['phi','psi']].values.T) / zmax
sns.scatterplot(phi_psi_dist, x='phi', y='psi', hue='likelihood', alpha=0.8, legend='brief')
plt.title('Likelihood of phi, psi pairs')
plt.xlim(-180, 180)
plt.ylim(-180, 180)
plt.show()

# %%
cutoff = phi_psi_dist[phi_psi_dist.likelihood > 0.4]

max_sil_avg = -1
for k in range(2, min(cutoff.shape[0], 7)):
    kmeans = KMeans(n_clusters=k, n_init=10) # TODO experiment with n_init
    labels = kmeans.fit_predict(cutoff[['phi', 'psi']])
    sil_avg = silhouette_score(cutoff[['phi', 'psi']], labels)
    if sil_avg > max_sil_avg:
        max_sil_avg = sil_avg
        cutoff.loc[:, 'cluster'] = labels

sns.scatterplot(cutoff, x='phi', y='psi', hue='cluster', alpha=0.8, legend='brief')
for cluster in cutoff.cluster.unique():
    center = cutoff[cutoff.cluster==cluster][['phi', 'psi']].mean().values
    plt.scatter(center[0], center[1], color='black', marker='X', alpha=0.8)
    print(center)
plt.scatter(xray[0], xray[1], color='red', marker='^', alpha=0.8, label='X-ray')
plt.title('Cluster with Kmeans points with normalized likelihood > 0.4')
plt.xlim(-180,180)
plt.ylim(-180,180)
plt.legend()
plt.show()
# Out:
# [-76.1030888  -21.70862291]
# [-81.24820416 124.05056711]

# %%
from sklearn.cluster import estimate_bandwidth

estimate_bandwidth(phi_psi_dist[['phi', 'psi']].values)
# Out:
# 32.22385554740044

# %%
# Find clusters
from sklearn.cluster import MeanShift
# bandwidth = 32
bandwidth = None
ms = MeanShift(bandwidth=bandwidth, bin_seeding=True)
ms.fit(phi_psi_dist[['phi','psi']])
phi_psi_dist['cluster'] = ms.labels_
sns.scatterplot(phi_psi_dist, x='phi', y='psi', hue='cluster', palette='Dark2')
# phi_psi_dist.plot(kind='scatter', x='phi', y='psi', c='cluster', cmap='viridis', s=10)
plt.title('Cluster with Mean Shift')
plt.show()
# Out:
# /tmp/ipykernel_3576709/2310827317.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cutoff['cluster'] = ms.labels_

# %%
proteins = [
  'T1024', 'T1096', 'T1091', 'T1030', 'T1038', 'T1030-D2', 'T1024-D1', 'T1032-D1', 'T1053-D1', 'T1027-D1', 'T1029-D1',
  'T1025-D1', 'T1028-D1', 'T1030-D1', 'T1053-D2', 'T1057-D1','T1058-D1', 'T1058-D2'
]
proteins = [
  'T1024', 'T1030', 'T1030-D2', 'T1024-D1', 'T1032-D1', 'T1053-D1', 'T1027-D1', 'T1029-D1',
  'T1025-D1', 'T1028-D1', 'T1030-D1', 'T1053-D2', 'T1057-D1','T1058-D1', 'T1058-D2'
]
for protein in proteins:
    try:
        da = DihedralAdherence(protein, [4,5,6,7], PDBMINE_URL, PROJECT_DIR, kdews=[1,32,64,128], 
                               mode='ml', weights_file='ml_runs/best_model-kde_16-32_383.pt', device='cuda')
        # da.query_pdbmine()
        # da.compute_structures(replace=True)
        da.load_results()
        da.compute_das(replace=True)
    except Exception as e:
        print(f"{protein} - Error: {e}")
# Out:
# Initializing T1024 ...
# Results already exist
# Casp ID: T1024 	PDB: 6t1z
# Structure exists: 'pdb/pdb6t1z.ent'
# UniProt ID: Q48658
# 0/372: KEFWNLD
# 	Win 4: FWNL - 388 samples
# 	Win 5: EFWNL - 25 samples
# 	Win 6: EFWNLD - 0 samples
# 	Win 7: KEFWNLD - 0 samples
# 	Weighted n samples: 538.0
# 	478 predictions
# 	Xray DA: [5.97061805] Pred DA: 43.96713513683796
# 1/372: EFWNLDK
# 	Win 4: WNLD - 291 samples
# 	Win 5: FWNLD - 8 samples
# 	Win 6: FWNLDK - 0 samples
# 	Win 7: EFWNLDK - 0 samples
# 	Weighted n samples: 339.0
# 	478 predictions
# 	Xray DA: [6.82231536] Pred DA: 51.58035031899081
# 2/372: FWNLDKN
# 	Win 4: NLDK - 2550 samples
# 	Win 5: WNLDK - 42 samples
# 	Win 6: WNLDKN - 0 samples
# 	Win 7: FWNLDKN - 0 samples
# 	Weighted n samples: 2802.0
# 	478 predictions
# 	Xray DA: [12.62324305] Pred DA: 54.897564303906755
# 3/372: WNLDKNL
# 	Win 4: LDKN - 2427 samples
# 	Win 5: NLDKN - 95 samples
# 	Win 6: NLDKNL - 8 samples
# 	Win 7: WNLDKNL - 0 samples
# 	Weighted n samples: 3053.0
# 	478 predictions
# 	Xray DA: [3.48757564] Pred DA: 56.12489581327336
# 4/372: NLDKNLQ
# 	Win 4: DKNL - 3165 samples
# 	Win 5: LDKNL - 132 samples
# 	Win 6: LDKNLQ - 6 samples
# 	Win 7: NLDKNLQ - 0 samples
# 	Weighted n samples: 3999.0
# 	478 predictions
# 	Xray DA: [14.93500792] Pred DA: 21.267721301695975
# 5/372: LDKNLQL
# 	Win 4: KNLQ - 2662 samples
# 	Win 5: DKNLQ - 31 samples
# 	Win 6: DKNLQL - 0 samples
# 	Win 7: LDKNLQL - 0 samples
# 	Weighted n samples: 2848.0
# 	478 predictions
# 	Xray DA: [12.60798508] Pred DA: 14.494595046720072
# 6/372: DKNLQLR
# 	Win 4: NLQL - 1602 samples
# 	Win 5: KNLQL - 152 samples
# 	Win 6: KNLQLR - 24 samples
# 	Win 7: DKNLQLR - 0 samples
# 	Weighted n samples: 2682.0
# 	478 predictions
# 	Xray DA: [3.13489024] Pred DA: 10.012139928547214
# 7/372: KNLQLRL
# 	Win 4: LQLR - 2892 samples
# 	Win 5: NLQLR - 138 samples
# 	Win 6: NLQLRL - 0 samples
# 	Win 7: KNLQLRL - 0 samples
# 	Weighted n samples: 3720.0
# 	478 predictions
# 	Xray DA: [3.90827709] Pred DA: 12.058778466638268
# 8/372: NLQLRLG
# 	Win 4: QLRL - 2633 samples
# 	Win 5: LQLRL - 175 samples
# 	Win 6: LQLRLG - 3 samples
# 	Win 7: NLQLRLG - 0 samples
# 	Weighted n samples: 3704.0
# 	478 predictions
# 	Xray DA: [0.21134875] Pred DA: 9.96780711741372
# 9/372: LQLRLGI
# 	Win 4: LRLG - 4454 samples
# 	Win 5: QLRLG - 52 samples
# 	Win 6: QLRLGI - 2 samples
# 	Win 7: LQLRLGI - 0 samples
# 	Weighted n samples: 4780.0
# 	478 predictions
# 	Xray DA: [4.46697947] Pred DA: 13.289631722759431
# 10/372: QLRLGIV
# 	Win 4: RLGI - 4135 samples
# 	Win 5: LRLGI - 111 samples
# 	Win 6: LRLGIV - 10 samples
# 	Win 7: QLRLGIV - 0 samples
# 	Weighted n samples: 4871.0
# 	478 predictions
# 	Xray DA: [4.35510513] Pred DA: 11.874928201372828
# 11/372: LRLGIVF
# 	Win 4: LGIV - 3126 samples
# 	Win 5: RLGIV - 154 samples
# 	Win 6: RLGIVF - 2 samples
# 	Win 7: LRLGIVF - 0 samples
# 	Weighted n samples: 4064.0
# 	478 predictions
# 	Xray DA: [19.86576862] Pred DA: 15.784555533159406
# 12/372: RLGIVFL
# 	Win 4: GIVF - 1756 samples
# 	Win 5: LGIVF - 75 samples
# 	Win 6: LGIVFL - 0 samples
# 	Win 7: RLGIVFL - 0 samples
# 	Weighted n samples: 2206.0
# 	478 predictions
# 	Xray DA: [14.0051102] Pred DA: 10.120063486712274
# 13/372: LGIVFLG
# 	Win 4: IVFL - 2195 samples
# 	Win 5: GIVFL - 103 samples
# 	Win 6: GIVFLG - 17 samples
# 	Win 7: LGIVFLG - 0 samples
# 	Weighted n samples: 2932.0
# 	478 predictions
# 	Xray DA: [8.7682501] Pred DA: 13.378051553132943
# 14/372: GIVFLGA
# 	Win 4: VFLG - 4127 samples
# 	Win 5: IVFLG - 172 samples
# 	Win 6: IVFLGA - 52 samples
# 	Win 7: GIVFLGA - 0 samples
# 	Weighted n samples: 5523.0
# 	478 predictions
# 	Xray DA: [18.64627262] Pred DA: 9.765141362899135
# 15/372: IVFLGAF
# 	Win 4: FLGA - 3914 samples
# 	Win 5: VFLGA - 153 samples
# 	Win 6: VFLGAF - 6 samples
# 	Win 7: IVFLGAF - 0 samples
# 	Weighted n samples: 4874.0
# 	478 predictions
# 	Xray DA: [12.96914474] Pred DA: 10.604811206342431
# 16/372: VFLGAFS
# 	Win 4: LGAF - 3888 samples
# 	Win 5: FLGAF - 72 samples
# 	Win 6: FLGAFS - 0 samples
# 	Win 7: VFLGAFS - 0 samples
# 	Weighted n samples: 4320.0
# 	478 predictions
# 	Xray DA: [11.5123671] Pred DA: 14.012620234247573
# 17/372: FLGAFSY
# 	Win 4: GAFS - 3149 samples
# 	Win 5: LGAFS - 1176 samples
# 	Win 6: LGAFSY - 3 samples
# 	Win 7: FLGAFSY - 0 samples
# 	Weighted n samples: 10226.0
# 	478 predictions
# 	Xray DA: [10.36587386] Pred DA: 10.568546424422118
# 18/372: LGAFSYG
# 	Win 4: AFSY - 1390 samples
# 	Win 5: GAFSY - 95 samples
# 	Win 6: GAFSYG - 6 samples
# 	Win 7: LGAFSYG - 0 samples
# 	Weighted n samples: 2002.0
# 	478 predictions
# 	Xray DA: [12.90394582] Pred DA: 9.046118939468402
# 19/372: GAFSYGT
# 	Win 4: FSYG - 1625 samples
# 	Win 5: AFSYG - 273 samples
# 	Win 6: AFSYGT - 0 samples
# 	Win 7: GAFSYGT - 0 samples
# 	Weighted n samples: 3263.0
# 	478 predictions
# 	Xray DA: [14.27393686] Pred DA: 16.227934626917612
# 20/372: AFSYGTV
# 	Win 4: SYGT - 1329 samples
# 	Win 5: FSYGT - 27 samples
# 	Win 6: FSYGTV - 0 samples
# 	Win 7: AFSYGTV - 0 samples
# 	Weighted n samples: 1491.0
# 	478 predictions
# 	Xray DA: [7.96000286] Pred DA: 15.521409815925638
# 21/372: FSYGTVF
# 	Win 4: YGTV - 926 samples
# 	Win 5: SYGTV - 38 samples
# 	Win 6: SYGTVF - 0 samples
# 	Win 7: FSYGTVF - 0 samples
# 	Weighted n samples: 1154.0
# 	478 predictions
# 	Xray DA: [29.70431256] Pred DA: 15.834263424402439
# 22/372: SYGTVFS
# 	Win 4: GTVF - 1901 samples
# 	Win 5: YGTVF - 16 samples
# 	Win 6: YGTVFS - 2 samples
# 	Win 7: SYGTVFS - 0 samples
# 	Weighted n samples: 2011.0
# 	478 predictions
# 	Xray DA: [18.82850175] Pred DA: 13.093352063543975
# 23/372: YGTVFSS
# 	Win 4: TVFS - 2915 samples
# 	Win 5: GTVFS - 34 samples
# 	Win 6: GTVFSS - 0 samples
# 	Win 7: YGTVFSS - 0 samples
# 	Weighted n samples: 3119.0
# 	478 predictions
# 	Xray DA: [14.30656614] Pred DA: 49.45476391346359
# 24/372: GTVFSSM
# 	Win 4: VFSS - 2491 samples
# 	Win 5: TVFSS - 185 samples
# 	Win 6: TVFSSM - 0 samples
# 	Win 7: GTVFSSM - 0 samples
# 	Weighted n samples: 3601.0
# 	478 predictions
# 	Xray DA: [4.07615591] Pred DA: 19.179464625290816
# 25/372: TVFSSMT
# 	Win 4: FSSM - 543 samples
# 	Win 5: VFSSM - 40 samples
# 	Win 6: VFSSMT - 0 samples
# 	Win 7: TVFSSMT - 0 samples
# 	Weighted n samples: 783.0
# 	478 predictions
# 	Xray DA: [8.86410576] Pred DA: 20.746005409326827
# 26/372: VFSSMTI
# 	Win 4: SSMT - 2214 samples
# 	Win 5: FSSMT - 63 samples
# 	Win 6: FSSMTI - 0 samples
# 	Win 7: VFSSMTI - 0 samples
# 	Weighted n samples: 2592.0
# 	478 predictions
# 	Xray DA: [9.67977256] Pred DA: 58.97673363100137
# 27/372: FSSMTIY
# 	Win 4: SMTI - 795 samples
# 	Win 5: SSMTI - 151 samples
# 	Win 6: SSMTIY - 0 samples
# 	Win 7: FSSMTIY - 0 samples
# 	Weighted n samples: 1701.0
# 	478 predictions
# 	Xray DA: [3.04545262] Pred DA: 17.475403957292766
# 28/372: SSMTIYY
# 	Win 4: MTIY - 335 samples
# 	Win 5: SMTIY - 27 samples
# 	Win 6: SMTIYY - 0 samples
# 	Win 7: SSMTIYY - 0 samples
# 	Weighted n samples: 497.0
# 	478 predictions
# 	Xray DA: [6.42823542] Pred DA: 11.13407703619515
# 29/372: SMTIYYN
# 	Win 4: TIYY - 1943 samples
# 	Win 5: MTIYY - 25 samples
# 	Win 6: MTIYYN - 0 samples
# 	Win 7: SMTIYYN - 0 samples
# 	Weighted n samples: 2093.0
# 	478 predictions
# 	Xray DA: [17.31854345] Pred DA: 11.115161695492926
# 30/372: MTIYYNQ
# 	Win 4: IYYN - 574 samples
# 	Win 5: TIYYN - 31 samples
# 	Win 6: TIYYNQ - 0 samples
# 	Win 7: MTIYYNQ - 0 samples
# 	Weighted n samples: 760.0
# 	478 predictions
# 	Xray DA: [14.20628261] Pred DA: 14.259699133038142
# 31/372: TIYYNQY
# 	Win 4: YYNQ - 2317 samples
# 	Win 5: IYYNQ - 0 samples
# 	Win 6: IYYNQY - 0 samples
# 	Win 7: TIYYNQY - 0 samples
# 	Weighted n samples: 2317.0
# 	478 predictions
# 	Xray DA: [14.45172101] Pred DA: 18.512782879034635
# 32/372: IYYNQYL
# 	Win 4: YNQY - 367 samples
# 	Win 5: YYNQY - 50 samples
# 	Win 6: YYNQYL - 2 samples
# 	Win 7: IYYNQYL - 0 samples
# 	Weighted n samples: 681.0
# 	478 predictions
# 	Xray DA: [3.75572428] Pred DA: 18.196430619364197
# 33/372: YYNQYLG
# 	Win 4: NQYL - 1001 samples
# 	Win 5: YNQYL - 15 samples
# 	Win 6: YNQYLG - 2 samples
# 	Win 7: YYNQYLG - 2 samples
# 	Weighted n samples: 1121.0
# 	478 predictions
# 	Xray DA: [10.30316003] Pred DA: 28.02237399334967
# 34/372: YNQYLGS
# 	Win 4: QYLG - 1423 samples
# 	Win 5: NQYLG - 26 samples
# 	Win 6: NQYLGS - 0 samples
# 	Win 7: YNQYLGS - 0 samples
# 	Weighted n samples: 1579.0
# 	478 predictions
# 	Xray DA: [10.7564876] Pred DA: 44.094810600527886
# 35/372: NQYLGSA
# 	Win 4: YLGS - 2335 samples
# 	Win 5: QYLGS - 102 samples
# 	Win 6: QYLGSA - 0 samples
# 	Win 7: NQYLGSA - 0 samples
# 	Weighted n samples: 2947.0
# 	478 predictions
# 	Xray DA: [165.67817583] Pred DA: 85.5776357664329
# 36/372: QYLGSAI
# 	Win 4: LGSA - 7591 samples
# 	Win 5: YLGSA - 127 samples
# 	Win 6: YLGSAI - 0 samples
# 	Win 7: QYLGSAI - 0 samples
# 	Weighted n samples: 8353.0
# 	478 predictions
# 	Xray DA: [160.13637003] Pred DA: 85.67145319306242
# 37/372: YLGSAIT
# 	Win 4: GSAI - 3088 samples
# 	Win 5: LGSAI - 354 samples
# 	Win 6: LGSAIT - 12 samples
# 	Win 7: YLGSAIT - 0 samples
# 	Weighted n samples: 5296.0
# 	478 predictions
# 	Xray DA: [28.36468582] Pred DA: 27.270258814263812
# 38/372: LGSAITG
# 	Win 4: SAIT - 4386 samples
# 	Win 5: GSAIT - 187 samples
# 	Win 6: GSAITG - 13 samples
# 	Win 7: LGSAITG - 0 samples
# 	Weighted n samples: 5599.0
# 	478 predictions
# 	Xray DA: [9.64479523] Pred DA: 25.691962161694875
# 39/372: GSAITGI
# 	Win 4: AITG - 3297 samples
# 	Win 5: SAITG - 240 samples
# 	Win 6: SAITGI - 14 samples
# 	Win 7: GSAITGI - 0 samples
# 	Weighted n samples: 4835.0
# 	478 predictions
# 	Xray DA: [10.47441968] Pred DA: 15.708052844313988
# 40/372: SAITGIL
# 	Win 4: ITGI - 2518 samples
# 	Win 5: AITGI - 216 samples
# 	Win 6: AITGIL - 0 samples
# 	Win 7: SAITGIL - 0 samples
# 	Weighted n samples: 3814.0
# 	478 predictions
# 	Xray DA: [2.63073074] Pred DA: 14.696304921161072
# 41/372: AITGILL
# 	Win 4: TGIL - 2500 samples
# 	Win 5: ITGIL - 256 samples
# 	Win 6: ITGILL - 182 samples
# 	Win 7: AITGILL - 0 samples
# 	Weighted n samples: 5310.0
# 	478 predictions
# 	Xray DA: [7.35068945] Pred DA: 18.984797075721822
# 42/372: ITGILLA
# 	Win 4: GILL - 5638 samples
# 	Win 5: TGILL - 401 samples
# 	Win 6: TGILLA - 26 samples
# 	Win 7: ITGILLA - 0 samples
# 	Weighted n samples: 8226.0
# 	478 predictions
# 	Xray DA: [4.17742322] Pred DA: 9.867877380344142
# 43/372: TGILLAL
# 	Win 4: ILLA - 6771 samples
# 	Win 5: GILLA - 596 samples
# 	Win 6: GILLAL - 4 samples
# 	Win 7: TGILLAL - 0 samples
# 	Weighted n samples: 10375.0
# 	478 predictions
# 	Xray DA: [12.56193426] Pred DA: 7.118325903693282
# 44/372: GILLALS
# 	Win 4: LLAL - 12759 samples
# 	Win 5: ILLAL - 650 samples
# 	Win 6: ILLALS - 10 samples
# 	Win 7: GILLALS - 0 samples
# 	Weighted n samples: 16729.0
# 	478 predictions
# 	Xray DA: [10.42024013] Pred DA: 7.451350015009184
# 45/372: ILLALSA
# 	Win 4: LALS - 5137 samples
# 	Win 5: LLALS - 412 samples
# 	Win 6: LLALSA - 35 samples
# 	Win 7: ILLALSA - 0 samples
# 	Weighted n samples: 7854.0
# 	478 predictions
# 	Xray DA: [5.32993947] Pred DA: 8.49730691199479
# 46/372: LLALSAV
# 	Win 4: ALSA - 7328 samples
# 	Win 5: LALSA - 301 samples
# 	Win 6: LALSAV - 7 samples
# 	Win 7: LLALSAV - 0 samples
# 	Weighted n samples: 9183.0
# 	478 predictions
# 	Xray DA: [9.9283567] Pred DA: 8.428749733404588
# 47/372: LALSAVA
# 	Win 4: LSAV - 5648 samples
# 	Win 5: ALSAV - 391 samples
# 	Win 6: ALSAVA - 55 samples
# 	Win 7: LALSAVA - 0 samples
# 	Weighted n samples: 8379.0
# 	478 predictions
# 	Xray DA: [10.28401495] Pred DA: 9.653685679444322
# 48/372: ALSAVAT
# 	Win 4: SAVA - 5132 samples
# 	Win 5: LSAVA - 298 samples
# 	Win 6: LSAVAT - 72 samples
# 	Win 7: ALSAVAT - 0 samples
# 	Weighted n samples: 7424.0
# 	478 predictions
# 	Xray DA: [4.18118647] Pred DA: 8.14562228428747
# 49/372: LSAVATF
# 	Win 4: AVAT - 5226 samples
# 	Win 5: SAVAT - 265 samples
# 	Win 6: SAVATF - 7 samples
# 	Win 7: LSAVATF - 0 samples
# 	Weighted n samples: 6865.0
# 	478 predictions
# 	Xray DA: [2.21591203] Pred DA: 9.268829353327906
# 50/372: SAVATFV
# 	Win 4: VATF - 2427 samples
# 	Win 5: AVATF - 109 samples
# 	Win 6: AVATFV - 0 samples
# 	Win 7: SAVATFV - 0 samples
# 	Weighted n samples: 3081.0
# 	478 predictions
# 	Xray DA: [5.78337381] Pred DA: 11.843170440085467
# 51/372: AVATFVA
# 	Win 4: ATFV - 1685 samples
# 	Win 5: VATFV - 317 samples
# 	Win 6: VATFVA - 0 samples
# 	Win 7: AVATFVA - 0 samples
# 	Weighted n samples: 3587.0
# 	478 predictions
# 	Xray DA: [4.3459722] Pred DA: 13.101454190572428
# 52/372: VATFVAG
# 	Win 4: TFVA - 2148 samples
# 	Win 5: ATFVA - 48 samples
# 	Win 6: ATFVAG - 6 samples
# 	Win 7: VATFVAG - 0 samples
# 	Weighted n samples: 2478.0
# 	478 predictions
# 	Xray DA: [0.86617303] Pred DA: 13.198888388246743
# 53/372: ATFVAGI
# 	Win 4: FVAG - 2532 samples
# 	Win 5: TFVAG - 107 samples
# 	Win 6: TFVAGI - 0 samples
# 	Win 7: ATFVAGI - 0 samples
# 	Weighted n samples: 3174.0
# 	478 predictions
# 	Xray DA: [5.18910657] Pred DA: 11.973702989065428
# 54/372: TFVAGIL
# 	Win 4: VAGI - 4502 samples
# 	Win 5: FVAGI - 121 samples
# 	Win 6: FVAGIL - 2 samples
# 	Win 7: TFVAGIL - 0 samples
# 	Weighted n samples: 5242.0
# 	478 predictions
# 	Xray DA: [3.03111446] Pred DA: 16.90501147492871
# 55/372: FVAGILA
# 	Win 4: AGIL - 5016 samples
# 	Win 5: VAGIL - 502 samples
# 	Win 6: VAGILA - 41 samples
# 	Win 7: FVAGILA - 0 samples
# 	Weighted n samples: 8315.0
# 	478 predictions
# 	Xray DA: [7.94090758] Pred DA: 16.659953603241473
# 56/372: VAGILAG
# 	Win 4: GILA - 5708 samples
# 	Win 5: AGILA - 579 samples
# 	Win 6: AGILAG - 44 samples
# 	Win 7: VAGILAG - 0 samples
# 	Weighted n samples: 9490.0
# 	478 predictions
# 	Xray DA: [6.93167846] Pred DA: 12.662836563647694
# 57/372: AGILAGF
# 	Win 4: ILAG - 5027 samples
# 	Win 5: GILAG - 559 samples
# 	Win 6: GILAGF - 0 samples
# 	Win 7: AGILAGF - 0 samples
# 	Weighted n samples: 8381.0
# 	478 predictions
# 	Xray DA: [5.16315905] Pred DA: 15.199484675654581
# 58/372: GILAGFF
# 	Win 4: LAGF - 2981 samples
# 	Win 5: ILAGF - 146 samples
# 	Win 6: ILAGFF - 0 samples
# 	Win 7: GILAGFF - 0 samples
# 	Weighted n samples: 3857.0
# 	478 predictions
# 	Xray DA: [2.9391383] Pred DA: 11.383715551540105
# 59/372: ILAGFFA
# 	Win 4: AGFF - 1071 samples
# 	Win 5: LAGFF - 120 samples
# 	Win 6: LAGFFA - 4 samples
# 	Win 7: ILAGFFA - 0 samples
# 	Weighted n samples: 1819.0
# 	478 predictions
# 	Xray DA: [4.60605974] Pred DA: 13.746507737287608
# 60/372: LAGFFAD
# 	Win 4: GFFA - 1432 samples
# 	Win 5: AGFFA - 139 samples
# 	Win 6: AGFFAD - 0 samples
# 	Win 7: LAGFFAD - 0 samples
# 	Weighted n samples: 2266.0
# 	478 predictions
# 	Xray DA: [14.81180682] Pred DA: 13.12202205832268
# 61/372: AGFFADR
# 	Win 4: FFAD - 1583 samples
# 	Win 5: GFFAD - 78 samples
# 	Win 6: GFFADR - 21 samples
# 	Win 7: AGFFADR - 0 samples
# 	Weighted n samples: 2198.0
# 	478 predictions
# 	Xray DA: [12.91408858] Pred DA: 15.708278135698812
# 62/372: GFFADRN
# 	Win 4: FADR - 2287 samples
# 	Win 5: FFADR - 162 samples
# 	Win 6: FFADRN - 24 samples
# 	Win 7: GFFADRN - 0 samples
# 	Weighted n samples: 3427.0
# 	478 predictions
# 	Xray DA: [13.31141821] Pred DA: 11.424486576033344
# 63/372: FFADRNG
# 	Win 4: ADRN - 1114 samples
# 	Win 5: FADRN - 40 samples
# 	Win 6: FADRNG - 0 samples
# 	Win 7: FFADRNG - 0 samples
# 	Weighted n samples: 1354.0
# 	478 predictions
# 	Xray DA: [17.6748026] Pred DA: 19.08824607827794
# 64/372: FADRNGR
# 	Win 4: DRNG - 1758 samples
# 	Win 5: ADRNG - 46 samples
# 	Win 6: ADRNGR - 0 samples
# 	Win 7: FADRNGR - 0 samples
# 	Weighted n samples: 2034.0
# 	478 predictions
# 	Xray DA: [33.11339625] Pred DA: 24.83349404773684
# 65/372: ADRNGRK
# 	Win 4: RNGR - 1086 samples
# 	Win 5: DRNGR - 182 samples
# 	Win 6: DRNGRK - 28 samples
# 	Win 7: ADRNGRK - 0 samples
# 	Weighted n samples: 2374.0
# 	478 predictions
# 	Xray DA: [163.48670675] Pred DA: 74.55887152592852
# 66/372: DRNGRKP
# 	Win 4: NGRK - 1809 samples
# 	Win 5: RNGRK - 128 samples
# 	Win 6: RNGRKP - 0 samples
# 	Win 7: DRNGRKP - 0 samples
# 	Weighted n samples: 2577.0
# 	478 predictions
# 	Xray DA: [178.86475429] Pred DA: 73.88025030252275
# 67/372: RNGRKPV
# 	Win 4: GRKP - 1534 samples
# 	Win 5: NGRKP - 20 samples
# 	Win 6: NGRKPV - 1 samples
# 	Win 7: RNGRKPV - 0 samples
# 	Weighted n samples: 1661.0
# 	478 predictions
# 	Xray DA: [5.62152594] Pred DA: 29.532172543317227
# 68/372: NGRKPVM
# 	Win 4: RKPV - 1487 samples
# 	Win 5: GRKPV - 50 samples
# 	Win 6: GRKPVM - 3 samples
# 	Win 7: NGRKPVM - 0 samples
# 	Weighted n samples: 1808.0
# 	478 predictions
# 	Xray DA: [16.29346292] Pred DA: 18.442354323543555
# 69/372: GRKPVMV
# 	Win 4: KPVM - 1023 samples
# 	Win 5: RKPVM - 6 samples
# 	Win 6: RKPVMV - 0 samples
# 	Win 7: GRKPVMV - 0 samples
# 	Weighted n samples: 1059.0
# 	478 predictions
# 	Xray DA: [18.11364156] Pred DA: 15.89280733125732
# 70/372: RKPVMVF
# 	Win 4: PVMV - 983 samples
# 	Win 5: KPVMV - 108 samples
# 	Win 6: KPVMVF - 2 samples
# 	Win 7: RKPVMVF - 0 samples
# 	Weighted n samples: 1645.0
# 	478 predictions
# 	Xray DA: [24.83443252] Pred DA: 10.286865236837002
# 71/372: KPVMVFG
# 	Win 4: VMVF - 396 samples
# 	Win 5: PVMVF - 23 samples
# 	Win 6: PVMVFG - 0 samples
# 	Win 7: KPVMVFG - 0 samples
# 	Weighted n samples: 534.0
# 	478 predictions
# 	Xray DA: [13.75603431] Pred DA: 10.415945119714676
# 72/372: PVMVFGT
# 	Win 4: MVFG - 823 samples
# 	Win 5: VMVFG - 37 samples
# 	Win 6: VMVFGT - 7 samples
# 	Win 7: PVMVFGT - 0 samples
# 	Weighted n samples: 1094.0
# 	478 predictions
# 	Xray DA: [9.67366607] Pred DA: 10.91676912689962
# 73/372: VMVFGTI
# 	Win 4: VFGT - 2189 samples
# 	Win 5: MVFGT - 22 samples
# 	Win 6: MVFGTI - 0 samples
# 	Win 7: VMVFGTI - 0 samples
# 	Weighted n samples: 2321.0
# 	478 predictions
# 	Xray DA: [2.13856702] Pred DA: 8.338188704790618
# 74/372: MVFGTII
# 	Win 4: FGTI - 1468 samples
# 	Win 5: VFGTI - 148 samples
# 	Win 6: VFGTII - 0 samples
# 	Win 7: MVFGTII - 0 samples
# 	Weighted n samples: 2356.0
# 	478 predictions
# 	Xray DA: [15.71722396] Pred DA: 9.7301695915516
# 75/372: VFGTIIQ
# 	Win 4: GTII - 2050 samples
# 	Win 5: FGTII - 71 samples
# 	Win 6: FGTIIQ - 0 samples
# 	Win 7: VFGTIIQ - 0 samples
# 	Weighted n samples: 2476.0
# 	478 predictions
# 	Xray DA: [20.92385655] Pred DA: 16.0533124694019
# 76/372: FGTIIQL
# 	Win 4: TIIQ - 583 samples
# 	Win 5: GTIIQ - 8 samples
# 	Win 6: GTIIQL - 7 samples
# 	Win 7: FGTIIQL - 0 samples
# 	Weighted n samples: 680.0
# 	478 predictions
# 	Xray DA: [7.44266715] Pred DA: 6.88000830482521
# 77/372: GTIIQLL
# 	Win 4: IIQL - 1527 samples
# 	Win 5: TIIQL - 60 samples
# 	Win 6: TIIQLL - 8 samples
# 	Win 7: GTIIQLL - 0 samples
# 	Weighted n samples: 1943.0
# 	478 predictions
# 	Xray DA: [12.59171854] Pred DA: 6.928693648781319
# 78/372: TIIQLLG
# 	Win 4: IQLL - 3467 samples
# 	Win 5: IIQLL - 100 samples
# 	Win 6: IIQLLG - 2 samples
# 	Win 7: TIIQLLG - 0 samples
# 	Weighted n samples: 4081.0
# 	478 predictions
# 	Xray DA: [11.29489554] Pred DA: 6.030240050251513
# 79/372: IIQLLGA
# 	Win 4: QLLG - 4914 samples
# 	Win 5: IQLLG - 189 samples
# 	Win 6: IQLLGA - 30 samples
# 	Win 7: IIQLLGA - 0 samples
# 	Weighted n samples: 6258.0
# 	478 predictions
# 	Xray DA: [12.87630775] Pred DA: 5.4081179773238635
# 80/372: IQLLGAA
# 	Win 4: LLGA - 10582 samples
# 	Win 5: QLLGA - 317 samples
# 	Win 6: QLLGAA - 28 samples
# 	Win 7: IQLLGAA - 0 samples
# 	Weighted n samples: 12680.0
# 	478 predictions
# 	Xray DA: [4.19903623] Pred DA: 11.215566324186693
# 81/372: QLLGAAL
# 	Win 4: LGAA - 7680 samples
# 	Win 5: LLGAA - 970 samples
# 	Win 6: LLGAAL - 92 samples
# 	Win 7: QLLGAAL - 0 samples
# 	Weighted n samples: 14144.0
# 	478 predictions
# 	Xray DA: [5.73064778] Pred DA: 12.727229512185076
# 82/372: LLGAALA
# 	Win 4: GAAL - 8938 samples
# 	Win 5: LGAAL - 600 samples
# 	Win 6: LGAALA - 55 samples
# 	Win 7: LLGAALA - 0 samples
# 	Weighted n samples: 12923.0
# 	478 predictions
# 	Xray DA: [4.54517091] Pred DA: 7.693244391242411
# 83/372: LGAALAI
# 	Win 4: AALA - 16761 samples
# 	Win 5: GAALA - 1046 samples
# 	Win 6: GAALAI - 70 samples
# 	Win 7: LGAALAI - 13 samples
# 	Weighted n samples: 23631.0
# 	478 predictions
# 	Xray DA: [4.62099056] Pred DA: 6.109580249312311
# 84/372: GAALAIA
# 	Win 4: ALAI - 5830 samples
# 	Win 5: AALAI - 604 samples
# 	Win 6: AALAIA - 72 samples
# 	Win 7: GAALAIA - 0 samples
# 	Weighted n samples: 9958.0
# 	478 predictions
# 	Xray DA: [6.00842673] Pred DA: 9.010303481447925
# 85/372: AALAIAS
# 	Win 4: LAIA - 6148 samples
# 	Win 5: ALAIA - 783 samples
# 	Win 6: ALAIAS - 23 samples
# 	Win 7: AALAIAS - 3 samples
# 	Weighted n samples: 11031.0
# 	478 predictions
# 	Xray DA: [10.41397811] Pred DA: 12.787050797941783
# 86/372: ALAIASN
# 	Win 4: AIAS - 5432 samples
# 	Win 5: LAIAS - 253 samples
# 	Win 6: LAIASN - 0 samples
# 	Win 7: ALAIASN - 0 samples
# 	Weighted n samples: 6950.0
# 	478 predictions
# 	Xray DA: [6.01638485] Pred DA: 13.452219639140248
# 87/372: LAIASNL
# 	Win 4: IASN - 3346 samples
# 	Win 5: AIASN - 826 samples
# 	Win 6: AIASNL - 4 samples
# 	Win 7: LAIASNL - 0 samples
# 	Weighted n samples: 8330.0
# 	478 predictions
# 	Xray DA: [16.52843381] Pred DA: 25.369734745706655
# 88/372: AIASNLP
# 	Win 4: ASNL - 3529 samples
# 	Win 5: IASNL - 117 samples
# 	Win 6: IASNLP - 9 samples
# 	Win 7: AIASNLP - 0 samples
# 	Weighted n samples: 4294.0
# 	478 predictions
# 	Xray DA: [12.23435911] Pred DA: 46.89049994219202
# 89/372: IASNLPG
# 	Win 4: SNLP - 2100 samples
# 	Win 5: ASNLP - 141 samples
# 	Win 6: ASNLPG - 0 samples
# 	Win 7: IASNLPG - 0 samples
# 	Weighted n samples: 2946.0
# 	478 predictions
# 	Xray DA: [20.43924193] Pred DA: 70.47286694368219
# 90/372: ASNLPGH
# 	Win 4: NLPG - 3095 samples
# 	Win 5: SNLPG - 76 samples
# 	Win 6: SNLPGH - 0 samples
# 	Win 7: ASNLPGH - 0 samples
# 	Weighted n samples: 3551.0
# 	478 predictions
# 	Xray DA: [20.68746454] Pred DA: 60.335697864221615
# 91/372: SNLPGHV
# 	Win 4: LPGH - 1145 samples
# 	Win 5: NLPGH - 28 samples
# 	Win 6: NLPGHV - 0 samples
# 	Win 7: SNLPGHV - 0 samples
# 	Weighted n samples: 1313.0
# 	478 predictions
# 	Xray DA: [19.11645131] Pred DA: 66.01916026521475
# 92/372: NLPGHVN
# 	Win 4: PGHV - 925 samples
# 	Win 5: LPGHV - 107 samples
# 	Win 6: LPGHVN - 0 samples
# 	Win 7: NLPGHVN - 0 samples
# 	Weighted n samples: 1567.0
# 	478 predictions
# 	Xray DA: [36.31688537] Pred DA: 90.74108425319186
# 93/372: LPGHVNP
# 	Win 4: GHVN - 720 samples
# 	Win 5: PGHVN - 50 samples
# 	Win 6: PGHVNP - 0 samples
# 	Win 7: LPGHVNP - 0 samples
# 	Weighted n samples: 1020.0
# 	478 predictions
# 	Xray DA: [8.40599413] Pred DA: 74.28408122041687
# 94/372: PGHVNPW
# 	Win 4: HVNP - 586 samples
# 	Win 5: GHVNP - 28 samples
# 	Win 6: GHVNPW - 0 samples
# 	Win 7: PGHVNPW - 0 samples
# 	Weighted n samples: 754.0
# 	478 predictions
# 	Xray DA: [9.28802095] Pred DA: 67.89323009927234
# 95/372: GHVNPWS
# 	Win 4: VNPW - 153 samples
# 	Win 5: HVNPW - 0 samples
# 	Win 6: HVNPWS - 0 samples
# 	Win 7: GHVNPWS - 0 samples
# 	Weighted n samples: 153.0
# 	478 predictions
# 	Xray DA: [6.22674808] Pred DA: 55.91747332114497
# 96/372: HVNPWST
# 	Win 4: NPWS - 650 samples
# 	Win 5: VNPWS - 22 samples
# 	Win 6: VNPWST - 0 samples
# 	Win 7: HVNPWST - 0 samples
# 	Weighted n samples: 782.0
# 	478 predictions
# 	Xray DA: [20.89776281] Pred DA: 18.119638225446284
# 97/372: VNPWSTF
# 	Win 4: PWST - 199 samples
# 	Win 5: NPWST - 1 samples
# 	Win 6: NPWSTF - 0 samples
# 	Win 7: VNPWSTF - 0 samples
# 	Weighted n samples: 205.0
# 	478 predictions
# 	Xray DA: [14.56155867] Pred DA: 19.45475282338195
# 98/372: NPWSTFI
# 	Win 4: WSTF - 435 samples
# 	Win 5: PWSTF - 76 samples
# 	Win 6: PWSTFI - 0 samples
# 	Win 7: NPWSTFI - 0 samples
# 	Weighted n samples: 891.0
# 	478 predictions
# 	Xray DA: [7.84537544] Pred DA: 12.32021555404787
# 99/372: PWSTFIA
# 	Win 4: STFI - 2424 samples
# 	Win 5: WSTFI - 5 samples
# 	Win 6: WSTFIA - 0 samples
# 	Win 7: PWSTFIA - 0 samples
# 	Weighted n samples: 2454.0
# 	478 predictions
# 	Xray DA: [14.20015551] Pred DA: 17.915482421276884
# 100/372: WSTFIAF
# 	Win 4: TFIA - 1504 samples
# 	Win 5: STFIA - 42 samples
# 	Win 6: STFIAF - 4 samples
# 	Win 7: WSTFIAF - 0 samples
# 	Weighted n samples: 1784.0
# 	478 predictions
# 	Xray DA: [2.49286273] Pred DA: 10.977544457743111
# 101/372: STFIAFL
# 	Win 4: FIAF - 772 samples
# 	Win 5: TFIAF - 51 samples
# 	Win 6: TFIAFL - 0 samples
# 	Win 7: STFIAFL - 0 samples
# 	Weighted n samples: 1078.0
# 	478 predictions
# 	Xray DA: [9.48240675] Pred DA: 8.4383037771917
# 102/372: TFIAFLL
# 	Win 4: IAFL - 2317 samples
# 	Win 5: FIAFL - 187 samples
# 	Win 6: FIAFLL - 0 samples
# 	Win 7: TFIAFLL - 0 samples
# 	Weighted n samples: 3439.0
# 	478 predictions
# 	Xray DA: [12.3804678] Pred DA: 13.392776412702812
# 103/372: FIAFLLI
# 	Win 4: AFLL - 4444 samples
# 	Win 5: IAFLL - 268 samples
# 	Win 6: IAFLLI - 4 samples
# 	Win 7: FIAFLLI - 0 samples
# 	Weighted n samples: 6080.0
# 	478 predictions
# 	Xray DA: [5.26519246] Pred DA: 13.188171718496816
# 104/372: IAFLLIS
# 	Win 4: FLLI - 2343 samples
# 	Win 5: AFLLI - 292 samples
# 	Win 6: AFLLIS - 12 samples
# 	Win 7: IAFLLIS - 0 samples
# 	Weighted n samples: 4179.0
# 	478 predictions
# 	Xray DA: [5.25118926] Pred DA: 6.594841887711675
# 105/372: AFLLISF
# 	Win 4: LLIS - 7345 samples
# 	Win 5: FLLIS - 223 samples
# 	Win 6: FLLISF - 0 samples
# 	Win 7: AFLLISF - 0 samples
# 	Weighted n samples: 8683.0
# 	478 predictions
# 	Xray DA: [4.77979687] Pred DA: 10.625796483322022
# 106/372: FLLISFG
# 	Win 4: LISF - 1769 samples
# 	Win 5: LLISF - 81 samples
# 	Win 6: LLISFG - 6 samples
# 	Win 7: FLLISFG - 0 samples
# 	Weighted n samples: 2297.0
# 	478 predictions
# 	Xray DA: [11.44570578] Pred DA: 6.708366725815313
# 107/372: LLISFGY
# 	Win 4: ISFG - 1771 samples
# 	Win 5: LISFG - 454 samples
# 	Win 6: LISFGY - 0 samples
# 	Win 7: LLISFGY - 0 samples
# 	Weighted n samples: 4495.0
# 	478 predictions
# 	Xray DA: [11.36113613] Pred DA: 9.399339244424498
# 108/372: LISFGYN
# 	Win 4: SFGY - 1495 samples
# 	Win 5: ISFGY - 60 samples
# 	Win 6: ISFGYN - 0 samples
# 	Win 7: LISFGYN - 0 samples
# 	Weighted n samples: 1855.0
# 	478 predictions
# 	Xray DA: [10.44892222] Pred DA: 12.013510913095962
# 109/372: ISFGYNF
# 	Win 4: FGYN - 1055 samples
# 	Win 5: SFGYN - 70 samples
# 	Win 6: SFGYNF - 0 samples
# 	Win 7: ISFGYNF - 0 samples
# 	Weighted n samples: 1475.0
# 	478 predictions
# 	Xray DA: [16.14244629] Pred DA: 19.392055019830742
# 110/372: SFGYNFV
# 	Win 4: GYNF - 1472 samples
# 	Win 5: FGYNF - 69 samples
# 	Win 6: FGYNFV - 0 samples
# 	Win 7: SFGYNFV - 0 samples
# 	Weighted n samples: 1886.0
# 	478 predictions
# 	Xray DA: [2.47947984] Pred DA: 11.548207269243587
# 111/372: FGYNFVI
# 	Win 4: YNFV - 540 samples
# 	Win 5: GYNFV - 24 samples
# 	Win 6: GYNFVI - 0 samples
# 	Win 7: FGYNFVI - 0 samples
# 	Weighted n samples: 684.0
# 	478 predictions
# 	Xray DA: [7.95061766] Pred DA: 13.78306332992856
# 112/372: GYNFVIT
# 	Win 4: NFVI - 854 samples
# 	Win 5: YNFVI - 33 samples
# 	Win 6: YNFVIT - 0 samples
# 	Win 7: GYNFVIT - 0 samples
# 	Weighted n samples: 1052.0
# 	478 predictions
# 	Xray DA: [9.50340655] Pred DA: 12.231348672599935
# 113/372: YNFVITA
# 	Win 4: FVIT - 1364 samples
# 	Win 5: NFVIT - 87 samples
# 	Win 6: NFVITA - 2 samples
# 	Win 7: YNFVITA - 0 samples
# 	Weighted n samples: 1900.0
# 	478 predictions
# 	Xray DA: [12.97475522] Pred DA: 15.134875178676118
# 114/372: NFVITAG
# 	Win 4: VITA - 3346 samples
# 	Win 5: FVITA - 76 samples
# 	Win 6: FVITAG - 8 samples
# 	Win 7: NFVITAG - 0 samples
# 	Weighted n samples: 3858.0
# 	478 predictions
# 	Xray DA: [11.42985688] Pred DA: 11.317837396416564
# 115/372: FVITAGN
# 	Win 4: ITAG - 4530 samples
# 	Win 5: VITAG - 666 samples
# 	Win 6: VITAGN - 0 samples
# 	Win 7: FVITAGN - 0 samples
# 	Weighted n samples: 8526.0
# 	478 predictions
# 	Xray DA: [17.25112183] Pred DA: 12.152246114648404
# 116/372: VITAGNA
# 	Win 4: TAGN - 3209 samples
# 	Win 5: ITAGN - 183 samples
# 	Win 6: ITAGNA - 30 samples
# 	Win 7: VITAGNA - 0 samples
# 	Weighted n samples: 4517.0
# 	478 predictions
# 	Xray DA: [1.32579506] Pred DA: 10.989820314323602
# 117/372: ITAGNAM
# 	Win 4: AGNA - 5122 samples
# 	Win 5: TAGNA - 468 samples
# 	Win 6: TAGNAM - 14 samples
# 	Win 7: ITAGNAM - 0 samples
# 	Weighted n samples: 8028.0
# 	478 predictions
# 	Xray DA: [9.31650343] Pred DA: 17.36333999618119
# 118/372: TAGNAMI
# 	Win 4: GNAM - 921 samples
# 	Win 5: AGNAM - 188 samples
# 	Win 6: AGNAMI - 97 samples
# 	Win 7: TAGNAMI - 0 samples
# 	Weighted n samples: 2728.0
# 	478 predictions
# 	Xray DA: [7.44121576] Pred DA: 10.678206954139569
# 119/372: AGNAMII
# 	Win 4: NAMI - 706 samples
# 	Win 5: GNAMI - 109 samples
# 	Win 6: GNAMII - 0 samples
# 	Win 7: AGNAMII - 0 samples
# 	Weighted n samples: 1360.0
# 	478 predictions
# 	Xray DA: [6.37297449] Pred DA: 11.62476921014876
# 120/372: GNAMIID
# 	Win 4: AMII - 842 samples
# 	Win 5: NAMII - 57 samples
# 	Win 6: NAMIID - 0 samples
# 	Win 7: GNAMIID - 0 samples
# 	Weighted n samples: 1184.0
# 	478 predictions
# 	Xray DA: [0.94370354] Pred DA: 10.29193146826903
# 121/372: NAMIIDA
# 	Win 4: MIID - 796 samples
# 	Win 5: AMIID - 75 samples
# 	Win 6: AMIIDA - 12 samples
# 	Win 7: NAMIIDA - 0 samples
# 	Weighted n samples: 1330.0
# 	478 predictions
# 	Xray DA: [18.33029906] Pred DA: 12.429649899655514
# 122/372: AMIIDAS
# 	Win 4: IIDA - 2691 samples
# 	Win 5: MIIDA - 125 samples
# 	Win 6: MIIDAS - 40 samples
# 	Win 7: AMIIDAS - 0 samples
# 	Weighted n samples: 3721.0
# 	478 predictions
# 	Xray DA: [14.64408823] Pred DA: 13.743140518775055
# 123/372: MIIDASN
# 	Win 4: IDAS - 2556 samples
# 	Win 5: IIDAS - 111 samples
# 	Win 6: IIDASN - 2 samples
# 	Win 7: MIIDASN - 0 samples
# 	Weighted n samples: 3236.0
# 	478 predictions
# 	Xray DA: [3.35234519] Pred DA: 17.228011129050905
# 124/372: IIDASNA
# 	Win 4: DASN - 1610 samples
# 	Win 5: IDASN - 172 samples
# 	Win 6: IDASNA - 0 samples
# 	Win 7: IIDASNA - 0 samples
# 	Weighted n samples: 2642.0
# 	478 predictions
# 	Xray DA: [10.78623662] Pred DA: 38.075431622080266
# 125/372: IDASNAE
# 	Win 4: ASNA - 1689 samples
# 	Win 5: DASNA - 62 samples
# 	Win 6: DASNAE - 2 samples
# 	Win 7: IDASNAE - 0 samples
# 	Weighted n samples: 2075.0
# 	478 predictions
# 	Xray DA: [3.59120051] Pred DA: 40.93943840058567
# 126/372: DASNAEN
# 	Win 4: SNAE - 1424 samples
# 	Win 5: ASNAE - 207 samples
# 	Win 6: ASNAEN - 8 samples
# 	Win 7: DASNAEN - 0 samples
# 	Weighted n samples: 2722.0
# 	478 predictions
# 	Xray DA: [7.85094471] Pred DA: 53.54199743157655
# 127/372: ASNAENR
# 	Win 4: NAEN - 1226 samples
# 	Win 5: SNAEN - 33 samples
# 	Win 6: SNAENR - 0 samples
# 	Win 7: ASNAENR - 0 samples
# 	Weighted n samples: 1424.0
# 	478 predictions
# 	Xray DA: [5.48807391] Pred DA: 32.97161582852288
# 128/372: SNAENRK
# 	Win 4: AENR - 2467 samples
# 	Win 5: NAENR - 13 samples
# 	Win 6: NAENRK - 0 samples
# 	Win 7: SNAENRK - 0 samples
# 	Weighted n samples: 2545.0
# 	478 predictions
# 	Xray DA: [7.80138939] Pred DA: 28.9126927545444
# 129/372: NAENRKV
# 	Win 4: ENRK - 1059 samples
# 	Win 5: AENRK - 164 samples
# 	Win 6: AENRKV - 0 samples
# 	Win 7: NAENRKV - 0 samples
# 	Weighted n samples: 2043.0
# 	478 predictions
# 	Xray DA: [16.15562955] Pred DA: 31.28807393191782
# 130/372: AENRKVV
# 	Win 4: NRKV - 1386 samples
# 	Win 5: ENRKV - 89 samples
# 	Win 6: ENRKVV - 2 samples
# 	Win 7: AENRKVV - 0 samples
# 	Weighted n samples: 1934.0
# 	478 predictions
# 	Xray DA: [18.51679909] Pred DA: 21.65723617804495
# 131/372: ENRKVVF
# 	Win 4: RKVV - 3568 samples
# 	Win 5: NRKVV - 50 samples
# 	Win 6: NRKVVF - 0 samples
# 	Win 7: ENRKVVF - 0 samples
# 	Weighted n samples: 3868.0
# 	478 predictions
# 	Xray DA: [3.56053003] Pred DA: 10.110758484764938
# 132/372: NRKVVFM
# 	Win 4: KVVF - 1988 samples
# 	Win 5: RKVVF - 79 samples
# 	Win 6: RKVVFM - 0 samples
# 	Win 7: NRKVVFM - 0 samples
# 	Weighted n samples: 2462.0
# 	478 predictions
# 	Xray DA: [13.28040335] Pred DA: 11.99691276956305
# 133/372: RKVVFML
# 	Win 4: VVFM - 346 samples
# 	Win 5: KVVFM - 47 samples
# 	Win 6: KVVFML - 0 samples
# 	Win 7: RKVVFML - 0 samples
# 	Weighted n samples: 628.0
# 	478 predictions
# 	Xray DA: [9.59214373] Pred DA: 13.42685392764168
# 134/372: KVVFMLD
# 	Win 4: VFML - 893 samples
# 	Win 5: VVFML - 28 samples
# 	Win 6: VVFMLD - 0 samples
# 	Win 7: KVVFMLD - 0 samples
# 	Weighted n samples: 1061.0
# 	478 predictions
# 	Xray DA: [8.99771391] Pred DA: 8.20325161036511
# 135/372: VVFMLDY
# 	Win 4: FMLD - 877 samples
# 	Win 5: VFMLD - 0 samples
# 	Win 6: VFMLDY - 0 samples
# 	Win 7: VVFMLDY - 0 samples
# 	Weighted n samples: 877.0
# 	478 predictions
# 	Xray DA: [5.46700192] Pred DA: 10.56404480261843
# 136/372: VFMLDYW
# 	Win 4: MLDY - 695 samples
# 	Win 5: FMLDY - 32 samples
# 	Win 6: FMLDYW - 0 samples
# 	Win 7: VFMLDYW - 0 samples
# 	Weighted n samples: 887.0
# 	478 predictions
# 	Xray DA: [10.96650672] Pred DA: 6.984701521167812
# 137/372: FMLDYWA
# 	Win 4: LDYW - 2254 samples
# 	Win 5: MLDYW - 10 samples
# 	Win 6: MLDYWA - 9 samples
# 	Win 7: FMLDYWA - 0 samples
# 	Weighted n samples: 2377.0
# 	478 predictions
# 	Xray DA: [15.81756712] Pred DA: 9.692597625652951
# 138/372: MLDYWAQ
# 	Win 4: DYWA - 194 samples
# 	Win 5: LDYWA - 36 samples
# 	Win 6: LDYWAQ - 1 samples
# 	Win 7: MLDYWAQ - 0 samples
# 	Weighted n samples: 417.0
# 	478 predictions
# 	Xray DA: [18.66023037] Pred DA: 10.050311560674407
# 139/372: LDYWAQN
# 	Win 4: YWAQ - 1072 samples
# 	Win 5: DYWAQ - 7 samples
# 	Win 6: DYWAQN - 0 samples
# 	Win 7: LDYWAQN - 0 samples
# 	Weighted n samples: 1114.0
# 	478 predictions
# 	Xray DA: [13.50650328] Pred DA: 7.245168042794278
# 140/372: DYWAQNL
# 	Win 4: WAQN - 235 samples
# 	Win 5: YWAQN - 0 samples
# 	Win 6: YWAQNL - 0 samples
# 	Win 7: DYWAQNL - 0 samples
# 	Weighted n samples: 235.0
# 	478 predictions
# 	Xray DA: [12.93468419] Pred DA: 5.269403498725135
# 141/372: YWAQNLS
# 	Win 4: AQNL - 2210 samples
# 	Win 5: WAQNL - 0 samples
# 	Win 6: WAQNLS - 0 samples
# 	Win 7: YWAQNLS - 0 samples
# 	Weighted n samples: 2210.0
# 	478 predictions
# 	Xray DA: [5.04861352] Pred DA: 8.355954965057556
# 142/372: WAQNLSV
# 	Win 4: QNLS - 2468 samples
# 	Win 5: AQNLS - 124 samples
# 	Win 6: AQNLSV - 0 samples
# 	Win 7: WAQNLSV - 0 samples
# 	Weighted n samples: 3212.0
# 	478 predictions
# 	Xray DA: [3.65325012] Pred DA: 17.596452682082813
# 143/372: AQNLSVI
# 	Win 4: NLSV - 3270 samples
# 	Win 5: QNLSV - 153 samples
# 	Win 6: QNLSVI - 9 samples
# 	Win 7: AQNLSVI - 0 samples
# 	Weighted n samples: 4251.0
# 	478 predictions
# 	Xray DA: [6.13537823] Pred DA: 9.955896167000759
# 144/372: QNLSVIL
# 	Win 4: LSVI - 3891 samples
# 	Win 5: NLSVI - 335 samples
# 	Win 6: NLSVIL - 4 samples
# 	Win 7: QNLSVIL - 0 samples
# 	Weighted n samples: 5929.0
# 	478 predictions
# 	Xray DA: [0.2184149] Pred DA: 11.421429580890608
# 145/372: NLSVILG
# 	Win 4: SVIL - 3899 samples
# 	Win 5: LSVIL - 315 samples
# 	Win 6: LSVILG - 0 samples
# 	Win 7: NLSVILG - 0 samples
# 	Weighted n samples: 5789.0
# 	478 predictions
# 	Xray DA: [7.22136845] Pred DA: 11.497158358006416
# 146/372: LSVILGA
# 	Win 4: VILG - 5816 samples
# 	Win 5: SVILG - 109 samples
# 	Win 6: SVILGA - 9 samples
# 	Win 7: LSVILGA - 0 samples
# 	Weighted n samples: 6533.0
# 	478 predictions
# 	Xray DA: [6.19616383] Pred DA: 10.419977614215615
# 147/372: SVILGAA
# 	Win 4: ILGA - 4860 samples
# 	Win 5: VILGA - 963 samples
# 	Win 6: VILGAA - 19 samples
# 	Win 7: SVILGAA - 0 samples
# 	Weighted n samples: 10771.0
# 	478 predictions
# 	Xray DA: [0.11743691] Pred DA: 14.305050097540375
# 148/372: VILGAAL
# 	Win 4: LGAA - 7680 samples
# 	Win 5: ILGAA - 209 samples
# 	Win 6: ILGAAL - 34 samples
# 	Win 7: VILGAAL - 0 samples
# 	Weighted n samples: 9172.0
# 	478 predictions
# 	Xray DA: [13.11058034] Pred DA: 12.999298619769643
# 149/372: ILGAALG
# 	Win 4: GAAL - 8938 samples
# 	Win 5: LGAAL - 600 samples
# 	Win 6: LGAALG - 33 samples
# 	Win 7: ILGAALG - 11 samples
# 	Weighted n samples: 12857.0
# 	478 predictions
# 	Xray DA: [12.47961199] Pred DA: 7.340535136525311
# 150/372: LGAALGA
# 	Win 4: AALG - 15505 samples
# 	Win 5: GAALG - 494 samples
# 	Win 6: GAALGA - 24 samples
# 	Win 7: LGAALGA - 11 samples
# 	Weighted n samples: 18725.0
# 	478 predictions
# 	Xray DA: [13.10650251] Pred DA: 6.831928551041475
# 151/372: GAALGAW
# 	Win 4: ALGA - 8804 samples
# 	Win 5: AALGA - 775 samples
# 	Win 6: AALGAW - 4 samples
# 	Win 7: GAALGAW - 0 samples
# 	Weighted n samples: 13482.0
# 	478 predictions
# 	Xray DA: [11.00973908] Pred DA: 12.339322878975215
# 152/372: AALGAWL
# 	Win 4: LGAW - 647 samples
# 	Win 5: ALGAW - 69 samples
# 	Win 6: ALGAWL - 20 samples
# 	Win 7: AALGAWL - 0 samples
# 	Weighted n samples: 1201.0
# 	478 predictions
# 	Xray DA: [28.17104959] Pred DA: 31.56486138926928
# 153/372: ALGAWLF
# 	Win 4: GAWL - 897 samples
# 	Win 5: LGAWL - 57 samples
# 	Win 6: LGAWLF - 0 samples
# 	Win 7: ALGAWLF - 0 samples
# 	Weighted n samples: 1239.0
# 	478 predictions
# 	Xray DA: [11.64354331] Pred DA: 12.458245362681797
# 154/372: LGAWLFR
# 	Win 4: AWLF - 481 samples
# 	Win 5: GAWLF - 42 samples
# 	Win 6: GAWLFR - 0 samples
# 	Win 7: LGAWLFR - 0 samples
# 	Weighted n samples: 733.0
# 	478 predictions
# 	Xray DA: [21.06259384] Pred DA: 22.21340135772366
# 155/372: GAWLFRP
# 	Win 4: WLFR - 531 samples
# 	Win 5: AWLFR - 3 samples
# 	Win 6: AWLFRP - 0 samples
# 	Win 7: GAWLFRP - 0 samples
# 	Weighted n samples: 549.0
# 	478 predictions
# 	Xray DA: [11.46911634] Pred DA: 34.282270159094935
# 156/372: AWLFRPA
# 	Win 4: LFRP - 1720 samples
# 	Win 5: WLFRP - 2 samples
# 	Win 6: WLFRPA - 0 samples
# 	Win 7: AWLFRPA - 0 samples
# 	Weighted n samples: 1732.0
# 	478 predictions
# 	Xray DA: [19.40629176] Pred DA: 29.40650734806515
# 157/372: WLFRPAF
# 	Win 4: FRPA - 924 samples
# 	Win 5: LFRPA - 38 samples
# 	Win 6: LFRPAF - 0 samples
# 	Win 7: WLFRPAF - 0 samples
# 	Weighted n samples: 1152.0
# 	478 predictions
# 	Xray DA: [17.81071815] Pred DA: 54.426855271099036
# 158/372: LFRPAFE
# 	Win 4: RPAF - 1143 samples
# 	Win 5: FRPAF - 25 samples
# 	Win 6: FRPAFE - 0 samples
# 	Win 7: LFRPAFE - 0 samples
# 	Weighted n samples: 1293.0
# 	478 predictions
# 	Xray DA: [33.6635018] Pred DA: 47.38358495397102
# 159/372: FRPAFEA
# 	Win 4: PAFE - 1480 samples
# 	Win 5: RPAFE - 84 samples
# 	Win 6: RPAFEA - 6 samples
# 	Win 7: FRPAFEA - 0 samples
# 	Weighted n samples: 2026.0
# 	478 predictions
# 	Xray DA: [23.01563424] Pred DA: 76.55608899328607
# 160/372: RPAFEAL
# 	Win 4: AFEA - 2924 samples
# 	Win 5: PAFEA - 79 samples
# 	Win 6: PAFEAL - 7 samples
# 	Win 7: RPAFEAL - 0 samples
# 	Weighted n samples: 3447.0
# 	478 predictions
# 	Xray DA: [18.68780617] Pred DA: 29.13637385898766
# 161/372: PAFEALL
# 	Win 4: FEAL - 3437 samples
# 	Win 5: AFEAL - 252 samples
# 	Win 6: AFEALL - 35 samples
# 	Win 7: PAFEALL - 0 samples
# 	Weighted n samples: 5194.0
# 	478 predictions
# 	Xray DA: [12.66768279] Pred DA: 15.92721629923908
# 162/372: AFEALLV
# 	Win 4: EALL - 10518 samples
# 	Win 5: FEALL - 376 samples
# 	Win 6: FEALLV - 89 samples
# 	Win 7: AFEALLV - 0 samples
# 	Weighted n samples: 13397.0
# 	478 predictions
# 	Xray DA: [5.54847024] Pred DA: 9.075255700272539
# 163/372: FEALLVI
# 	Win 4: ALLV - 6431 samples
# 	Win 5: EALLV - 376 samples
# 	Win 6: EALLVI - 24 samples
# 	Win 7: FEALLVI - 0 samples
# 	Weighted n samples: 8855.0
# 	478 predictions
# 	Xray DA: [8.03787339] Pred DA: 11.275210496298422
# 164/372: EALLVIL
# 	Win 4: LLVI - 3440 samples
# 	Win 5: ALLVI - 258 samples
# 	Win 6: ALLVIL - 37 samples
# 	Win 7: EALLVIL - 0 samples
# 	Weighted n samples: 5247.0
# 	478 predictions
# 	Xray DA: [8.56678826] Pred DA: 7.842168309781652
# 165/372: ALLVILL
# 	Win 4: LVIL - 3377 samples
# 	Win 5: LLVIL - 423 samples
# 	Win 6: LLVILL - 28 samples
# 	Win 7: ALLVILL - 0 samples
# 	Weighted n samples: 6111.0
# 	478 predictions
# 	Xray DA: [7.15770502] Pred DA: 6.659839455626462
# 166/372: LLVILLL
# 	Win 4: VILL - 4018 samples
# 	Win 5: LVILL - 218 samples
# 	Win 6: LVILLL - 49 samples
# 	Win 7: LLVILLL - 20 samples
# 	Weighted n samples: 5829.0
# 	478 predictions
# 	Xray DA: [3.15812614] Pred DA: 6.183259389117755
# 167/372: LVILLLT
# 	Win 4: ILLL - 6216 samples
# 	Win 5: VILLL - 261 samples
# 	Win 6: VILLLT - 82 samples
# 	Win 7: LVILLLT - 0 samples
# 	Weighted n samples: 8356.0
# 	478 predictions
# 	Xray DA: [4.98940683] Pred DA: 9.1180702142107
# 168/372: VILLLTV
# 	Win 4: LLLT - 6294 samples
# 	Win 5: ILLLT - 381 samples
# 	Win 6: ILLLTV - 50 samples
# 	Win 7: VILLLTV - 49 samples
# 	Weighted n samples: 9322.0
# 	478 predictions
# 	Xray DA: [1.57986062] Pred DA: 5.903642468311663
# 169/372: ILLLTVL
# 	Win 4: LLTV - 4181 samples
# 	Win 5: LLLTV - 448 samples
# 	Win 6: LLLTVL - 65 samples
# 	Win 7: ILLLTVL - 1 samples
# 	Weighted n samples: 7332.0
# 	478 predictions
# 	Xray DA: [3.54115612] Pred DA: 5.408580612095969
# 170/372: LLLTVLV
# 	Win 4: LTVL - 10194 samples
# 	Win 5: LLTVL - 622 samples
# 	Win 6: LLTVLV - 58 samples
# 	Win 7: LLLTVLV - 0 samples
# 	Weighted n samples: 14332.0
# 	478 predictions
# 	Xray DA: [8.16798352] Pred DA: 9.024069819775072
# 171/372: LLTVLVS
# 	Win 4: TVLV - 5978 samples
# 	Win 5: LTVLV - 478 samples
# 	Win 6: LTVLVS - 29 samples
# 	Win 7: LLTVLVS - 24 samples
# 	Weighted n samples: 9241.0
# 	478 predictions
# 	Xray DA: [64.460081] Pred DA: 50.65019703632653
# 172/372: LTVLVSF
# 	Win 4: VLVS - 5219 samples
# 	Win 5: TVLVS - 340 samples
# 	Win 6: TVLVSF - 30 samples
# 	Win 7: LTVLVSF - 24 samples
# 	Weighted n samples: 7661.0
# 	478 predictions
# 	Xray DA: [75.47500409] Pred DA: 58.029282806382774
# 173/372: TVLVSFF
# 	Win 4: LVSF - 2598 samples
# 	Win 5: VLVSF - 146 samples
# 	Win 6: VLVSFF - 0 samples
# 	Win 7: TVLVSFF - 0 samples
# 	Weighted n samples: 3474.0
# 	478 predictions
# 	Xray DA: [17.40289152] Pred DA: 9.59964320995128
# 174/372: VLVSFFL
# 	Win 4: VSFF - 1513 samples
# 	Win 5: LVSFF - 40 samples
# 	Win 6: LVSFFL - 0 samples
# 	Win 7: VLVSFFL - 0 samples
# 	Weighted n samples: 1753.0
# 	478 predictions
# 	Xray DA: [10.39104813] Pred DA: 8.305876638575505
# 175/372: LVSFFLT
# 	Win 4: SFFL - 1766 samples
# 	Win 5: VSFFL - 123 samples
# 	Win 6: VSFFLT - 6 samples
# 	Win 7: LVSFFLT - 0 samples
# 	Weighted n samples: 2546.0
# 	478 predictions
# 	Xray DA: [3.97201622] Pred DA: 8.758191161223952
# 176/372: VSFFLTT
# 	Win 4: FFLT - 1224 samples
# 	Win 5: SFFLT - 74 samples
# 	Win 6: SFFLTT - 0 samples
# 	Win 7: VSFFLTT - 0 samples
# 	Weighted n samples: 1668.0
# 	478 predictions
# 	Xray DA: [6.66805725] Pred DA: 8.500499154408626
# 177/372: SFFLTTF
# 	Win 4: FLTT - 1769 samples
# 	Win 5: FFLTT - 111 samples
# 	Win 6: FFLTTF - 0 samples
# 	Win 7: SFFLTTF - 0 samples
# 	Weighted n samples: 2435.0
# 	478 predictions
# 	Xray DA: [11.54316448] Pred DA: 12.168857903495748
# 178/372: FFLTTFV
# 	Win 4: LTTF - 2318 samples
# 	Win 5: FLTTF - 134 samples
# 	Win 6: FLTTFV - 0 samples
# 	Win 7: FFLTTFV - 0 samples
# 	Weighted n samples: 3122.0
# 	478 predictions
# 	Xray DA: [19.38862411] Pred DA: 14.236979035749055
# 179/372: FLTTFVM
# 	Win 4: TTFV - 1579 samples
# 	Win 5: LTTFV - 134 samples
# 	Win 6: LTTFVM - 2 samples
# 	Win 7: FLTTFVM - 0 samples
# 	Weighted n samples: 2397.0
# 	478 predictions
# 	Xray DA: [11.32325591] Pred DA: 20.869891468512254
# 180/372: LTTFVMT
# 	Win 4: TFVM - 422 samples
# 	Win 5: TTFVM - 2 samples
# 	Win 6: TTFVMT - 0 samples
# 	Win 7: LTTFVMT - 0 samples
# 	Weighted n samples: 434.0
# 	478 predictions
# 	Xray DA: [46.9566589] Pred DA: 35.40106465023896
# 181/372: TTFVMTE
# 	Win 4: FVMT - 297 samples
# 	Win 5: TFVMT - 0 samples
# 	Win 6: TFVMTE - 0 samples
# 	Win 7: TTFVMTE - 0 samples
# 	Weighted n samples: 297.0
# 	478 predictions
# 	Xray DA: [37.28839039] Pred DA: 34.05993145071169
# 182/372: TFVMTET
# 	Win 4: VMTE - 661 samples
# 	Win 5: FVMTE - 11 samples
# 	Win 6: FVMTET - 0 samples
# 	Win 7: TFVMTET - 0 samples
# 	Weighted n samples: 727.0
# 	478 predictions
# 	Xray DA: [3.85099619] Pred DA: 75.45877406053447
# 183/372: FVMTETF
# 	Win 4: MTET - 1588 samples
# 	Win 5: VMTET - 1 samples
# 	Win 6: VMTETF - 0 samples
# 	Win 7: FVMTETF - 0 samples
# 	Weighted n samples: 1594.0
# 	478 predictions
# 	Xray DA: [22.02960147] Pred DA: 91.64746850473054
# 184/372: VMTETFK
# 	Win 4: TETF - 1926 samples
# 	Win 5: MTETF - 31 samples
# 	Win 6: MTETFK - 2 samples
# 	Win 7: VMTETFK - 0 samples
# 	Weighted n samples: 2126.0
# 	478 predictions
# 	Xray DA: [15.97523912] Pred DA: 85.68530587082003
# 185/372: MTETFKP
# 	Win 4: ETFK - 1976 samples
# 	Win 5: TETFK - 20 samples
# 	Win 6: TETFKP - 0 samples
# 	Win 7: MTETFKP - 0 samples
# 	Weighted n samples: 2096.0
# 	478 predictions
# 	Xray DA: [7.13241618] Pred DA: 73.55600317062704
# 186/372: TETFKPT
# 	Win 4: TFKP - 1100 samples
# 	Win 5: ETFKP - 22 samples
# 	Win 6: ETFKPT - 0 samples
# 	Win 7: TETFKPT - 0 samples
# 	Weighted n samples: 1232.0
# 	478 predictions
# 	Xray DA: [7.6402639] Pred DA: 74.3339702695218
# 187/372: NIFQAYK
# 	Win 4: FQAY - 430 samples
# 	Win 5: IFQAY - 7 samples
# 	Win 6: IFQAYK - 0 samples
# 	Win 7: NIFQAYK - 0 samples
# 	Weighted n samples: 472.0
# 	478 predictions
# 	Xray DA: [10.42298306] Pred DA: 17.698729222653768
# 188/372: IFQAYKT
# 	Win 4: QAYK - 1019 samples
# 	Win 5: FQAYK - 18 samples
# 	Win 6: FQAYKT - 0 samples
# 	Win 7: IFQAYKT - 0 samples
# 	Weighted n samples: 1127.0
# 	478 predictions
# 	Xray DA: [17.40593172] Pred DA: 29.465645221650018
# 189/372: FQAYKTV
# 	Win 4: AYKT - 1561 samples
# 	Win 5: QAYKT - 51 samples
# 	Win 6: QAYKTV - 0 samples
# 	Win 7: FQAYKTV - 0 samples
# 	Weighted n samples: 1867.0
# 	478 predictions
# 	Xray DA: [13.84010043] Pred DA: 23.84852493442387
# 190/372: QAYKTVL
# 	Win 4: YKTV - 800 samples
# 	Win 5: AYKTV - 74 samples
# 	Win 6: AYKTVL - 17 samples
# 	Win 7: QAYKTVL - 0 samples
# 	Weighted n samples: 1363.0
# 	478 predictions
# 	Xray DA: [10.23559231] Pred DA: 11.678706641463265
# 191/372: AYKTVLQ
# 	Win 4: KTVL - 4197 samples
# 	Win 5: YKTVL - 52 samples
# 	Win 6: YKTVLQ - 0 samples
# 	Win 7: AYKTVLQ - 0 samples
# 	Weighted n samples: 4509.0
# 	478 predictions
# 	Xray DA: [7.59338991] Pred DA: 12.771215911727817
# 192/372: YKTVLQD
# 	Win 4: TVLQ - 2269 samples
# 	Win 5: KTVLQ - 262 samples
# 	Win 6: KTVLQD - 2 samples
# 	Win 7: YKTVLQD - 0 samples
# 	Weighted n samples: 3855.0
# 	478 predictions
# 	Xray DA: [2.14908486] Pred DA: 15.756381790927266
# 193/372: KTVLQDK
# 	Win 4: VLQD - 2796 samples
# 	Win 5: TVLQD - 91 samples
# 	Win 6: TVLQDK - 0 samples
# 	Win 7: KTVLQDK - 0 samples
# 	Weighted n samples: 3342.0
# 	478 predictions
# 	Xray DA: [1.1235136] Pred DA: 15.288985753135087
# 194/372: TVLQDKT
# 	Win 4: LQDK - 3090 samples
# 	Win 5: VLQDK - 218 samples
# 	Win 6: VLQDKT - 0 samples
# 	Win 7: TVLQDKT - 0 samples
# 	Weighted n samples: 4398.0
# 	478 predictions
# 	Xray DA: [7.66125098] Pred DA: 26.833565531110235
# 195/372: VLQDKTY
# 	Win 4: QDKT - 1119 samples
# 	Win 5: LQDKT - 194 samples
# 	Win 6: LQDKTY - 0 samples
# 	Win 7: VLQDKTY - 0 samples
# 	Weighted n samples: 2283.0
# 	478 predictions
# 	Xray DA: [4.19608919] Pred DA: 44.18063239162806
# 196/372: LQDKTYM
# 	Win 4: DKTY - 1162 samples
# 	Win 5: QDKTY - 61 samples
# 	Win 6: QDKTYM - 0 samples
# 	Win 7: LQDKTYM - 0 samples
# 	Weighted n samples: 1528.0
# 	478 predictions
# 	Xray DA: [8.30136412] Pred DA: 21.77222251181014
# 197/372: QDKTYMI
# 	Win 4: KTYM - 324 samples
# 	Win 5: DKTYM - 21 samples
# 	Win 6: DKTYMI - 0 samples
# 	Win 7: QDKTYMI - 0 samples
# 	Weighted n samples: 450.0
# 	478 predictions
# 	Xray DA: [13.02968083] Pred DA: 18.221246489032392
# 198/372: DKTYMIF
# 	Win 4: TYMI - 299 samples
# 	Win 5: KTYMI - 37 samples
# 	Win 6: KTYMIF - 35 samples
# 	Win 7: DKTYMIF - 0 samples
# 	Weighted n samples: 766.0
# 	478 predictions
# 	Xray DA: [5.9770313] Pred DA: 15.607089252258955
# 199/372: KTYMIFM
# 	Win 4: YMIF - 207 samples
# 	Win 5: TYMIF - 35 samples
# 	Win 6: TYMIFM - 0 samples
# 	Win 7: KTYMIFM - 0 samples
# 	Weighted n samples: 417.0
# 	478 predictions
# 	Xray DA: [13.62972582] Pred DA: 18.00432754757547
# 200/372: TYMIFMG
# 	Win 4: MIFM - 79 samples
# 	Win 5: YMIFM - 0 samples
# 	Win 6: YMIFMG - 0 samples
# 	Win 7: TYMIFMG - 0 samples
# 	Weighted n samples: 79.0
# 	478 predictions
# 	Xray DA: [7.04026717] Pred DA: 11.74877585918536
# 201/372: YMIFMGA
# 	Win 4: IFMG - 442 samples
# 	Win 5: MIFMG - 11 samples
# 	Win 6: MIFMGA - 0 samples
# 	Win 7: YMIFMGA - 0 samples
# 	Weighted n samples: 508.0
# 	478 predictions
# 	Xray DA: [3.50010455] Pred DA: 11.96738686215359
# 202/372: MIFMGAN
# 	Win 4: FMGA - 727 samples
# 	Win 5: IFMGA - 30 samples
# 	Win 6: IFMGAN - 3 samples
# 	Win 7: MIFMGAN - 0 samples
# 	Weighted n samples: 928.0
# 	478 predictions
# 	Xray DA: [14.9570853] Pred DA: 11.665100739637097
# 203/372: IFMGANI
# 	Win 4: MGAN - 1063 samples
# 	Win 5: FMGAN - 3 samples
# 	Win 6: FMGANI - 0 samples
# 	Win 7: IFMGANI - 0 samples
# 	Weighted n samples: 1081.0
# 	478 predictions
# 	Xray DA: [10.02990669] Pred DA: 14.809474215709784
# 204/372: FMGANIA
# 	Win 4: GANI - 2426 samples
# 	Win 5: MGANI - 95 samples
# 	Win 6: MGANIA - 57 samples
# 	Win 7: FMGANIA - 0 samples
# 	Weighted n samples: 3395.0
# 	478 predictions
# 	Xray DA: [8.59578221] Pred DA: 13.202943791630624
# 205/372: MGANIAT
# 	Win 4: ANIA - 3003 samples
# 	Win 5: GANIA - 273 samples
# 	Win 6: GANIAT - 42 samples
# 	Win 7: MGANIAT - 36 samples
# 	Weighted n samples: 5223.0
# 	478 predictions
# 	Xray DA: [45.94593106] Pred DA: 42.78007183464608
# 206/372: GANIATT
# 	Win 4: NIAT - 1921 samples
# 	Win 5: ANIAT - 153 samples
# 	Win 6: ANIATT - 2 samples
# 	Win 7: GANIATT - 0 samples
# 	Weighted n samples: 2853.0
# 	478 predictions
# 	Xray DA: [5.2462982] Pred DA: 7.68597035117268
# 207/372: ANIATTF
# 	Win 4: IATT - 1644 samples
# 	Win 5: NIATT - 48 samples
# 	Win 6: NIATTF - 8 samples
# 	Win 7: ANIATTF - 0 samples
# 	Weighted n samples: 1988.0
# 	478 predictions
# 	Xray DA: [5.18070903] Pred DA: 9.61233970163965
# 208/372: NIATTFI
# 	Win 4: ATTF - 2503 samples
# 	Win 5: IATTF - 51 samples
# 	Win 6: IATTFI - 2 samples
# 	Win 7: NIATTFI - 0 samples
# 	Weighted n samples: 2823.0
# 	478 predictions
# 	Xray DA: [7.70054755] Pred DA: 18.618062720514096
# 209/372: IATTFII
# 	Win 4: TTFI - 696 samples
# 	Win 5: ATTFI - 31 samples
# 	Win 6: ATTFII - 0 samples
# 	Win 7: IATTFII - 0 samples
# 	Weighted n samples: 882.0
# 	478 predictions
# 	Xray DA: [30.73016323] Pred DA: 11.066687826116443
# 210/372: ATTFIIM
# 	Win 4: TFII - 1101 samples
# 	Win 5: TTFII - 36 samples
# 	Win 6: TTFIIM - 0 samples
# 	Win 7: ATTFIIM - 0 samples
# 	Weighted n samples: 1317.0
# 	478 predictions
# 	Xray DA: [14.40448191] Pred DA: 17.76018246211062
# 211/372: TTFIIMQ
# 	Win 4: FIIM - 265 samples
# 	Win 5: TFIIM - 1 samples
# 	Win 6: TFIIMQ - 0 samples
# 	Win 7: TTFIIMQ - 0 samples
# 	Weighted n samples: 271.0
# 	478 predictions
# 	Xray DA: [1.7373528] Pred DA: 10.568393106093371
# 212/372: TFIIMQF
# 	Win 4: IIMQ - 167 samples
# 	Win 5: FIIMQ - 0 samples
# 	Win 6: FIIMQF - 0 samples
# 	Win 7: TFIIMQF - 0 samples
# 	Weighted n samples: 167.0
# 	478 predictions
# 	Xray DA: [2.21104403] Pred DA: 11.277196160834452
# 213/372: FIIMQFD
# 	Win 4: IMQF - 271 samples
# 	Win 5: IIMQF - 2 samples
# 	Win 6: IIMQFD - 0 samples
# 	Win 7: FIIMQFD - 0 samples
# 	Weighted n samples: 283.0
# 	478 predictions
# 	Xray DA: [4.11706381] Pred DA: 30.862233987365983
# 214/372: IIMQFDN
# 	Win 4: MQFD - 1261 samples
# 	Win 5: IMQFD - 0 samples
# 	Win 6: IMQFDN - 0 samples
# 	Win 7: IIMQFDN - 0 samples
# 	Weighted n samples: 1261.0
# 	478 predictions
# 	Xray DA: [20.06906643] Pred DA: 18.66602917811473
# ...
# 	Win 6: PREQLG - 2 samples
# 	Win 7: LPREQLG - 0 samples
# 	Weighted n samples: 4775.0
# 	503 predictions
# 	Xray DA: [20.94551165] Pred DA: 55.195431352901736
# 78/148: PREQLGE
# 	Win 4: EQLG - 4493 samples
# 	Win 5: REQLG - 580 samples
# 	Win 6: REQLGE - 2 samples
# 	Win 7: PREQLGE - 0 samples
# 	Weighted n samples: 7987.0
# 	503 predictions
# 	Xray DA: [13.46401277] Pred DA: 55.99637600693773
# 79/148: REQLGET
# 	Win 4: QLGE - 2548 samples
# 	Win 5: EQLGE - 366 samples
# 	Win 6: EQLGET - 11 samples
# 	Win 7: REQLGET - 0 samples
# 	Weighted n samples: 4821.0
# 	503 predictions
# 	Xray DA: [16.1485549] Pred DA: 75.46816774511706
# 80/148: EQLGETR
# 	Win 4: LGET - 2977 samples
# 	Win 5: QLGET - 70 samples
# 	Win 6: QLGETR - 0 samples
# 	Win 7: EQLGETR - 0 samples
# 	Weighted n samples: 3397.0
# 	503 predictions
# 	Xray DA: [5.93691447] Pred DA: 163.93189954896863
# 81/148: QLGETRL
# 	Win 4: GETR - 2151 samples
# 	Win 5: LGETR - 76 samples
# 	Win 6: LGETRL - 0 samples
# 	Win 7: QLGETRL - 0 samples
# 	Weighted n samples: 2607.0
# 	503 predictions
# 	Xray DA: [12.23009943] Pred DA: 86.89936525645011
# 82/148: LGETRLD
# 	Win 4: ETRL - 1738 samples
# 	Win 5: GETRL - 164 samples
# 	Win 6: GETRLD - 46 samples
# 	Win 7: LGETRLD - 0 samples
# 	Weighted n samples: 3044.0
# 	503 predictions
# 	Xray DA: [14.50898503] Pred DA: 60.68679315698132
# 83/148: GETRLDY
# 	Win 4: TRLD - 2086 samples
# 	Win 5: ETRLD - 104 samples
# 	Win 6: ETRLDY - 25 samples
# 	Win 7: GETRLDY - 0 samples
# 	Weighted n samples: 2885.0
# 	503 predictions
# 	Xray DA: [25.80024536] Pred DA: 114.5540249655829
# 84/148: ETRLDYD
# 	Win 4: RLDY - 1357 samples
# 	Win 5: TRLDY - 59 samples
# 	Win 6: TRLDYD - 0 samples
# 	Win 7: ETRLDYD - 0 samples
# 	Weighted n samples: 1711.0
# 	503 predictions
# 	Xray DA: [24.03519576] Pred DA: 58.259325006057516
# 85/148: TRLDYDR
# 	Win 4: LDYD - 2053 samples
# 	Win 5: RLDYD - 19 samples
# 	Win 6: RLDYDR - 0 samples
# 	Win 7: TRLDYDR - 0 samples
# 	Weighted n samples: 2167.0
# 	503 predictions
# 	Xray DA: [15.21622744] Pred DA: 76.30072237370327
# 86/148: RLDYDRT
# 	Win 4: DYDR - 2479 samples
# 	Win 5: LDYDR - 72 samples
# 	Win 6: LDYDRT - 0 samples
# 	Win 7: RLDYDRT - 0 samples
# 	Weighted n samples: 2911.0
# 	503 predictions
# 	Xray DA: [11.56516611] Pred DA: 24.657346162971734
# 87/148: LDYDRTF
# 	Win 4: YDRT - 852 samples
# 	Win 5: DYDRT - 146 samples
# 	Win 6: DYDRTF - 0 samples
# 	Win 7: LDYDRTF - 0 samples
# 	Weighted n samples: 1728.0
# 	503 predictions
# 	Xray DA: [10.94299972] Pred DA: 24.294390775014154
# 88/148: DYDRTFQ
# 	Win 4: DRTF - 1527 samples
# 	Win 5: YDRTF - 125 samples
# 	Win 6: YDRTFQ - 0 samples
# 	Win 7: DYDRTFQ - 0 samples
# 	Weighted n samples: 2277.0
# 	503 predictions
# 	Xray DA: [4.68981129] Pred DA: 19.21662752365539
# 89/148: YDRTFQL
# 	Win 4: RTFQ - 962 samples
# 	Win 5: DRTFQ - 450 samples
# 	Win 6: DRTFQL - 0 samples
# 	Win 7: YDRTFQL - 0 samples
# 	Weighted n samples: 3662.0
# 	503 predictions
# 	Xray DA: [1.39411801] Pred DA: 20.013197401448277
# 90/148: DRTFQLA
# 	Win 4: TFQL - 1078 samples
# 	Win 5: RTFQL - 16 samples
# 	Win 6: RTFQLA - 0 samples
# 	Win 7: DRTFQLA - 0 samples
# 	Weighted n samples: 1174.0
# 	503 predictions
# 	Xray DA: [1.92978816] Pred DA: 17.63663828937824
# 91/148: RTFQLAS
# 	Win 4: FQLA - 1595 samples
# 	Win 5: TFQLA - 66 samples
# 	Win 6: TFQLAS - 0 samples
# 	Win 7: RTFQLAS - 0 samples
# 	Weighted n samples: 1991.0
# 	503 predictions
# 	Xray DA: [13.26488471] Pred DA: 19.53059657987055
# 92/148: TFQLASV
# 	Win 4: QLAS - 3387 samples
# 	Win 5: FQLAS - 32 samples
# 	Win 6: FQLASV - 6 samples
# 	Win 7: TFQLASV - 0 samples
# 	Weighted n samples: 3621.0
# 	503 predictions
# 	Xray DA: [5.20769243] Pred DA: 15.424647798300018
# 93/148: FQLASVE
# 	Win 4: LASV - 5493 samples
# 	Win 5: QLASV - 218 samples
# 	Win 6: QLASVE - 17 samples
# 	Win 7: FQLASVE - 0 samples
# 	Weighted n samples: 6920.0
# 	503 predictions
# 	Xray DA: [12.12100178] Pred DA: 17.44200178500053
# 94/148: QLASVEA
# 	Win 4: ASVE - 3934 samples
# 	Win 5: LASVE - 285 samples
# 	Win 6: LASVEA - 35 samples
# 	Win 7: QLASVEA - 17 samples
# 	Weighted n samples: 6025.0
# 	503 predictions
# 	Xray DA: [85.53359168] Pred DA: 92.16127399418627
# 95/148: LASVEAA
# 	Win 4: SVEA - 3720 samples
# 	Win 5: ASVEA - 239 samples
# 	Win 6: ASVEAA - 56 samples
# 	Win 7: LASVEAA - 0 samples
# 	Weighted n samples: 5546.0
# 	503 predictions
# 	Xray DA: [12.44275396] Pred DA: 16.420233974154183
# 96/148: ASVEAAR
# 	Win 4: VEAA - 9111 samples
# 	Win 5: SVEAA - 248 samples
# 	Win 6: SVEAAR - 33 samples
# 	Win 7: ASVEAAR - 14 samples
# 	Weighted n samples: 10942.0
# 	503 predictions
# 	Xray DA: [4.11913262] Pred DA: 16.184302315610726
# 97/148: SVEAARL
# 	Win 4: EAAR - 10450 samples
# 	Win 5: VEAAR - 1662 samples
# 	Win 6: VEAARL - 22 samples
# 	Win 7: SVEAARL - 0 samples
# 	Weighted n samples: 20576.0
# 	503 predictions
# 	Xray DA: [11.78990969] Pred DA: 27.057327677467693
# 98/148: VEAARLG
# 	Win 4: AARL - 8287 samples
# 	Win 5: EAARL - 872 samples
# 	Win 6: EAARLG - 111 samples
# 	Win 7: VEAARLG - 0 samples
# 	Weighted n samples: 14296.0
# 	503 predictions
# 	Xray DA: [10.34512466] Pred DA: 27.076353870381855
# 99/148: EAARLGI
# 	Win 4: ARLG - 4635 samples
# 	Win 5: AARLG - 877 samples
# 	Win 6: AARLGI - 18 samples
# 	Win 7: EAARLGI - 0 samples
# 	Weighted n samples: 10023.0
# 	503 predictions
# 	Xray DA: [12.78752794] Pred DA: 31.495046598749894
# 100/148: AARLGIA
# 	Win 4: RLGI - 4134 samples
# 	Win 5: ARLGI - 186 samples
# 	Win 6: ARLGIA - 4 samples
# 	Win 7: AARLGIA - 0 samples
# 	Weighted n samples: 5278.0
# 	503 predictions
# 	Xray DA: [4.45662872] Pred DA: 53.14207321306262
# 101/148: ARLGIAE
# 	Win 4: LGIA - 4940 samples
# 	Win 5: RLGIA - 218 samples
# 	Win 6: RLGIAE - 6 samples
# 	Win 7: ARLGIAE - 0 samples
# 	Weighted n samples: 6290.0
# 	503 predictions
# 	Xray DA: [13.34219891] Pred DA: 78.61908146589782
# 102/148: RLGIAEP
# 	Win 4: GIAE - 2399 samples
# 	Win 5: LGIAE - 307 samples
# 	Win 6: LGIAEP - 0 samples
# 	Win 7: RLGIAEP - 0 samples
# 	Weighted n samples: 4241.0
# 	503 predictions
# 	Xray DA: [6.93277665] Pred DA: 53.69441765051989
# 103/148: LGIAEPI
# 	Win 4: IAEP - 1065 samples
# 	Win 5: GIAEP - 49 samples
# 	Win 6: GIAEPI - 0 samples
# 	Win 7: LGIAEPI - 0 samples
# 	Weighted n samples: 1359.0
# 	503 predictions
# 	Xray DA: [30.58734821] Pred DA: 78.80120531239567
# 104/148: GIAEPIG
# 	Win 4: AEPI - 927 samples
# 	Win 5: IAEPI - 109 samples
# 	Win 6: IAEPIG - 24 samples
# 	Win 7: GIAEPIG - 0 samples
# 	Weighted n samples: 1749.0
# 	503 predictions
# 	Xray DA: [18.03196209] Pred DA: 51.72302901142345
# 105/148: IAEPIGE
# 	Win 4: EPIG - 813 samples
# 	Win 5: AEPIG - 47 samples
# 	Win 6: AEPIGE - 8 samples
# 	Win 7: IAEPIGE - 0 samples
# 	Weighted n samples: 1151.0
# 	503 predictions
# 	Xray DA: [28.51179618] Pred DA: 48.70225855910587
# 106/148: AEPIGEL
# 	Win 4: PIGE - 1359 samples
# 	Win 5: EPIGE - 78 samples
# 	Win 6: EPIGEL - 0 samples
# 	Win 7: AEPIGEL - 0 samples
# 	Weighted n samples: 1827.0
# 	503 predictions
# 	Xray DA: [17.45277712] Pred DA: 58.595807803494786
# 107/148: EPIGELY
# 	Win 4: IGEL - 4137 samples
# 	Win 5: PIGEL - 72 samples
# 	Win 6: PIGELY - 0 samples
# 	Win 7: EPIGELY - 0 samples
# 	Weighted n samples: 4569.0
# 	503 predictions
# 	Xray DA: [23.55681254] Pred DA: 91.0273932588152
# 108/148: PIGELYY
# 	Win 4: GELY - 1989 samples
# 	Win 5: IGELY - 106 samples
# 	Win 6: IGELYY - 2 samples
# 	Win 7: PIGELYY - 0 samples
# 	Weighted n samples: 2639.0
# 	503 predictions
# 	Xray DA: [11.85207748] Pred DA: 61.032397405811125
# 109/148: IGELYYS
# 	Win 4: ELYY - 1033 samples
# 	Win 5: GELYY - 187 samples
# 	Win 6: GELYYS - 143 samples
# 	Win 7: IGELYYS - 0 samples
# 	Weighted n samples: 3156.0
# 	503 predictions
# 	Xray DA: [4.48925013] Pred DA: 54.74207761965646
# 110/148: GELYYSF
# 	Win 4: LYYS - 1034 samples
# 	Win 5: ELYYS - 257 samples
# 	Win 6: ELYYSF - 0 samples
# 	Win 7: GELYYSF - 0 samples
# 	Weighted n samples: 2576.0
# 	503 predictions
# 	Xray DA: [19.84777028] Pred DA: 56.25225043370514
# 111/148: ELYYSFE
# 	Win 4: YYSF - 1099 samples
# 	Win 5: LYYSF - 50 samples
# 	Win 6: LYYSFE - 0 samples
# 	Win 7: ELYYSFE - 0 samples
# 	Weighted n samples: 1399.0
# 	503 predictions
# 	Xray DA: [21.1472036] Pred DA: 58.72636337201338
# 112/148: LYYSFEY
# 	Win 4: YSFE - 1416 samples
# 	Win 5: YYSFE - 152 samples
# 	Win 6: YYSFEY - 0 samples
# 	Win 7: LYYSFEY - 0 samples
# 	Weighted n samples: 2328.0
# 	503 predictions
# 	Xray DA: [38.63897923] Pred DA: 61.05340075262172
# 113/148: YYSFEYN
# 	Win 4: SFEY - 1897 samples
# 	Win 5: YSFEY - 61 samples
# 	Win 6: YSFEYN - 2 samples
# 	Win 7: YYSFEYN - 0 samples
# 	Weighted n samples: 2277.0
# 	503 predictions
# 	Xray DA: [18.19016112] Pred DA: 81.4602908138793
# 114/148: YSFEYNF
# 	Win 4: FEYN - 623 samples
# 	Win 5: SFEYN - 48 samples
# 	Win 6: SFEYNF - 0 samples
# 	Win 7: YSFEYNF - 0 samples
# 	Weighted n samples: 911.0
# 	503 predictions
# 	Xray DA: [14.72795533] Pred DA: 82.06081346927687
# 115/148: SFEYNFF
# 	Win 4: EYNF - 1113 samples
# 	Win 5: FEYNF - 13 samples
# 	Win 6: FEYNFF - 0 samples
# 	Win 7: SFEYNFF - 0 samples
# 	Weighted n samples: 1191.0
# 	503 predictions
# 	Xray DA: [29.89139965] Pred DA: 87.07210378668438
# 116/148: FEYNFFG
# 	Win 4: YNFF - 515 samples
# 	Win 5: EYNFF - 153 samples
# 	Win 6: EYNFFG - 153 samples
# 	Win 7: FEYNFFG - 0 samples
# 	Weighted n samples: 2504.0
# 	503 predictions
# 	Xray DA: [45.12245328] Pred DA: 103.83317068510415
# 117/148: EYNFFGA
# 	Win 4: NFFG - 862 samples
# 	Win 5: YNFFG - 158 samples
# 	Win 6: YNFFGA - 0 samples
# 	Win 7: EYNFFGA - 0 samples
# 	Weighted n samples: 1810.0
# 	503 predictions
# 	Xray DA: [7.77451409] Pred DA: 53.44055267468567
# 118/148: YNFFGAG
# 	Win 4: FFGA - 1382 samples
# 	Win 5: NFFGA - 14 samples
# 	Win 6: NFFGAG - 0 samples
# 	Win 7: YNFFGAG - 0 samples
# 	Weighted n samples: 1466.0
# 	503 predictions
# 	Xray DA: [16.58403384] Pred DA: 44.874297523971485
# 119/148: NFFGAGF
# 	Win 4: FGAG - 7531 samples
# 	Win 5: FFGAG - 171 samples
# 	Win 6: FFGAGF - 2 samples
# 	Win 7: NFFGAGF - 0 samples
# 	Weighted n samples: 8571.0
# 	503 predictions
# 	Xray DA: [15.42096585] Pred DA: 58.19085459576577
# 120/148: FFGAGFG
# 	Win 4: GAGF - 2699 samples
# 	Win 5: FGAGF - 81 samples
# 	Win 6: FGAGFG - 0 samples
# 	Win 7: FFGAGFG - 0 samples
# 	Weighted n samples: 3185.0
# 	503 predictions
# 	Xray DA: [6.21701564] Pred DA: 56.97129529690949
# 121/148: FGAGFGD
# 	Win 4: AGFG - 2669 samples
# 	Win 5: GAGFG - 193 samples
# 	Win 6: GAGFGD - 0 samples
# 	Win 7: FGAGFGD - 0 samples
# 	Weighted n samples: 3827.0
# 	503 predictions
# 	Xray DA: [10.11690829] Pred DA: 68.2070477072764
# 122/148: GAGFGDH
# 	Win 4: GFGD - 2964 samples
# 	Win 5: AGFGD - 207 samples
# 	Win 6: AGFGDH - 0 samples
# 	Win 7: GAGFGDH - 0 samples
# 	Weighted n samples: 4206.0
# 	503 predictions
# 	Xray DA: [14.26991343] Pred DA: 73.74420560060442
# 123/148: AGFGDHD
# 	Win 4: FGDH - 555 samples
# 	Win 5: GFGDH - 97 samples
# 	Win 6: GFGDHD - 0 samples
# 	Win 7: AGFGDHD - 0 samples
# 	Weighted n samples: 1137.0
# 	503 predictions
# 	Xray DA: [26.49725446] Pred DA: 119.87622763986559
# 124/148: GFGDHDD
# 	Win 4: GDHD - 533 samples
# 	Win 5: FGDHD - 15 samples
# 	Win 6: FGDHDD - 3 samples
# 	Win 7: GFGDHDD - 0 samples
# 	Weighted n samples: 644.0
# 	503 predictions
# 	Xray DA: [7.43959997] Pred DA: 103.87952061699545
# 125/148: FGDHDDP
# 	Win 4: DHDD - 228 samples
# 	Win 5: GDHDD - 5 samples
# 	Win 6: GDHDDP - 0 samples
# 	Win 7: FGDHDDP - 0 samples
# 	Weighted n samples: 258.0
# 	503 predictions
# 	Xray DA: [28.73946512] Pred DA: 84.11391976041728
# 126/148: GDHDDPM
# 	Win 4: HDDP - 482 samples
# 	Win 5: DHDDP - 10 samples
# 	Win 6: DHDDPM - 0 samples
# 	Win 7: GDHDDPM - 0 samples
# 	Weighted n samples: 542.0
# 	503 predictions
# 	Xray DA: [12.80614492] Pred DA: 64.64797601001239
# 127/148: DHDDPMG
# 	Win 4: DDPM - 263 samples
# 	Win 5: HDDPM - 18 samples
# 	Win 6: HDDPMG - 0 samples
# 	Win 7: DHDDPMG - 0 samples
# 	Weighted n samples: 371.0
# 	503 predictions
# 	Xray DA: [89.81314671] Pred DA: 67.20383585193004
# 128/148: HDDPMGK
# 	Win 4: DPMG - 791 samples
# 	Win 5: DDPMG - 20 samples
# 	Win 6: DDPMGK - 0 samples
# 	Win 7: HDDPMGK - 0 samples
# 	Weighted n samples: 911.0
# 	503 predictions
# 	Xray DA: [22.26379715] Pred DA: 55.64871040866452
# 129/148: DDPMGKS
# 	Win 4: PMGK - 522 samples
# 	Win 5: DPMGK - 126 samples
# 	Win 6: DPMGKS - 0 samples
# 	Win 7: DDPMGKS - 0 samples
# 	Weighted n samples: 1278.0
# 	503 predictions
# 	Xray DA: [21.19587228] Pred DA: 85.0255138563338
# 130/148: DPMGKSW
# 	Win 4: MGKS - 909 samples
# 	Win 5: PMGKS - 6 samples
# 	Win 6: PMGKSW - 0 samples
# 	Win 7: DPMGKSW - 0 samples
# 	Weighted n samples: 945.0
# 	503 predictions
# 	Xray DA: [222.80598445] Pred DA: 166.2436044546567
# 131/148: PMGKSWL
# 	Win 4: GKSW - 389 samples
# 	Win 5: MGKSW - 0 samples
# 	Win 6: MGKSWL - 0 samples
# 	Win 7: PMGKSWL - 0 samples
# 	Weighted n samples: 389.0
# 	503 predictions
# 	Xray DA: [16.52284605] Pred DA: 59.355819683644015
# 132/148: MGKSWLF
# 	Win 4: KSWL - 657 samples
# 	Win 5: GKSWL - 13 samples
# 	Win 6: GKSWLF - 0 samples
# 	Win 7: MGKSWLF - 0 samples
# 	Weighted n samples: 735.0
# 	503 predictions
# 	Xray DA: [34.76127742] Pred DA: 50.005706410841
# 133/148: GKSWLFF
# 	Win 4: SWLF - 441 samples
# 	Win 5: KSWLF - 1 samples
# 	Win 6: KSWLFF - 0 samples
# 	Win 7: GKSWLFF - 0 samples
# 	Weighted n samples: 447.0
# 	503 predictions
# 	Xray DA: [14.51510655] Pred DA: 29.508079698983583
# 134/148: KSWLFFH
# 	Win 4: WLFF - 370 samples
# 	Win 5: SWLFF - 46 samples
# 	Win 6: SWLFFH - 0 samples
# 	Win 7: KSWLFFH - 0 samples
# 	Weighted n samples: 646.0
# 	503 predictions
# 	Xray DA: [10.01887455] Pred DA: 24.11038580298179
# 135/148: SWLFFHG
# 	Win 4: LFFH - 629 samples
# 	Win 5: WLFFH - 0 samples
# 	Win 6: WLFFHG - 0 samples
# 	Win 7: SWLFFHG - 0 samples
# 	Weighted n samples: 629.0
# 	503 predictions
# 	Xray DA: [9.48024552] Pred DA: 25.6375120906358
# 136/148: WLFFHGS
# 	Win 4: FFHG - 737 samples
# 	Win 5: LFFHG - 20 samples
# 	Win 6: LFFHGS - 0 samples
# 	Win 7: WLFFHGS - 0 samples
# 	Weighted n samples: 857.0
# 	503 predictions
# 	Xray DA: [6.42329397] Pred DA: 27.562674981014688
# 137/148: LFFHGSD
# 	Win 4: FHGS - 1029 samples
# 	Win 5: FFHGS - 8 samples
# 	Win 6: FFHGSD - 0 samples
# 	Win 7: LFFHGSD - 0 samples
# 	Weighted n samples: 1077.0
# 	503 predictions
# 	Xray DA: [16.63854763] Pred DA: 44.92468911172089
# 138/148: FFHGSDG
# 	Win 4: HGSD - 1630 samples
# 	Win 5: FHGSD - 27 samples
# 	Win 6: FHGSDG - 4 samples
# 	Win 7: FFHGSDG - 0 samples
# 	Weighted n samples: 1820.0
# 	503 predictions
# 	Xray DA: [24.96274084] Pred DA: 63.7264879421854
# 139/148: FHGSDGR
# 	Win 4: GSDG - 3278 samples
# 	Win 5: HGSDG - 42 samples
# 	Win 6: HGSDGR - 0 samples
# 	Win 7: FHGSDGR - 0 samples
# 	Weighted n samples: 3530.0
# 	503 predictions
# 	Xray DA: [24.45121004] Pred DA: 53.20242363353157
# 140/148: HGSDGRL
# 	Win 4: SDGR - 2752 samples
# 	Win 5: GSDGR - 489 samples
# 	Win 6: GSDGRL - 200 samples
# 	Win 7: HGSDGRL - 0 samples
# 	Weighted n samples: 7086.0
# 	503 predictions
# 	Xray DA: [73.03981672] Pred DA: 62.097737318264166
# 141/148: GSDGRLL
# 	Win 4: DGRL - 6362 samples
# 	Win 5: SDGRL - 448 samples
# 	Win 6: SDGRLL - 238 samples
# 	Win 7: GSDGRLL - 191 samples
# 	Weighted n samples: 12244.0
# 	503 predictions
# 	Xray DA: [1.52429216] Pred DA: 62.622862302982554
# 142/148: SDGRLLG
# 	Win 4: GRLL - 8489 samples
# 	Win 5: DGRLL - 1211 samples
# 	Win 6: DGRLLG - 8 samples
# 	Win 7: SDGRLLG - 0 samples
# 	Weighted n samples: 15811.0
# 	503 predictions
# 	Xray DA: [15.178342] Pred DA: 40.32508242224623
# 143/148: DGRLLGQ
# 	Win 4: RLLG - 6345 samples
# 	Win 5: GRLLG - 584 samples
# 	Win 6: GRLLGQ - 12 samples
# 	Win 7: DGRLLGQ - 0 samples
# 	Weighted n samples: 9933.0
# 	503 predictions
# 	Xray DA: [10.49057727] Pred DA: 33.39011844303814
# 144/148: GRLLGQE
# 	Win 4: LLGQ - 3962 samples
# 	Win 5: RLLGQ - 137 samples
# 	Win 6: RLLGQE - 0 samples
# 	Win 7: GRLLGQE - 0 samples
# 	Weighted n samples: 4784.0
# 	503 predictions
# 	Xray DA: [15.10667367] Pred DA: 50.82581222098338
# 145/148: RLLGQEV
# 	Win 4: LGQE - 2403 samples
# 	Win 5: LLGQE - 313 samples
# 	Win 6: LLGQEV - 5 samples
# 	Win 7: RLLGQEV - 0 samples
# 	Weighted n samples: 4316.0
# 	503 predictions
# 	Xray DA: [38.66414105] Pred DA: 56.69925745435131
# 146/148: LLGQEVA
# 	Win 4: GQEV - 2355 samples
# 	Win 5: LGQEV - 145 samples
# 	Win 6: LGQEVA - 10 samples
# 	Win 7: LLGQEVA - 0 samples
# 	Weighted n samples: 3295.0
# 	503 predictions
# 	Xray DA: [21.29794427] Pred DA: 36.95690633369173
# 147/148: LGQEVAG
# 	Win 4: QEVA - 2424 samples
# 	Win 5: GQEVA - 165 samples
# 	Win 6: GQEVAG - 16 samples
# 	Win 7: LGQEVAG - 0 samples
# 	Weighted n samples: 3526.0
# 	503 predictions
# 	Xray DA: [31.00807687] Pred DA: 56.52226716210203
# 148/148: GQEVAGQ
# 	Win 4: EVAG - 3116 samples
# 	Win 5: QEVAG - 191 samples
# 	Win 6: QEVAGQ - 0 samples
# 	Win 7: GQEVAGQ - 0 samples
# 	Weighted n samples: 4262.0
# 	503 predictions
# 	Xray DA: [20.50249455] Pred DA: 53.753539973565694

# %%
from lib.fit_model_on_multiple import fit_lr, plot_md_vs_rmsd
import os
PDBMINE_URL = os.getenv("PDBMINE_URL")
PROJECT_DIR = 'tests'

# model, grouped_preds = fit_model_on_multiple(['T1056', 'T1038', 'T1025', 'T1028'], WINDOW_SIZE, WINDOW_SIZE_CONTEXT, PDBMINE_URL, n_comp=2000)
model, grouped_preds = fit_lr(
    ['T1024', 'T1096', 'T1027', 'T1082', 'T1091', 'T1049', 'T1030', 'T1056', 'T1038', 'T1025'],
    # ['T1024', 'T1096', 'T1027', 'T1082', 'T1091', 'T1058', 'T1049', 'T1030', 'T1056', 'T1038', 'T1025', 'T1028'],
    [4,5,6,7], [1,32,64,128],
    PDBMINE_URL, PROJECT_DIR,
    n_comp=2000,
)
plot_md_vs_rmsd(grouped_preds, axlims=((0,60), (0,80)))
