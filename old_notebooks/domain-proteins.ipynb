# %%
# %load_ext autoreload
# %autoreload 2

# %%
from lib import DihedralAdherence
from lib import PDBMineQuery
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from pathlib import Path
PDBMINE_URL = os.getenv("PDBMINE_URL")
PROJECT_DIR = 'casp_da'

# %%
da = DihedralAdherence('T1030-D2', [4,5,6,7], PDBMINE_URL, PROJECT_DIR, kdews=[1,32,64,128], 
                       mode='ml', weights_file='ml_data/best_model_kde_64-64_390.pt', device='cuda')
# da.compute_structures(replace=False)
# da.query_pdbmine(replace=False)
# da.compute_das(replace=False)
da.load_results_da()
# Out:
# Initializing T1030-D2 ...
# Results already exist
# Casp ID: T1030-D2 	PDB: 6poo
# Structure exists: 'pdb/pdb6poo.ent'
# No CASP AlphaFold prediction

# %%
da.plot_da_vs_gdt_simple()
# Out:
# Slope: -0.37977683811652885, Intercept: 54.25419135349436 R-squared: 0.4101304235868203

# %%
da.plot_da_for_seq(da.seqs[4])
# Out:
#                phi          psi       weight      winsize
# count  2943.000000  2943.000000  2943.000000  2943.000000
# mean    -69.716174   -14.803160     2.211689     4.039076
# std      28.770121    60.585323     6.065614     0.195554
# min    -179.100000  -179.000000     1.000000     4.000000
# 25%     -74.650000   -42.300000     1.000000     4.000000
# 50%     -65.100000   -38.400000     1.000000     4.000000
# 75%     -61.600000   -28.250000     1.000000     4.000000
# max     175.500000   179.400000    64.000000     6.000000
# No AlphaFold data for this window
# Residue Q of Window SIKQAAQ centered at 167 of SIKQAAQ
# 	Win 4: KQAA - 2829 samples
# 	Win 5: IKQAA - 113 samples
# 	Win 6: IKQAAQ - 1 samples
# 	Win 7: SIKQAAQ - 0 samples
# Ideal:	 (-59.01, -42.92)
# X-ray[167]:	 (-63.02, -40.71), DA=4.59
# TS387_1-D2[13]:	 (-63.02, -40.56), DA=4.65
# Other Predictions DA:
#                  0
# count  463.000000
# mean    12.340350
# std     28.263424
# min      0.342632
# ...
